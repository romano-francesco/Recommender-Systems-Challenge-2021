# %%
# !cp -r ../input/d/romanofrancesco/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_path = "../input/recommender-system-2021-challenge-polimi/data_train.csv"
URM_all_dataframe = pd.read_csv(filepath_or_buffer=URM_path, 
                                sep=",",
                                dtype={0:int, 1:int, 2:float},
                                header=0)
URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]

userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_all_dataframe)

URM_all = sps.coo_matrix((URM_all_dataframe["Interaction"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# split data into train and validation data 80/20
URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 8 (0.06 %) of 13650 users have no sampled items

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 13642 ( 0.1%) Users that have less than 1 test interactions

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
recommender_SLIMElasticNet = SLIMElasticNetRecommender(URM_train)
recommender_SLIMElasticNet.fit(epochs = 500, l1_ratio = 0.0023170159712850467, alpha = 0.09078974149197175, 
                positive_only = True, topK = 363)

# %%
import pyximport
pyximport.install()
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: '/opt/conda/bin/python'
# Compiling [1/10]: MatrixFactorization_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorization_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorization_Cython_Epoch.c: In function ‘__pyx_pf_32MatrixFactorization_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorization_Cython_Epoch.c:8519:9: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8519 |         for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |         ^~~
# MatrixFactorization_Cython_Epoch.c:8519:9: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [1/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorizationImpressions_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_f_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_sampleBPR_Cython’:
# MatrixFactorizationImpressions_Cython_Epoch.c:12608:17: warning: ‘__pyx_v_start_pos_impression_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 12608 |       __pyx_t_4 = (__pyx_v_start_pos_impression_items + __pyx_v_index);
#       |       ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_pf_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorizationImpressions_Cython_Epoch.c:8586:7: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8586 |       for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |       ^~~
# MatrixFactorizationImpressions_Cython_Epoch.c:8586:7: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [2/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Compute_Similarity_Cython.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/Similarity/Cython/Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx...
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from SLIM_BPR_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# SLIM_BPR_Cython_Epoch.c: In function ‘__pyx_f_21SLIM_BPR_Cython_Epoch_22Sparse_Matrix_Tree_CSR_test_list_tee_conversion’:
# SLIM_BPR_Cython_Epoch.c:10691:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 10691 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx...
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Sparse_Matrix_Tree_CSR.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# Sparse_Matrix_Tree_CSR.c: In function ‘__pyx_f_22Sparse_Matrix_Tree_CSR_22Sparse_Matrix_Tree_CSR_test_list_tree_conversion’:
# Sparse_Matrix_Tree_CSR.c:5696:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5696 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [5/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [6/10]: Triangular_Matrix.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Triangular_Matrix.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [6/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [7/10]: CFW_D_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_D_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# CFW_D_Similarity_Cython_SGD.c: In function ‘__pyx_pf_27CFW_D_Similarity_Cython_SGD_27CFW_D_Similarity_Cython_SGD_6fit’:
# CFW_D_Similarity_Cython_SGD.c:5900:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5900 |   __pyx_t_3 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_3)) __PYX_ERR(0, 290, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [7/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: HP3_Similarity_Cython_SGD.pyx...
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from HP3_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# HP3_Similarity_Cython_SGD.c: In function ‘__pyx_pf_25HP3_Similarity_Cython_SGD_25HP3_Similarity_Cython_SGD_4fit’:
# HP3_Similarity_Cython_SGD.c:6147:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6147 |   __pyx_t_1 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 291, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# Compiling [8/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_DVV_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [9/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: FBSM_Rating_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from FBSM_Rating_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# FBSM_Rating_Cython_SGD.c: In function ‘__pyx_pf_22FBSM_Rating_Cython_SGD_22FBSM_Rating_Cython_SGD_2fit’:
# FBSM_Rating_Cython_SGD.c:8875:55: warning: ‘__pyx_v_num_sample’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8875 |   __pyx_t_5 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_num_sample))); if (unlikely(!__pyx_t_5)) __PYX_ERR(0, 551, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [10/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
recommender_SLIM_BPR_Cython = SLIM_BPR_Cython(URM_train)
recommender_SLIM_BPR_Cython.fit(epochs=650, sgd_mode = "sgd", topK = 483, lambda_i = 0.0006712905081189398, 
                lambda_j = 0.06584150350451998, learning_rate = 0.0036482363905043207)

# %%
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
recommender_RP3beta = RP3betaRecommender(URM_train)
recommender_RP3beta.fit(alpha = 0.9902904484569759, beta = 0.5159273869398134, topK = 61, implicit = False)

# %%
print("MAP of the starting models")

result_df, _ = evaluator_valid.evaluateRecommender(recommender_SLIMElasticNet)
print("SLIM ElasticNet - MAP: {}".format(result_df.loc[10]["MAP"]))

result_df, _ = evaluator_valid.evaluateRecommender(recommender_SLIM_BPR_Cython)
print("SLIM BPR - MAP: {}".format(result_df.loc[10]["MAP"]))

result_df, _ = evaluator_valid.evaluateRecommender(recommender_RP3beta)
print("RP3beta - MAP: {}".format(result_df.loc[10]["MAP"]))

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of three predictions scores
    R = R1*alpha + R2*beta + R3*(1-alpha-beta)
    
    Class from Dacrema exercise modified by Antonio Ercolani
    The original took as input 2 recommender

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        
        
        
    def fit(self, norm, alpha = 0.5, beta = 0.5):

        self.alpha = alpha
        self.beta = beta
        self.norm = norm


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        norm_item_weights_3 = LA.norm(item_weights_3, self.norm)
        
        
        if norm_item_weights_1 == 0:
            raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
            
        if norm_item_weights_3 == 0:
            raise ValueError("Norm {} of item weights for recommender 3 is zero. Avoiding division by zero".format(self.norm))
        
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * self.beta + item_weights_3 / norm_item_weights_3 * (1-self.alpha-self.beta)

        return item_weights

# %%
recommender_object = DifferentLossScoresHybridRecommender(URM_train, recommender_SLIMElasticNet, recommender_SLIM_BPR_Cython, recommender_RP3beta)

best_model = {
    "MAP" : 0,
    "alpha" : 0,
    "beta" : 0,
    "norm" : 0
}

for norm in [1,2]:
    for alpha in np.arange(0.0, 1.1, 0.1):
        for beta in np.arange(0.0, 1.1, 0.1):
            
            #truncate digits since np.arange sometimes doesn't
            alpha = round(alpha,1)
            beta = round(beta,1)
            
            
            #discard cases in which the sum is greater than 1 
            if ( (alpha+beta) <= 1): 
                theta = round(1-alpha-beta,1)
            
                print("----")
                recommender_object.fit(norm, alpha, beta)
                result_df, _ = evaluator_valid.evaluateRecommender(recommender_object)
                print("Norm: {}, Alpha: {}, Beta: {}, Theta: {}, Result: {}".format(norm, alpha, beta, 1-alpha-beta, result_df.loc[10]["MAP"]))

                if result_df.loc[10]["MAP"] > best_model["MAP"]:
                    best_model["MAP"] = result_df.loc[10]["MAP"]
                    best_model["alpha"] = alpha
                    best_model["norm"] = norm

                    print("*** New best model found! ")
                    print("New best model has MAP: {} with alpha: {}, beta: {}, theta: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"],
                                                                                                            1-best_model["alpha"]-best_model["beta"], best_model["norm"]))

print("----")
print("Best model has MAP: {} with alpha: {}, beta: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"], best_model["norm"]))

# %%
#re-tune - Norm: , Alpha: 0.5, Beta: 0.5, Theta: 0, Result: 0.2505692650743614
# further exploration

best_model = {
    "MAP" : 0,
    "alpha" : 0,
    "beta" : 0,
    "norm" : 0
}

for norm in [1]:
    for alpha in np.arange(0.45, 0.55, 0.01):
        for beta in np.arange(0.45, 0.55, 0.01):
            
            
            #discard cases in which the sum is greater than 1 
            if ( (alpha+beta) <= 1): 
                theta = round(1-alpha-beta,1)
            
                print("----")
                recommender_object.fit(norm, alpha, beta)
                result_df, _ = evaluator_valid.evaluateRecommender(recommender_object)
                print("Norm: {}, Alpha: {}, Beta: {}, Theta: {}, Result: {}".format(norm, alpha, beta, 1-alpha-beta, result_df.loc[10]["MAP"]))

                if result_df.loc[10]["MAP"] > best_model["MAP"]:
                    best_model["MAP"] = result_df.loc[10]["MAP"]
                    best_model["alpha"] = alpha
                    best_model["beta"] = beta
                    best_model["norm"] = norm

                    print("*** New best model found! ")
                    print("New best model has MAP: {} with alpha: {}, beta: {}, theta: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"],
                                                                                                            1-best_model["alpha"]-best_model["beta"], best_model["norm"]))

print("----")
print("Best model has MAP: {} with alpha: {}, beta: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"], best_model["norm"]))

# %%
# Best model has MAP: 0.2508066736727197 with alpha: 0.48000000000000004, beta: 0.51, norm: 1
delta_MAP_improvement = best_model["MAP"] - 0.24831015633273928
delta_MAP_improvement

# %%
recommender_SLIMElasticNet = SLIMElasticNetRecommender(URM_all)
recommender_SLIMElasticNet.fit(epochs = 500, l1_ratio = 0.0023170159712850467, alpha = 0.09078974149197175, 
                positive_only = True, topK = 363)
# Out:
# SLIMElasticNetRecommender: Processed 977 ( 5.4%) in 5.00 min. Items per second: 3.25
# SLIMElasticNetRecommender: Processed 1967 (10.9%) in 10.01 min. Items per second: 3.27
# SLIMElasticNetRecommender: Processed 2966 (16.4%) in 15.01 min. Items per second: 3.29
# SLIMElasticNetRecommender: Processed 3990 (22.1%) in 20.01 min. Items per second: 3.32
# SLIMElasticNetRecommender: Processed 5007 (27.7%) in 25.01 min. Items per second: 3.34
# SLIMElasticNetRecommender: Processed 6012 (33.3%) in 30.01 min. Items per second: 3.34
# SLIMElasticNetRecommender: Processed 7024 (38.9%) in 35.02 min. Items per second: 3.34
# SLIMElasticNetRecommender: Processed 8049 (44.6%) in 40.02 min. Items per second: 3.35
# SLIMElasticNetRecommender: Processed 9083 (50.3%) in 45.02 min. Items per second: 3.36
# SLIMElasticNetRecommender: Processed 10114 (56.0%) in 50.02 min. Items per second: 3.37
# SLIMElasticNetRecommender: Processed 11165 (61.8%) in 55.02 min. Items per second: 3.38
# SLIMElasticNetRecommender: Processed 12198 (67.5%) in 1.00 hour. Items per second: 3.39
# SLIMElasticNetRecommender: Processed 13237 (73.3%) in 1.08 hour. Items per second: 3.39
# SLIMElasticNetRecommender: Processed 14271 (79.0%) in 1.17 hour. Items per second: 3.40
# SLIMElasticNetRecommender: Processed 15317 (84.8%) in 1.25 hour. Items per second: 3.40
# SLIMElasticNetRecommender: Processed 16354 (90.6%) in 1.33 hour. Items per second: 3.41
# SLIMElasticNetRecommender: Processed 17395 (96.3%) in 1.42 hour. Items per second: 3.41
# SLIMElasticNetRecommender: Processed 18059 (100.0%) in 1.47 hour. Items per second: 3.41

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
recommender_SLIM_BPR_Cython = SLIM_BPR_Cython(URM_all)
recommender_SLIM_BPR_Cython.fit(epochs=650, sgd_mode = "sgd", topK = 483, lambda_i = 0.0006712905081189398, 
                lambda_j = 0.06584150350451998, learning_rate = 0.0036482363905043207)
# Out:
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 16742.00 MB (93.01%) of 18001.00 MB, required is 1304.51 MB. Using dense matrix.
# Processed 13650 (100.0%) in 1.74 sec. BPR loss is 5.31E-01. Sample per second: 7865
# SLIM_BPR_Recommender: Epoch 1 of 650. Elapsed time 0.90 sec
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 1.87E+00. Sample per second: 8184
# SLIM_BPR_Recommender: Epoch 2 of 650. Elapsed time 1.84 sec
# Processed 13650 (100.0%) in 1.44 sec. BPR loss is 3.11E+00. Sample per second: 9453
# SLIM_BPR_Recommender: Epoch 3 of 650. Elapsed time 2.61 sec
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 4.17E+00. Sample per second: 10590
# SLIM_BPR_Recommender: Epoch 4 of 650. Elapsed time 3.46 sec
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 5.20E+00. Sample per second: 11621
# SLIM_BPR_Recommender: Epoch 5 of 650. Elapsed time 4.34 sec
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 6.13E+00. Sample per second: 12821
# SLIM_BPR_Recommender: Epoch 6 of 650. Elapsed time 5.23 sec
# Processed 13650 (100.0%) in 0.98 sec. BPR loss is 6.98E+00. Sample per second: 13911
# SLIM_BPR_Recommender: Epoch 7 of 650. Elapsed time 6.15 sec
# Processed 13650 (100.0%) in 1.94 sec. BPR loss is 7.54E+00. Sample per second: 7036
# SLIM_BPR_Recommender: Epoch 8 of 650. Elapsed time 7.11 sec
# Processed 13650 (100.0%) in 1.83 sec. BPR loss is 8.35E+00. Sample per second: 7452
# SLIM_BPR_Recommender: Epoch 9 of 650. Elapsed time 8.00 sec
# Processed 13650 (100.0%) in 1.72 sec. BPR loss is 8.95E+00. Sample per second: 7940
# SLIM_BPR_Recommender: Epoch 10 of 650. Elapsed time 8.89 sec
# Processed 13650 (100.0%) in 1.62 sec. BPR loss is 9.51E+00. Sample per second: 8405
# SLIM_BPR_Recommender: Epoch 11 of 650. Elapsed time 9.79 sec
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 1.03E+01. Sample per second: 8993
# SLIM_BPR_Recommender: Epoch 12 of 650. Elapsed time 10.69 sec
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 1.05E+01. Sample per second: 10133
# SLIM_BPR_Recommender: Epoch 13 of 650. Elapsed time 11.52 sec
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 1.12E+01. Sample per second: 12357
# SLIM_BPR_Recommender: Epoch 14 of 650. Elapsed time 12.27 sec
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 1.15E+01. Sample per second: 13711
# SLIM_BPR_Recommender: Epoch 15 of 650. Elapsed time 13.16 sec
# Processed 13650 (100.0%) in 1.89 sec. BPR loss is 1.24E+01. Sample per second: 7228
# SLIM_BPR_Recommender: Epoch 16 of 650. Elapsed time 14.06 sec
# Processed 13650 (100.0%) in 1.76 sec. BPR loss is 1.24E+01. Sample per second: 7739
# SLIM_BPR_Recommender: Epoch 17 of 650. Elapsed time 14.93 sec
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 1.28E+01. Sample per second: 8205
# SLIM_BPR_Recommender: Epoch 18 of 650. Elapsed time 15.83 sec
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 1.32E+01. Sample per second: 8736
# SLIM_BPR_Recommender: Epoch 19 of 650. Elapsed time 16.73 sec
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 1.35E+01. Sample per second: 9432
# SLIM_BPR_Recommender: Epoch 20 of 650. Elapsed time 17.62 sec
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 1.36E+01. Sample per second: 10241
# SLIM_BPR_Recommender: Epoch 21 of 650. Elapsed time 18.50 sec
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 1.47E+01. Sample per second: 11187
# SLIM_BPR_Recommender: Epoch 22 of 650. Elapsed time 19.39 sec
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 1.45E+01. Sample per second: 12197
# SLIM_BPR_Recommender: Epoch 23 of 650. Elapsed time 20.29 sec
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 1.47E+01. Sample per second: 13831
# SLIM_BPR_Recommender: Epoch 24 of 650. Elapsed time 21.15 sec
# Processed 13650 (100.0%) in 1.85 sec. BPR loss is 1.51E+01. Sample per second: 7366
# SLIM_BPR_Recommender: Epoch 25 of 650. Elapsed time 22.02 sec
# Processed 13650 (100.0%) in 1.74 sec. BPR loss is 1.58E+01. Sample per second: 7842
# SLIM_BPR_Recommender: Epoch 26 of 650. Elapsed time 22.91 sec
# Processed 13650 (100.0%) in 1.64 sec. BPR loss is 1.52E+01. Sample per second: 8310
# SLIM_BPR_Recommender: Epoch 27 of 650. Elapsed time 23.81 sec
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 1.58E+01. Sample per second: 8926
# SLIM_BPR_Recommender: Epoch 28 of 650. Elapsed time 24.70 sec
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 1.60E+01. Sample per second: 9634
# SLIM_BPR_Recommender: Epoch 29 of 650. Elapsed time 25.58 sec
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 1.63E+01. Sample per second: 10458
# SLIM_BPR_Recommender: Epoch 30 of 650. Elapsed time 26.47 sec
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 1.65E+01. Sample per second: 11400
# SLIM_BPR_Recommender: Epoch 31 of 650. Elapsed time 27.37 sec
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 1.64E+01. Sample per second: 12413
# SLIM_BPR_Recommender: Epoch 32 of 650. Elapsed time 28.27 sec
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 1.68E+01. Sample per second: 13118
# SLIM_BPR_Recommender: Epoch 33 of 650. Elapsed time 29.21 sec
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 1.73E+01. Sample per second: 14761
# SLIM_BPR_Recommender: Epoch 34 of 650. Elapsed time 30.09 sec
# Processed 13650 (100.0%) in 1.73 sec. BPR loss is 1.71E+01. Sample per second: 7905
# SLIM_BPR_Recommender: Epoch 35 of 650. Elapsed time 30.89 sec
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 1.73E+01. Sample per second: 9352
# SLIM_BPR_Recommender: Epoch 36 of 650. Elapsed time 31.63 sec
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 1.81E+01. Sample per second: 11642
# SLIM_BPR_Recommender: Epoch 37 of 650. Elapsed time 32.34 sec
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 1.83E+01. Sample per second: 13706
# SLIM_BPR_Recommender: Epoch 38 of 650. Elapsed time 33.16 sec
# Processed 13650 (100.0%) in 1.88 sec. BPR loss is 1.81E+01. Sample per second: 7264
# SLIM_BPR_Recommender: Epoch 39 of 650. Elapsed time 34.05 sec
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 1.83E+01. Sample per second: 8197
# SLIM_BPR_Recommender: Epoch 40 of 650. Elapsed time 34.83 sec
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 1.84E+01. Sample per second: 8798
# SLIM_BPR_Recommender: Epoch 41 of 650. Elapsed time 35.72 sec
# Processed 13650 (100.0%) in 1.44 sec. BPR loss is 1.87E+01. Sample per second: 9457
# SLIM_BPR_Recommender: Epoch 42 of 650. Elapsed time 36.61 sec
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 1.97E+01. Sample per second: 10097
# SLIM_BPR_Recommender: Epoch 43 of 650. Elapsed time 37.52 sec
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 1.93E+01. Sample per second: 11149
# SLIM_BPR_Recommender: Epoch 44 of 650. Elapsed time 38.39 sec
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 1.94E+01. Sample per second: 12184
# SLIM_BPR_Recommender: Epoch 45 of 650. Elapsed time 39.29 sec
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 1.95E+01. Sample per second: 12956
# SLIM_BPR_Recommender: Epoch 46 of 650. Elapsed time 40.22 sec
# Processed 13650 (100.0%) in 0.77 sec. BPR loss is 1.98E+01. Sample per second: 17659
# SLIM_BPR_Recommender: Epoch 47 of 650. Elapsed time 40.94 sec
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 1.97E+01. Sample per second: 9282
# SLIM_BPR_Recommender: Epoch 48 of 650. Elapsed time 41.64 sec
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 1.99E+01. Sample per second: 10318
# SLIM_BPR_Recommender: Epoch 49 of 650. Elapsed time 42.49 sec
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 1.99E+01. Sample per second: 10479
# SLIM_BPR_Recommender: Epoch 50 of 650. Elapsed time 43.47 sec
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 2.03E+01. Sample per second: 12206
# SLIM_BPR_Recommender: Epoch 51 of 650. Elapsed time 44.29 sec
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 2.00E+01. Sample per second: 13290
# SLIM_BPR_Recommender: Epoch 52 of 650. Elapsed time 45.20 sec
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 2.02E+01. Sample per second: 15345
# SLIM_BPR_Recommender: Epoch 53 of 650. Elapsed time 46.06 sec
# Processed 13650 (100.0%) in 1.62 sec. BPR loss is 2.06E+01. Sample per second: 8416
# SLIM_BPR_Recommender: Epoch 54 of 650. Elapsed time 46.79 sec
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.08E+01. Sample per second: 10204
# SLIM_BPR_Recommender: Epoch 55 of 650. Elapsed time 47.51 sec
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 2.17E+01. Sample per second: 11925
# SLIM_BPR_Recommender: Epoch 56 of 650. Elapsed time 48.31 sec
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 2.11E+01. Sample per second: 13159
# SLIM_BPR_Recommender: Epoch 57 of 650. Elapsed time 49.20 sec
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.07E+01. Sample per second: 14745
# SLIM_BPR_Recommender: Epoch 58 of 650. Elapsed time 50.09 sec
# Processed 13650 (100.0%) in 1.85 sec. BPR loss is 2.15E+01. Sample per second: 7381
# SLIM_BPR_Recommender: Epoch 59 of 650. Elapsed time 51.02 sec
# Processed 13650 (100.0%) in 1.71 sec. BPR loss is 2.12E+01. Sample per second: 7982
# SLIM_BPR_Recommender: Epoch 60 of 650. Elapsed time 51.88 sec
# Processed 13650 (100.0%) in 1.61 sec. BPR loss is 2.17E+01. Sample per second: 8503
# SLIM_BPR_Recommender: Epoch 61 of 650. Elapsed time 52.77 sec
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.09E+01. Sample per second: 9091
# SLIM_BPR_Recommender: Epoch 62 of 650. Elapsed time 53.67 sec
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.06E+01. Sample per second: 9781
# SLIM_BPR_Recommender: Epoch 63 of 650. Elapsed time 54.56 sec
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.17E+01. Sample per second: 10627
# SLIM_BPR_Recommender: Epoch 64 of 650. Elapsed time 55.45 sec
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 2.14E+01. Sample per second: 13232
# SLIM_BPR_Recommender: Epoch 65 of 650. Elapsed time 56.20 sec
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 2.11E+01. Sample per second: 15034
# SLIM_BPR_Recommender: Epoch 66 of 650. Elapsed time 57.08 sec
# Processed 13650 (100.0%) in 1.78 sec. BPR loss is 2.15E+01. Sample per second: 7672
# SLIM_BPR_Recommender: Epoch 67 of 650. Elapsed time 57.95 sec
# Processed 13650 (100.0%) in 1.62 sec. BPR loss is 2.18E+01. Sample per second: 8428
# SLIM_BPR_Recommender: Epoch 68 of 650. Elapsed time 58.79 sec
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.13E+01. Sample per second: 9095
# SLIM_BPR_Recommender: Epoch 69 of 650. Elapsed time 59.67 sec
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.15E+01. Sample per second: 9842
# SLIM_BPR_Recommender: Epoch 70 of 650. Elapsed time 1.01 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.19E+01. Sample per second: 10611
# SLIM_BPR_Recommender: Epoch 71 of 650. Elapsed time 1.02 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.15E+01. Sample per second: 11385
# SLIM_BPR_Recommender: Epoch 72 of 650. Elapsed time 1.04 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.15E+01. Sample per second: 12682
# SLIM_BPR_Recommender: Epoch 73 of 650. Elapsed time 1.05 min
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 2.25E+01. Sample per second: 17159
# SLIM_BPR_Recommender: Epoch 74 of 650. Elapsed time 1.07 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 2.21E+01. Sample per second: 8556
# SLIM_BPR_Recommender: Epoch 75 of 650. Elapsed time 1.08 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.22E+01. Sample per second: 9281
# SLIM_BPR_Recommender: Epoch 76 of 650. Elapsed time 1.09 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.23E+01. Sample per second: 10218
# SLIM_BPR_Recommender: Epoch 77 of 650. Elapsed time 1.11 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.28E+01. Sample per second: 11336
# SLIM_BPR_Recommender: Epoch 78 of 650. Elapsed time 1.12 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.22E+01. Sample per second: 12495
# SLIM_BPR_Recommender: Epoch 79 of 650. Elapsed time 1.14 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.26E+01. Sample per second: 13826
# SLIM_BPR_Recommender: Epoch 80 of 650. Elapsed time 1.15 min
# Processed 13650 (100.0%) in 1.91 sec. BPR loss is 2.27E+01. Sample per second: 7147
# SLIM_BPR_Recommender: Epoch 81 of 650. Elapsed time 1.17 min
# Processed 13650 (100.0%) in 1.78 sec. BPR loss is 2.19E+01. Sample per second: 7680
# SLIM_BPR_Recommender: Epoch 82 of 650. Elapsed time 1.18 min
# Processed 13650 (100.0%) in 1.65 sec. BPR loss is 2.21E+01. Sample per second: 8291
# SLIM_BPR_Recommender: Epoch 83 of 650. Elapsed time 1.20 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.23E+01. Sample per second: 8895
# SLIM_BPR_Recommender: Epoch 84 of 650. Elapsed time 1.21 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 2.24E+01. Sample per second: 10489
# SLIM_BPR_Recommender: Epoch 85 of 650. Elapsed time 1.22 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 2.29E+01. Sample per second: 11451
# SLIM_BPR_Recommender: Epoch 86 of 650. Elapsed time 1.24 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.21E+01. Sample per second: 13524
# SLIM_BPR_Recommender: Epoch 87 of 650. Elapsed time 1.25 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 2.25E+01. Sample per second: 16906
# SLIM_BPR_Recommender: Epoch 88 of 650. Elapsed time 1.27 min
# Processed 13650 (100.0%) in 1.57 sec. BPR loss is 2.34E+01. Sample per second: 8702
# SLIM_BPR_Recommender: Epoch 89 of 650. Elapsed time 1.28 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.27E+01. Sample per second: 10620
# SLIM_BPR_Recommender: Epoch 90 of 650. Elapsed time 1.29 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.33E+01. Sample per second: 12126
# SLIM_BPR_Recommender: Epoch 91 of 650. Elapsed time 1.30 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.35E+01. Sample per second: 13411
# SLIM_BPR_Recommender: Epoch 92 of 650. Elapsed time 1.32 min
# Processed 13650 (100.0%) in 0.84 sec. BPR loss is 2.36E+01. Sample per second: 16277
# SLIM_BPR_Recommender: Epoch 93 of 650. Elapsed time 1.33 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 2.37E+01. Sample per second: 8822
# SLIM_BPR_Recommender: Epoch 94 of 650. Elapsed time 1.35 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 2.41E+01. Sample per second: 10834
# SLIM_BPR_Recommender: Epoch 95 of 650. Elapsed time 1.36 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 2.37E+01. Sample per second: 14091
# SLIM_BPR_Recommender: Epoch 96 of 650. Elapsed time 1.37 min
# Processed 13650 (100.0%) in 1.69 sec. BPR loss is 2.32E+01. Sample per second: 8078
# SLIM_BPR_Recommender: Epoch 97 of 650. Elapsed time 1.38 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.27E+01. Sample per second: 8633
# SLIM_BPR_Recommender: Epoch 98 of 650. Elapsed time 1.40 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 2.35E+01. Sample per second: 10249
# SLIM_BPR_Recommender: Epoch 99 of 650. Elapsed time 1.41 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 2.35E+01. Sample per second: 13248
# SLIM_BPR_Recommender: Epoch 100 of 650. Elapsed time 1.42 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 2.35E+01. Sample per second: 17916
# SLIM_BPR_Recommender: Epoch 101 of 650. Elapsed time 1.43 min
# Processed 13650 (100.0%) in 1.64 sec. BPR loss is 2.38E+01. Sample per second: 8300
# SLIM_BPR_Recommender: Epoch 102 of 650. Elapsed time 1.45 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.41E+01. Sample per second: 8959
# SLIM_BPR_Recommender: Epoch 103 of 650. Elapsed time 1.46 min
# Processed 13650 (100.0%) in 1.37 sec. BPR loss is 2.43E+01. Sample per second: 9962
# SLIM_BPR_Recommender: Epoch 104 of 650. Elapsed time 1.48 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 2.30E+01. Sample per second: 10851
# SLIM_BPR_Recommender: Epoch 105 of 650. Elapsed time 1.49 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.50E+01. Sample per second: 12563
# SLIM_BPR_Recommender: Epoch 106 of 650. Elapsed time 1.50 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.38E+01. Sample per second: 16517
# SLIM_BPR_Recommender: Epoch 107 of 650. Elapsed time 1.52 min
# Processed 13650 (100.0%) in 1.72 sec. BPR loss is 2.38E+01. Sample per second: 7923
# SLIM_BPR_Recommender: Epoch 108 of 650. Elapsed time 1.53 min
# Processed 13650 (100.0%) in 1.61 sec. BPR loss is 2.43E+01. Sample per second: 8503
# SLIM_BPR_Recommender: Epoch 109 of 650. Elapsed time 1.55 min
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 2.50E+01. Sample per second: 9234
# SLIM_BPR_Recommender: Epoch 110 of 650. Elapsed time 1.56 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 2.40E+01. Sample per second: 9876
# SLIM_BPR_Recommender: Epoch 111 of 650. Elapsed time 1.58 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 2.44E+01. Sample per second: 10480
# SLIM_BPR_Recommender: Epoch 112 of 650. Elapsed time 1.59 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.55E+01. Sample per second: 11404
# SLIM_BPR_Recommender: Epoch 113 of 650. Elapsed time 1.61 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.48E+01. Sample per second: 12681
# SLIM_BPR_Recommender: Epoch 114 of 650. Elapsed time 1.62 min
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.50E+01. Sample per second: 14614
# SLIM_BPR_Recommender: Epoch 115 of 650. Elapsed time 1.64 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 2.41E+01. Sample per second: 7526
# SLIM_BPR_Recommender: Epoch 116 of 650. Elapsed time 1.65 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.44E+01. Sample per second: 8164
# SLIM_BPR_Recommender: Epoch 117 of 650. Elapsed time 1.66 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.45E+01. Sample per second: 8659
# SLIM_BPR_Recommender: Epoch 118 of 650. Elapsed time 1.68 min
# Processed 13650 (100.0%) in 1.37 sec. BPR loss is 2.52E+01. Sample per second: 9966
# SLIM_BPR_Recommender: Epoch 119 of 650. Elapsed time 1.69 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.47E+01. Sample per second: 12622
# SLIM_BPR_Recommender: Epoch 120 of 650. Elapsed time 1.70 min
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 2.42E+01. Sample per second: 17263
# SLIM_BPR_Recommender: Epoch 121 of 650. Elapsed time 1.72 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.51E+01. Sample per second: 8185
# SLIM_BPR_Recommender: Epoch 122 of 650. Elapsed time 1.73 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.48E+01. Sample per second: 9285
# SLIM_BPR_Recommender: Epoch 123 of 650. Elapsed time 1.74 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.54E+01. Sample per second: 10385
# SLIM_BPR_Recommender: Epoch 124 of 650. Elapsed time 1.76 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 2.52E+01. Sample per second: 13009
# SLIM_BPR_Recommender: Epoch 125 of 650. Elapsed time 1.77 min
# Processed 13650 (100.0%) in 0.75 sec. BPR loss is 2.57E+01. Sample per second: 18165
# SLIM_BPR_Recommender: Epoch 126 of 650. Elapsed time 1.78 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.54E+01. Sample per second: 8643
# SLIM_BPR_Recommender: Epoch 127 of 650. Elapsed time 1.80 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.60E+01. Sample per second: 10425
# SLIM_BPR_Recommender: Epoch 128 of 650. Elapsed time 1.81 min
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 2.51E+01. Sample per second: 11757
# SLIM_BPR_Recommender: Epoch 129 of 650. Elapsed time 1.82 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.60E+01. Sample per second: 13395
# SLIM_BPR_Recommender: Epoch 130 of 650. Elapsed time 1.84 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 2.56E+01. Sample per second: 15339
# SLIM_BPR_Recommender: Epoch 131 of 650. Elapsed time 1.85 min
# Processed 13650 (100.0%) in 1.75 sec. BPR loss is 2.65E+01. Sample per second: 7781
# SLIM_BPR_Recommender: Epoch 132 of 650. Elapsed time 1.87 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.56E+01. Sample per second: 8958
# SLIM_BPR_Recommender: Epoch 133 of 650. Elapsed time 1.88 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.58E+01. Sample per second: 9820
# SLIM_BPR_Recommender: Epoch 134 of 650. Elapsed time 1.89 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 2.73E+01. Sample per second: 10795
# SLIM_BPR_Recommender: Epoch 135 of 650. Elapsed time 1.91 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.68E+01. Sample per second: 12029
# SLIM_BPR_Recommender: Epoch 136 of 650. Elapsed time 1.92 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.61E+01. Sample per second: 13520
# SLIM_BPR_Recommender: Epoch 137 of 650. Elapsed time 1.94 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 2.56E+01. Sample per second: 14551
# SLIM_BPR_Recommender: Epoch 138 of 650. Elapsed time 1.95 min
# Processed 13650 (100.0%) in 1.83 sec. BPR loss is 2.61E+01. Sample per second: 7471
# SLIM_BPR_Recommender: Epoch 139 of 650. Elapsed time 1.97 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 2.53E+01. Sample per second: 8582
# SLIM_BPR_Recommender: Epoch 140 of 650. Elapsed time 1.98 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.56E+01. Sample per second: 9312
# SLIM_BPR_Recommender: Epoch 141 of 650. Elapsed time 1.99 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.58E+01. Sample per second: 10219
# SLIM_BPR_Recommender: Epoch 142 of 650. Elapsed time 2.01 min
# Processed 13650 (100.0%) in 1.23 sec. BPR loss is 2.65E+01. Sample per second: 11089
# SLIM_BPR_Recommender: Epoch 143 of 650. Elapsed time 2.02 min
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 2.64E+01. Sample per second: 12243
# SLIM_BPR_Recommender: Epoch 144 of 650. Elapsed time 2.04 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 2.60E+01. Sample per second: 13674
# SLIM_BPR_Recommender: Epoch 145 of 650. Elapsed time 2.05 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 2.73E+01. Sample per second: 15320
# SLIM_BPR_Recommender: Epoch 146 of 650. Elapsed time 2.07 min
# Processed 13650 (100.0%) in 1.79 sec. BPR loss is 2.70E+01. Sample per second: 7627
# SLIM_BPR_Recommender: Epoch 147 of 650. Elapsed time 2.08 min
# Processed 13650 (100.0%) in 1.68 sec. BPR loss is 2.68E+01. Sample per second: 8136
# SLIM_BPR_Recommender: Epoch 148 of 650. Elapsed time 2.10 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 2.63E+01. Sample per second: 8824
# SLIM_BPR_Recommender: Epoch 149 of 650. Elapsed time 2.11 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.60E+01. Sample per second: 9735
# SLIM_BPR_Recommender: Epoch 150 of 650. Elapsed time 2.13 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.64E+01. Sample per second: 10406
# SLIM_BPR_Recommender: Epoch 151 of 650. Elapsed time 2.14 min
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 2.68E+01. Sample per second: 11180
# SLIM_BPR_Recommender: Epoch 152 of 650. Elapsed time 2.16 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.70E+01. Sample per second: 12409
# SLIM_BPR_Recommender: Epoch 153 of 650. Elapsed time 2.17 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.73E+01. Sample per second: 13808
# SLIM_BPR_Recommender: Epoch 154 of 650. Elapsed time 2.19 min
# Processed 13650 (100.0%) in 1.86 sec. BPR loss is 2.77E+01. Sample per second: 7322
# SLIM_BPR_Recommender: Epoch 155 of 650. Elapsed time 2.20 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.65E+01. Sample per second: 8511
# SLIM_BPR_Recommender: Epoch 156 of 650. Elapsed time 2.21 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.78E+01. Sample per second: 9091
# SLIM_BPR_Recommender: Epoch 157 of 650. Elapsed time 2.23 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.69E+01. Sample per second: 9823
# SLIM_BPR_Recommender: Epoch 158 of 650. Elapsed time 2.24 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.80E+01. Sample per second: 10687
# SLIM_BPR_Recommender: Epoch 159 of 650. Elapsed time 2.26 min
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 2.79E+01. Sample per second: 12231
# SLIM_BPR_Recommender: Epoch 160 of 650. Elapsed time 2.27 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.77E+01. Sample per second: 16488
# SLIM_BPR_Recommender: Epoch 161 of 650. Elapsed time 2.28 min
# Processed 13650 (100.0%) in 1.70 sec. BPR loss is 2.86E+01. Sample per second: 8007
# SLIM_BPR_Recommender: Epoch 162 of 650. Elapsed time 2.30 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.78E+01. Sample per second: 8659
# SLIM_BPR_Recommender: Epoch 163 of 650. Elapsed time 2.31 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.88E+01. Sample per second: 8746
# SLIM_BPR_Recommender: Epoch 164 of 650. Elapsed time 2.33 min
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 2.71E+01. Sample per second: 9540
# SLIM_BPR_Recommender: Epoch 165 of 650. Elapsed time 2.34 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.73E+01. Sample per second: 10896
# SLIM_BPR_Recommender: Epoch 166 of 650. Elapsed time 2.36 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 2.74E+01. Sample per second: 14172
# SLIM_BPR_Recommender: Epoch 167 of 650. Elapsed time 2.37 min
# Processed 13650 (100.0%) in 1.82 sec. BPR loss is 2.64E+01. Sample per second: 7501
# SLIM_BPR_Recommender: Epoch 168 of 650. Elapsed time 2.38 min
# Processed 13650 (100.0%) in 1.69 sec. BPR loss is 2.79E+01. Sample per second: 8081
# SLIM_BPR_Recommender: Epoch 169 of 650. Elapsed time 2.40 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.65E+01. Sample per second: 8724
# SLIM_BPR_Recommender: Epoch 170 of 650. Elapsed time 2.41 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.69E+01. Sample per second: 9382
# SLIM_BPR_Recommender: Epoch 171 of 650. Elapsed time 2.43 min
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 2.75E+01. Sample per second: 10111
# SLIM_BPR_Recommender: Epoch 172 of 650. Elapsed time 2.44 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 2.82E+01. Sample per second: 10861
# SLIM_BPR_Recommender: Epoch 173 of 650. Elapsed time 2.46 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 2.85E+01. Sample per second: 11947
# SLIM_BPR_Recommender: Epoch 174 of 650. Elapsed time 2.47 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.79E+01. Sample per second: 13434
# SLIM_BPR_Recommender: Epoch 175 of 650. Elapsed time 2.49 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.89E+01. Sample per second: 14431
# SLIM_BPR_Recommender: Epoch 176 of 650. Elapsed time 2.50 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 2.76E+01. Sample per second: 7526
# SLIM_BPR_Recommender: Epoch 177 of 650. Elapsed time 2.52 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.78E+01. Sample per second: 8175
# SLIM_BPR_Recommender: Epoch 178 of 650. Elapsed time 2.53 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.87E+01. Sample per second: 8928
# SLIM_BPR_Recommender: Epoch 179 of 650. Elapsed time 2.54 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.69E+01. Sample per second: 9835
# SLIM_BPR_Recommender: Epoch 180 of 650. Elapsed time 2.56 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 2.78E+01. Sample per second: 10810
# SLIM_BPR_Recommender: Epoch 181 of 650. Elapsed time 2.57 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.71E+01. Sample per second: 12036
# SLIM_BPR_Recommender: Epoch 182 of 650. Elapsed time 2.59 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.72E+01. Sample per second: 13483
# SLIM_BPR_Recommender: Epoch 183 of 650. Elapsed time 2.60 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 2.84E+01. Sample per second: 15046
# SLIM_BPR_Recommender: Epoch 184 of 650. Elapsed time 2.62 min
# Processed 13650 (100.0%) in 1.79 sec. BPR loss is 2.85E+01. Sample per second: 7630
# SLIM_BPR_Recommender: Epoch 185 of 650. Elapsed time 2.63 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.76E+01. Sample per second: 8187
# SLIM_BPR_Recommender: Epoch 186 of 650. Elapsed time 2.65 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 2.84E+01. Sample per second: 8877
# SLIM_BPR_Recommender: Epoch 187 of 650. Elapsed time 2.66 min
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 2.86E+01. Sample per second: 9518
# SLIM_BPR_Recommender: Epoch 188 of 650. Elapsed time 2.68 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 2.80E+01. Sample per second: 11428
# SLIM_BPR_Recommender: Epoch 189 of 650. Elapsed time 2.69 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.74E+01. Sample per second: 12651
# SLIM_BPR_Recommender: Epoch 190 of 650. Elapsed time 2.70 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.93E+01. Sample per second: 14331
# SLIM_BPR_Recommender: Epoch 191 of 650. Elapsed time 2.72 min
# Processed 13650 (100.0%) in 1.82 sec. BPR loss is 2.90E+01. Sample per second: 7509
# SLIM_BPR_Recommender: Epoch 192 of 650. Elapsed time 2.73 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.82E+01. Sample per second: 8151
# SLIM_BPR_Recommender: Epoch 193 of 650. Elapsed time 2.75 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.82E+01. Sample per second: 8769
# SLIM_BPR_Recommender: Epoch 194 of 650. Elapsed time 2.76 min
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 2.89E+01. Sample per second: 9544
# SLIM_BPR_Recommender: Epoch 195 of 650. Elapsed time 2.78 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.81E+01. Sample per second: 10198
# SLIM_BPR_Recommender: Epoch 196 of 650. Elapsed time 2.79 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 2.92E+01. Sample per second: 11543
# SLIM_BPR_Recommender: Epoch 197 of 650. Elapsed time 2.81 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.81E+01. Sample per second: 12597
# SLIM_BPR_Recommender: Epoch 198 of 650. Elapsed time 2.82 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 2.89E+01. Sample per second: 14172
# SLIM_BPR_Recommender: Epoch 199 of 650. Elapsed time 2.84 min
# Processed 13650 (100.0%) in 1.84 sec. BPR loss is 2.86E+01. Sample per second: 7431
# SLIM_BPR_Recommender: Epoch 200 of 650. Elapsed time 2.85 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 2.84E+01. Sample per second: 7539
# SLIM_BPR_Recommender: Epoch 201 of 650. Elapsed time 2.87 min
# Processed 13650 (100.0%) in 1.68 sec. BPR loss is 2.81E+01. Sample per second: 8122
# SLIM_BPR_Recommender: Epoch 202 of 650. Elapsed time 2.88 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.85E+01. Sample per second: 8739
# SLIM_BPR_Recommender: Epoch 203 of 650. Elapsed time 2.90 min
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 2.93E+01. Sample per second: 9563
# SLIM_BPR_Recommender: Epoch 204 of 650. Elapsed time 2.91 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 2.98E+01. Sample per second: 10494
# SLIM_BPR_Recommender: Epoch 205 of 650. Elapsed time 2.92 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 2.82E+01. Sample per second: 11592
# SLIM_BPR_Recommender: Epoch 206 of 650. Elapsed time 2.94 min
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 2.88E+01. Sample per second: 13079
# SLIM_BPR_Recommender: Epoch 207 of 650. Elapsed time 2.95 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 2.90E+01. Sample per second: 15010
# SLIM_BPR_Recommender: Epoch 208 of 650. Elapsed time 2.97 min
# Processed 13650 (100.0%) in 1.78 sec. BPR loss is 2.99E+01. Sample per second: 7674
# SLIM_BPR_Recommender: Epoch 209 of 650. Elapsed time 2.98 min
# Processed 13650 (100.0%) in 1.65 sec. BPR loss is 3.02E+01. Sample per second: 8296
# SLIM_BPR_Recommender: Epoch 210 of 650. Elapsed time 3.00 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.82E+01. Sample per second: 8956
# SLIM_BPR_Recommender: Epoch 211 of 650. Elapsed time 3.01 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.86E+01. Sample per second: 9708
# SLIM_BPR_Recommender: Epoch 212 of 650. Elapsed time 3.03 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.85E+01. Sample per second: 10596
# SLIM_BPR_Recommender: Epoch 213 of 650. Elapsed time 3.04 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 2.82E+01. Sample per second: 11469
# SLIM_BPR_Recommender: Epoch 214 of 650. Elapsed time 3.06 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.99E+01. Sample per second: 14882
# SLIM_BPR_Recommender: Epoch 215 of 650. Elapsed time 3.07 min
# Processed 13650 (100.0%) in 1.78 sec. BPR loss is 2.91E+01. Sample per second: 7660
# SLIM_BPR_Recommender: Epoch 216 of 650. Elapsed time 3.08 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 2.79E+01. Sample per second: 8168
# SLIM_BPR_Recommender: Epoch 217 of 650. Elapsed time 3.10 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 3.00E+01. Sample per second: 8834
# SLIM_BPR_Recommender: Epoch 218 of 650. Elapsed time 3.11 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.95E+01. Sample per second: 9655
# SLIM_BPR_Recommender: Epoch 219 of 650. Elapsed time 3.13 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 2.92E+01. Sample per second: 10744
# SLIM_BPR_Recommender: Epoch 220 of 650. Elapsed time 3.14 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.82E+01. Sample per second: 12085
# SLIM_BPR_Recommender: Epoch 221 of 650. Elapsed time 3.15 min
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 2.92E+01. Sample per second: 15890
# SLIM_BPR_Recommender: Epoch 222 of 650. Elapsed time 3.17 min
# Processed 13650 (100.0%) in 1.57 sec. BPR loss is 2.88E+01. Sample per second: 8718
# SLIM_BPR_Recommender: Epoch 223 of 650. Elapsed time 3.18 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.92E+01. Sample per second: 10451
# SLIM_BPR_Recommender: Epoch 224 of 650. Elapsed time 3.19 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 2.93E+01. Sample per second: 11699
# SLIM_BPR_Recommender: Epoch 225 of 650. Elapsed time 3.21 min
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 2.86E+01. Sample per second: 13071
# SLIM_BPR_Recommender: Epoch 226 of 650. Elapsed time 3.22 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 3.03E+01. Sample per second: 14380
# SLIM_BPR_Recommender: Epoch 227 of 650. Elapsed time 3.24 min
# Processed 13650 (100.0%) in 1.80 sec. BPR loss is 2.97E+01. Sample per second: 7568
# SLIM_BPR_Recommender: Epoch 228 of 650. Elapsed time 3.25 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 2.95E+01. Sample per second: 8208
# SLIM_BPR_Recommender: Epoch 229 of 650. Elapsed time 3.26 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.93E+01. Sample per second: 8916
# SLIM_BPR_Recommender: Epoch 230 of 650. Elapsed time 3.28 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.87E+01. Sample per second: 9704
# SLIM_BPR_Recommender: Epoch 231 of 650. Elapsed time 3.29 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 2.98E+01. Sample per second: 10758
# SLIM_BPR_Recommender: Epoch 232 of 650. Elapsed time 3.31 min
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 2.93E+01. Sample per second: 11766
# SLIM_BPR_Recommender: Epoch 233 of 650. Elapsed time 3.32 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 3.04E+01. Sample per second: 13260
# SLIM_BPR_Recommender: Epoch 234 of 650. Elapsed time 3.34 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.92E+01. Sample per second: 15143
# SLIM_BPR_Recommender: Epoch 235 of 650. Elapsed time 3.35 min
# Processed 13650 (100.0%) in 1.79 sec. BPR loss is 2.94E+01. Sample per second: 7625
# SLIM_BPR_Recommender: Epoch 236 of 650. Elapsed time 3.37 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 2.83E+01. Sample per second: 8201
# SLIM_BPR_Recommender: Epoch 237 of 650. Elapsed time 3.38 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 2.96E+01. Sample per second: 8880
# SLIM_BPR_Recommender: Epoch 238 of 650. Elapsed time 3.40 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.97E+01. Sample per second: 9056
# SLIM_BPR_Recommender: Epoch 239 of 650. Elapsed time 3.41 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 3.02E+01. Sample per second: 9282
# SLIM_BPR_Recommender: Epoch 240 of 650. Elapsed time 3.43 min
# Processed 13650 (100.0%) in 1.21 sec. BPR loss is 2.92E+01. Sample per second: 11263
# SLIM_BPR_Recommender: Epoch 241 of 650. Elapsed time 3.44 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 2.97E+01. Sample per second: 12986
# SLIM_BPR_Recommender: Epoch 242 of 650. Elapsed time 3.45 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 2.91E+01. Sample per second: 14122
# SLIM_BPR_Recommender: Epoch 243 of 650. Elapsed time 3.47 min
# Processed 13650 (100.0%) in 1.88 sec. BPR loss is 2.98E+01. Sample per second: 7277
# SLIM_BPR_Recommender: Epoch 244 of 650. Elapsed time 3.48 min
# Processed 13650 (100.0%) in 1.77 sec. BPR loss is 3.04E+01. Sample per second: 7711
# SLIM_BPR_Recommender: Epoch 245 of 650. Elapsed time 3.50 min
# Processed 13650 (100.0%) in 1.64 sec. BPR loss is 3.01E+01. Sample per second: 8311
# SLIM_BPR_Recommender: Epoch 246 of 650. Elapsed time 3.51 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.87E+01. Sample per second: 9080
# SLIM_BPR_Recommender: Epoch 247 of 650. Elapsed time 3.53 min
# Processed 13650 (100.0%) in 1.36 sec. BPR loss is 3.02E+01. Sample per second: 10019
# SLIM_BPR_Recommender: Epoch 248 of 650. Elapsed time 3.54 min
# Processed 13650 (100.0%) in 1.23 sec. BPR loss is 3.06E+01. Sample per second: 11140
# SLIM_BPR_Recommender: Epoch 249 of 650. Elapsed time 3.56 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.99E+01. Sample per second: 12465
# SLIM_BPR_Recommender: Epoch 250 of 650. Elapsed time 3.57 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 2.96E+01. Sample per second: 14266
# SLIM_BPR_Recommender: Epoch 251 of 650. Elapsed time 3.59 min
# Processed 13650 (100.0%) in 1.85 sec. BPR loss is 2.97E+01. Sample per second: 7370
# SLIM_BPR_Recommender: Epoch 252 of 650. Elapsed time 3.60 min
# Processed 13650 (100.0%) in 1.74 sec. BPR loss is 2.98E+01. Sample per second: 7849
# SLIM_BPR_Recommender: Epoch 253 of 650. Elapsed time 3.62 min
# Processed 13650 (100.0%) in 1.61 sec. BPR loss is 2.96E+01. Sample per second: 8494
# SLIM_BPR_Recommender: Epoch 254 of 650. Elapsed time 3.63 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 3.06E+01. Sample per second: 9333
# SLIM_BPR_Recommender: Epoch 255 of 650. Elapsed time 3.64 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 3.00E+01. Sample per second: 10281
# SLIM_BPR_Recommender: Epoch 256 of 650. Elapsed time 3.66 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 3.20E+01. Sample per second: 11459
# SLIM_BPR_Recommender: Epoch 257 of 650. Elapsed time 3.67 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 3.22E+01. Sample per second: 14349
# SLIM_BPR_Recommender: Epoch 258 of 650. Elapsed time 3.69 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 3.02E+01. Sample per second: 7553
# SLIM_BPR_Recommender: Epoch 259 of 650. Elapsed time 3.70 min
# Processed 13650 (100.0%) in 1.68 sec. BPR loss is 3.01E+01. Sample per second: 8116
# SLIM_BPR_Recommender: Epoch 260 of 650. Elapsed time 3.71 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 3.09E+01. Sample per second: 8922
# SLIM_BPR_Recommender: Epoch 261 of 650. Elapsed time 3.73 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 3.02E+01. Sample per second: 9848
# SLIM_BPR_Recommender: Epoch 262 of 650. Elapsed time 3.74 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.94E+01. Sample per second: 10961
# SLIM_BPR_Recommender: Epoch 263 of 650. Elapsed time 3.76 min
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 2.97E+01. Sample per second: 12167
# SLIM_BPR_Recommender: Epoch 264 of 650. Elapsed time 3.77 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 2.97E+01. Sample per second: 13210
# SLIM_BPR_Recommender: Epoch 265 of 650. Elapsed time 3.79 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.90E+01. Sample per second: 15242
# SLIM_BPR_Recommender: Epoch 266 of 650. Elapsed time 3.80 min
# Processed 13650 (100.0%) in 1.78 sec. BPR loss is 3.16E+01. Sample per second: 7687
# SLIM_BPR_Recommender: Epoch 267 of 650. Elapsed time 3.82 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 3.15E+01. Sample per second: 8235
# SLIM_BPR_Recommender: Epoch 268 of 650. Elapsed time 3.83 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 3.02E+01. Sample per second: 9011
# SLIM_BPR_Recommender: Epoch 269 of 650. Elapsed time 3.84 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 3.11E+01. Sample per second: 10529
# SLIM_BPR_Recommender: Epoch 270 of 650. Elapsed time 3.86 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 3.01E+01. Sample per second: 13428
# SLIM_BPR_Recommender: Epoch 271 of 650. Elapsed time 3.87 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 3.05E+01. Sample per second: 15683
# SLIM_BPR_Recommender: Epoch 272 of 650. Elapsed time 3.88 min
# Processed 13650 (100.0%) in 1.69 sec. BPR loss is 3.13E+01. Sample per second: 8067
# SLIM_BPR_Recommender: Epoch 273 of 650. Elapsed time 3.90 min
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 3.09E+01. Sample per second: 9228
# SLIM_BPR_Recommender: Epoch 274 of 650. Elapsed time 3.91 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 3.09E+01. Sample per second: 10255
# SLIM_BPR_Recommender: Epoch 275 of 650. Elapsed time 3.93 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 3.18E+01. Sample per second: 11398
# SLIM_BPR_Recommender: Epoch 276 of 650. Elapsed time 3.94 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 3.19E+01. Sample per second: 13735
# SLIM_BPR_Recommender: Epoch 277 of 650. Elapsed time 3.95 min
# Processed 13650 (100.0%) in 1.88 sec. BPR loss is 3.02E+01. Sample per second: 7272
# SLIM_BPR_Recommender: Epoch 278 of 650. Elapsed time 3.97 min
# Processed 13650 (100.0%) in 1.68 sec. BPR loss is 3.23E+01. Sample per second: 8147
# SLIM_BPR_Recommender: Epoch 279 of 650. Elapsed time 3.98 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.99E+01. Sample per second: 8943
# SLIM_BPR_Recommender: Epoch 280 of 650. Elapsed time 3.99 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 3.23E+01. Sample per second: 9883
# SLIM_BPR_Recommender: Epoch 281 of 650. Elapsed time 4.01 min
# Processed 13650 (100.0%) in 1.24 sec. BPR loss is 3.19E+01. Sample per second: 11010
# SLIM_BPR_Recommender: Epoch 282 of 650. Elapsed time 4.02 min
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 3.13E+01. Sample per second: 12306
# SLIM_BPR_Recommender: Epoch 283 of 650. Elapsed time 4.04 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 3.22E+01. Sample per second: 14199
# SLIM_BPR_Recommender: Epoch 284 of 650. Elapsed time 4.05 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 3.03E+01. Sample per second: 7525
# SLIM_BPR_Recommender: Epoch 285 of 650. Elapsed time 4.07 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 3.21E+01. Sample per second: 8214
# SLIM_BPR_Recommender: Epoch 286 of 650. Elapsed time 4.08 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 3.08E+01. Sample per second: 8979
# SLIM_BPR_Recommender: Epoch 287 of 650. Elapsed time 4.09 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 3.10E+01. Sample per second: 9921
# SLIM_BPR_Recommender: Epoch 288 of 650. Elapsed time 4.11 min
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 3.06E+01. Sample per second: 12279
# SLIM_BPR_Recommender: Epoch 289 of 650. Elapsed time 4.12 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 3.07E+01. Sample per second: 15253
# SLIM_BPR_Recommender: Epoch 290 of 650. Elapsed time 4.13 min
# Processed 13650 (100.0%) in 1.79 sec. BPR loss is 3.34E+01. Sample per second: 7617
# SLIM_BPR_Recommender: Epoch 291 of 650. Elapsed time 4.15 min
# Processed 13650 (100.0%) in 1.68 sec. BPR loss is 3.23E+01. Sample per second: 8114
# SLIM_BPR_Recommender: Epoch 292 of 650. Elapsed time 4.16 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 3.12E+01. Sample per second: 8796
# SLIM_BPR_Recommender: Epoch 293 of 650. Elapsed time 4.18 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 3.05E+01. Sample per second: 9727
# SLIM_BPR_Recommender: Epoch 294 of 650. Elapsed time 4.19 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 3.24E+01. Sample per second: 10721
# SLIM_BPR_Recommender: Epoch 295 of 650. Elapsed time 4.21 min
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 2.95E+01. Sample per second: 12161
# SLIM_BPR_Recommender: Epoch 296 of 650. Elapsed time 4.22 min
# Processed 13650 (100.0%) in 0.98 sec. BPR loss is 3.15E+01. Sample per second: 13958
# SLIM_BPR_Recommender: Epoch 297 of 650. Elapsed time 4.24 min
# Processed 13650 (100.0%) in 1.84 sec. BPR loss is 3.24E+01. Sample per second: 7415
# SLIM_BPR_Recommender: Epoch 298 of 650. Elapsed time 4.25 min
# Processed 13650 (100.0%) in 1.70 sec. BPR loss is 3.24E+01. Sample per second: 8028
# SLIM_BPR_Recommender: Epoch 299 of 650. Elapsed time 4.26 min
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 3.32E+01. Sample per second: 9620
# SLIM_BPR_Recommender: Epoch 300 of 650. Elapsed time 4.28 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 3.12E+01. Sample per second: 10769
# SLIM_BPR_Recommender: Epoch 301 of 650. Elapsed time 4.29 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 3.32E+01. Sample per second: 12036
# SLIM_BPR_Recommender: Epoch 302 of 650. Elapsed time 4.31 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 3.25E+01. Sample per second: 15288
# SLIM_BPR_Recommender: Epoch 303 of 650. Elapsed time 4.32 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 3.19E+01. Sample per second: 8556
# SLIM_BPR_Recommender: Epoch 304 of 650. Elapsed time 4.33 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 3.12E+01. Sample per second: 9117
# SLIM_BPR_Recommender: Epoch 305 of 650. Elapsed time 4.34 min
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 3.31E+01. Sample per second: 10130
# SLIM_BPR_Recommender: Epoch 306 of 650. Elapsed time 4.36 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 3.20E+01. Sample per second: 11338
# SLIM_BPR_Recommender: Epoch 307 of 650. Elapsed time 4.37 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 3.16E+01. Sample per second: 12793
# SLIM_BPR_Recommender: Epoch 308 of 650. Elapsed time 4.39 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 3.17E+01. Sample per second: 14539
# SLIM_BPR_Recommender: Epoch 309 of 650. Elapsed time 4.40 min
# Processed 13650 (100.0%) in 1.81 sec. BPR loss is 3.21E+01. Sample per second: 7555
# SLIM_BPR_Recommender: Epoch 310 of 650. Elapsed time 4.42 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 3.05E+01. Sample per second: 8158
# SLIM_BPR_Recommender: Epoch 311 of 650. Elapsed time 4.43 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 3.24E+01. Sample per second: 8998
# SLIM_BPR_Recommender: Epoch 312 of 650. Elapsed time 4.44 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 3.12E+01. Sample per second: 9784
# SLIM_BPR_Recommender: Epoch 313 of 650. Elapsed time 4.46 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 3.19E+01. Sample per second: 10813
# SLIM_BPR_Recommender: Epoch 314 of 650. Elapsed time 4.47 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 3.24E+01. Sample per second: 11985
# SLIM_BPR_Recommender: Epoch 315 of 650. Elapsed time 4.49 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 3.19E+01. Sample per second: 13643
# SLIM_BPR_Recommender: Epoch 316 of 650. Elapsed time 4.50 min
# Processed 13650 (100.0%) in 0.72 sec. BPR loss is 3.12E+01. Sample per second: 18831
# SLIM_BPR_Recommender: Epoch 317 of 650. Elapsed time 4.51 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 3.26E+01. Sample per second: 8587
# SLIM_BPR_Recommender: Epoch 318 of 650. Elapsed time 4.53 min
# Processed 13650 (100.0%) in 1.44 sec. BPR loss is 3.17E+01. Sample per second: 9458
# SLIM_BPR_Recommender: Epoch 319 of 650. Elapsed time 4.54 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 3.15E+01. Sample per second: 10453
# SLIM_BPR_Recommender: Epoch 320 of 650. Elapsed time 4.56 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 3.12E+01. Sample per second: 11687
# SLIM_BPR_Recommender: Epoch 321 of 650. Elapsed time 4.57 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 3.18E+01. Sample per second: 13047
# SLIM_BPR_Recommender: Epoch 322 of 650. Elapsed time 4.59 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 3.17E+01. Sample per second: 14994
# SLIM_BPR_Recommender: Epoch 323 of 650. Elapsed time 4.60 min
# Processed 13650 (100.0%) in 1.79 sec. BPR loss is 3.13E+01. Sample per second: 7614
# SLIM_BPR_Recommender: Epoch 324 of 650. Elapsed time 4.62 min
# Processed 13650 (100.0%) in 1.65 sec. BPR loss is 3.11E+01. Sample per second: 8285
# SLIM_BPR_Recommender: Epoch 325 of 650. Elapsed time 4.63 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 3.22E+01. Sample per second: 8953
# SLIM_BPR_Recommender: Epoch 326 of 650. Elapsed time 4.64 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 3.31E+01. Sample per second: 9836
# ...
# SLIM_BPR_Recommender: Epoch 542 of 650. Elapsed time 7.73 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 3.69E+01. Sample per second: 8172
# SLIM_BPR_Recommender: Epoch 543 of 650. Elapsed time 7.75 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 3.62E+01. Sample per second: 8764
# SLIM_BPR_Recommender: Epoch 544 of 650. Elapsed time 7.76 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 3.49E+01. Sample per second: 9442
# SLIM_BPR_Recommender: Epoch 545 of 650. Elapsed time 7.78 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 3.47E+01. Sample per second: 9884
# SLIM_BPR_Recommender: Epoch 546 of 650. Elapsed time 7.79 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 3.57E+01. Sample per second: 10609
# SLIM_BPR_Recommender: Epoch 547 of 650. Elapsed time 7.81 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 3.42E+01. Sample per second: 11468
# SLIM_BPR_Recommender: Epoch 548 of 650. Elapsed time 7.82 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 3.65E+01. Sample per second: 12810
# SLIM_BPR_Recommender: Epoch 549 of 650. Elapsed time 7.84 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 3.61E+01. Sample per second: 14435
# SLIM_BPR_Recommender: Epoch 550 of 650. Elapsed time 7.85 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 3.58E+01. Sample per second: 8203
# SLIM_BPR_Recommender: Epoch 551 of 650. Elapsed time 7.86 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 3.56E+01. Sample per second: 8942
# SLIM_BPR_Recommender: Epoch 552 of 650. Elapsed time 7.88 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 3.50E+01. Sample per second: 10569
# SLIM_BPR_Recommender: Epoch 553 of 650. Elapsed time 7.89 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 3.69E+01. Sample per second: 12451
# SLIM_BPR_Recommender: Epoch 554 of 650. Elapsed time 7.90 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 3.62E+01. Sample per second: 16761
# SLIM_BPR_Recommender: Epoch 555 of 650. Elapsed time 7.92 min
# Processed 13650 (100.0%) in 1.70 sec. BPR loss is 3.81E+01. Sample per second: 8050
# SLIM_BPR_Recommender: Epoch 556 of 650. Elapsed time 7.93 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 3.51E+01. Sample per second: 8637
# SLIM_BPR_Recommender: Epoch 557 of 650. Elapsed time 7.95 min
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 3.55E+01. Sample per second: 9214
# SLIM_BPR_Recommender: Epoch 558 of 650. Elapsed time 7.96 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 3.78E+01. Sample per second: 10489
# SLIM_BPR_Recommender: Epoch 559 of 650. Elapsed time 7.97 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 3.62E+01. Sample per second: 12807
# SLIM_BPR_Recommender: Epoch 560 of 650. Elapsed time 7.99 min
# Processed 13650 (100.0%) in 0.78 sec. BPR loss is 3.48E+01. Sample per second: 17388
# SLIM_BPR_Recommender: Epoch 561 of 650. Elapsed time 8.00 min
# Processed 13650 (100.0%) in 1.66 sec. BPR loss is 3.66E+01. Sample per second: 8210
# SLIM_BPR_Recommender: Epoch 562 of 650. Elapsed time 8.01 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 3.79E+01. Sample per second: 8915
# SLIM_BPR_Recommender: Epoch 563 of 650. Elapsed time 8.03 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 3.46E+01. Sample per second: 9771
# SLIM_BPR_Recommender: Epoch 564 of 650. Elapsed time 8.04 min
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 3.64E+01. Sample per second: 10808
# SLIM_BPR_Recommender: Epoch 565 of 650. Elapsed time 8.06 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 3.57E+01. Sample per second: 14225
# SLIM_BPR_Recommender: Epoch 566 of 650. Elapsed time 8.07 min
# Processed 13650 (100.0%) in 1.85 sec. BPR loss is 3.59E+01. Sample per second: 7376
# SLIM_BPR_Recommender: Epoch 567 of 650. Elapsed time 8.08 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 3.47E+01. Sample per second: 8573
# SLIM_BPR_Recommender: Epoch 568 of 650. Elapsed time 8.10 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 3.40E+01. Sample per second: 10717
# SLIM_BPR_Recommender: Epoch 569 of 650. Elapsed time 8.11 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 3.84E+01. Sample per second: 14030
# SLIM_BPR_Recommender: Epoch 570 of 650. Elapsed time 8.12 min
# Processed 13650 (100.0%) in 1.65 sec. BPR loss is 3.60E+01. Sample per second: 8269
# SLIM_BPR_Recommender: Epoch 571 of 650. Elapsed time 8.13 min
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 3.69E+01. Sample per second: 9632
# SLIM_BPR_Recommender: Epoch 572 of 650. Elapsed time 8.14 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 3.81E+01. Sample per second: 10572
# SLIM_BPR_Recommender: Epoch 573 of 650. Elapsed time 8.16 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 3.75E+01. Sample per second: 11622
# SLIM_BPR_Recommender: Epoch 574 of 650. Elapsed time 8.17 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 3.65E+01. Sample per second: 14985
# SLIM_BPR_Recommender: Epoch 575 of 650. Elapsed time 8.18 min
# Processed 13650 (100.0%) in 1.72 sec. BPR loss is 3.64E+01. Sample per second: 7932
# SLIM_BPR_Recommender: Epoch 576 of 650. Elapsed time 8.20 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 3.62E+01. Sample per second: 8555
# SLIM_BPR_Recommender: Epoch 577 of 650. Elapsed time 8.21 min
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 3.45E+01. Sample per second: 9192
# SLIM_BPR_Recommender: Epoch 578 of 650. Elapsed time 8.23 min
# Processed 13650 (100.0%) in 1.36 sec. BPR loss is 3.78E+01. Sample per second: 10023
# SLIM_BPR_Recommender: Epoch 579 of 650. Elapsed time 8.24 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 3.74E+01. Sample per second: 10954
# SLIM_BPR_Recommender: Epoch 580 of 650. Elapsed time 8.26 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 3.57E+01. Sample per second: 11960
# SLIM_BPR_Recommender: Epoch 581 of 650. Elapsed time 8.27 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 3.83E+01. Sample per second: 13250
# SLIM_BPR_Recommender: Epoch 582 of 650. Elapsed time 8.29 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 3.55E+01. Sample per second: 15312
# SLIM_BPR_Recommender: Epoch 583 of 650. Elapsed time 8.30 min
# Processed 13650 (100.0%) in 1.74 sec. BPR loss is 3.62E+01. Sample per second: 7819
# SLIM_BPR_Recommender: Epoch 584 of 650. Elapsed time 8.32 min
# Processed 13650 (100.0%) in 1.62 sec. BPR loss is 3.46E+01. Sample per second: 8437
# SLIM_BPR_Recommender: Epoch 585 of 650. Elapsed time 8.33 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 3.47E+01. Sample per second: 10235
# SLIM_BPR_Recommender: Epoch 586 of 650. Elapsed time 8.34 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 3.77E+01. Sample per second: 10587
# SLIM_BPR_Recommender: Epoch 587 of 650. Elapsed time 8.36 min
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 3.80E+01. Sample per second: 12856
# SLIM_BPR_Recommender: Epoch 588 of 650. Elapsed time 8.37 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 3.55E+01. Sample per second: 15764
# SLIM_BPR_Recommender: Epoch 589 of 650. Elapsed time 8.38 min
# Processed 13650 (100.0%) in 1.72 sec. BPR loss is 3.67E+01. Sample per second: 7946
# SLIM_BPR_Recommender: Epoch 590 of 650. Elapsed time 8.40 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 3.63E+01. Sample per second: 8651
# SLIM_BPR_Recommender: Epoch 591 of 650. Elapsed time 8.41 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 3.81E+01. Sample per second: 9419
# SLIM_BPR_Recommender: Epoch 592 of 650. Elapsed time 8.43 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 3.69E+01. Sample per second: 10400
# SLIM_BPR_Recommender: Epoch 593 of 650. Elapsed time 8.44 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 3.62E+01. Sample per second: 11827
# SLIM_BPR_Recommender: Epoch 594 of 650. Elapsed time 8.46 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 3.61E+01. Sample per second: 13529
# SLIM_BPR_Recommender: Epoch 595 of 650. Elapsed time 8.47 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 3.74E+01. Sample per second: 15680
# SLIM_BPR_Recommender: Epoch 596 of 650. Elapsed time 8.48 min
# Processed 13650 (100.0%) in 1.75 sec. BPR loss is 3.81E+01. Sample per second: 7800
# SLIM_BPR_Recommender: Epoch 597 of 650. Elapsed time 8.50 min
# Processed 13650 (100.0%) in 1.63 sec. BPR loss is 3.52E+01. Sample per second: 8370
# SLIM_BPR_Recommender: Epoch 598 of 650. Elapsed time 8.51 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 3.76E+01. Sample per second: 9014
# SLIM_BPR_Recommender: Epoch 599 of 650. Elapsed time 8.53 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 3.81E+01. Sample per second: 9692
# SLIM_BPR_Recommender: Epoch 600 of 650. Elapsed time 8.54 min
# Processed 13650 (100.0%) in 1.37 sec. BPR loss is 3.80E+01. Sample per second: 9928
# SLIM_BPR_Recommender: Epoch 601 of 650. Elapsed time 8.56 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 3.78E+01. Sample per second: 10477
# SLIM_BPR_Recommender: Epoch 602 of 650. Elapsed time 8.57 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 3.61E+01. Sample per second: 11327
# SLIM_BPR_Recommender: Epoch 603 of 650. Elapsed time 8.59 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 3.74E+01. Sample per second: 11905
# SLIM_BPR_Recommender: Epoch 604 of 650. Elapsed time 8.61 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 3.62E+01. Sample per second: 12721
# SLIM_BPR_Recommender: Epoch 605 of 650. Elapsed time 8.62 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 3.63E+01. Sample per second: 14096
# SLIM_BPR_Recommender: Epoch 606 of 650. Elapsed time 8.64 min
# Processed 13650 (100.0%) in 1.84 sec. BPR loss is 3.71E+01. Sample per second: 7418
# SLIM_BPR_Recommender: Epoch 607 of 650. Elapsed time 8.65 min
# Processed 13650 (100.0%) in 1.72 sec. BPR loss is 3.42E+01. Sample per second: 7958
# SLIM_BPR_Recommender: Epoch 608 of 650. Elapsed time 8.66 min
# Processed 13650 (100.0%) in 1.61 sec. BPR loss is 3.66E+01. Sample per second: 8490
# SLIM_BPR_Recommender: Epoch 609 of 650. Elapsed time 8.68 min
# Processed 13650 (100.0%) in 1.49 sec. BPR loss is 3.73E+01. Sample per second: 9168
# SLIM_BPR_Recommender: Epoch 610 of 650. Elapsed time 8.69 min
# Processed 13650 (100.0%) in 1.37 sec. BPR loss is 3.80E+01. Sample per second: 9991
# SLIM_BPR_Recommender: Epoch 611 of 650. Elapsed time 8.71 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 3.62E+01. Sample per second: 12006
# SLIM_BPR_Recommender: Epoch 612 of 650. Elapsed time 8.72 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 3.90E+01. Sample per second: 13026
# SLIM_BPR_Recommender: Epoch 613 of 650. Elapsed time 8.74 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 3.89E+01. Sample per second: 14844
# SLIM_BPR_Recommender: Epoch 614 of 650. Elapsed time 8.75 min
# Processed 13650 (100.0%) in 1.80 sec. BPR loss is 3.59E+01. Sample per second: 7595
# SLIM_BPR_Recommender: Epoch 615 of 650. Elapsed time 8.77 min
# Processed 13650 (100.0%) in 1.67 sec. BPR loss is 3.68E+01. Sample per second: 8164
# SLIM_BPR_Recommender: Epoch 616 of 650. Elapsed time 8.78 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 3.66E+01. Sample per second: 8889
# SLIM_BPR_Recommender: Epoch 617 of 650. Elapsed time 8.80 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 3.65E+01. Sample per second: 10420
# SLIM_BPR_Recommender: Epoch 618 of 650. Elapsed time 8.81 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 3.64E+01. Sample per second: 11628
# SLIM_BPR_Recommender: Epoch 619 of 650. Elapsed time 8.82 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 3.75E+01. Sample per second: 12968
# SLIM_BPR_Recommender: Epoch 620 of 650. Elapsed time 8.84 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 3.42E+01. Sample per second: 17875
# SLIM_BPR_Recommender: Epoch 621 of 650. Elapsed time 8.85 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 3.68E+01. Sample per second: 8786
# SLIM_BPR_Recommender: Epoch 622 of 650. Elapsed time 8.86 min
# Processed 13650 (100.0%) in 1.44 sec. BPR loss is 3.74E+01. Sample per second: 9507
# SLIM_BPR_Recommender: Epoch 623 of 650. Elapsed time 8.88 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 3.69E+01. Sample per second: 10403
# SLIM_BPR_Recommender: Epoch 624 of 650. Elapsed time 8.89 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 3.68E+01. Sample per second: 10749
# SLIM_BPR_Recommender: Epoch 625 of 650. Elapsed time 8.91 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 3.89E+01. Sample per second: 12588
# SLIM_BPR_Recommender: Epoch 626 of 650. Elapsed time 8.92 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 3.59E+01. Sample per second: 14278
# SLIM_BPR_Recommender: Epoch 627 of 650. Elapsed time 8.94 min
# Processed 13650 (100.0%) in 1.82 sec. BPR loss is 3.68E+01. Sample per second: 7495
# SLIM_BPR_Recommender: Epoch 628 of 650. Elapsed time 8.95 min
# Processed 13650 (100.0%) in 1.69 sec. BPR loss is 3.45E+01. Sample per second: 8069
# SLIM_BPR_Recommender: Epoch 629 of 650. Elapsed time 8.96 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 3.62E+01. Sample per second: 8813
# SLIM_BPR_Recommender: Epoch 630 of 650. Elapsed time 8.98 min
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 3.66E+01. Sample per second: 9635
# SLIM_BPR_Recommender: Epoch 631 of 650. Elapsed time 8.99 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 3.63E+01. Sample per second: 10495
# SLIM_BPR_Recommender: Epoch 632 of 650. Elapsed time 9.01 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 3.66E+01. Sample per second: 11680
# SLIM_BPR_Recommender: Epoch 633 of 650. Elapsed time 9.02 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 3.64E+01. Sample per second: 13255
# SLIM_BPR_Recommender: Epoch 634 of 650. Elapsed time 9.04 min
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 3.62E+01. Sample per second: 15534
# SLIM_BPR_Recommender: Epoch 635 of 650. Elapsed time 9.05 min
# Processed 13650 (100.0%) in 1.63 sec. BPR loss is 3.61E+01. Sample per second: 8370
# SLIM_BPR_Recommender: Epoch 636 of 650. Elapsed time 9.06 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 3.69E+01. Sample per second: 9113
# SLIM_BPR_Recommender: Epoch 637 of 650. Elapsed time 9.08 min
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 3.95E+01. Sample per second: 11161
# SLIM_BPR_Recommender: Epoch 638 of 650. Elapsed time 9.09 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 3.67E+01. Sample per second: 12762
# SLIM_BPR_Recommender: Epoch 639 of 650. Elapsed time 9.10 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 3.53E+01. Sample per second: 15741
# SLIM_BPR_Recommender: Epoch 640 of 650. Elapsed time 9.12 min
# Processed 13650 (100.0%) in 1.73 sec. BPR loss is 3.75E+01. Sample per second: 7896
# SLIM_BPR_Recommender: Epoch 641 of 650. Elapsed time 9.13 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 3.60E+01. Sample per second: 8574
# SLIM_BPR_Recommender: Epoch 642 of 650. Elapsed time 9.15 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 3.62E+01. Sample per second: 9427
# SLIM_BPR_Recommender: Epoch 643 of 650. Elapsed time 9.16 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 3.67E+01. Sample per second: 10300
# SLIM_BPR_Recommender: Epoch 644 of 650. Elapsed time 9.17 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 3.87E+01. Sample per second: 11527
# SLIM_BPR_Recommender: Epoch 645 of 650. Elapsed time 9.19 min
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 3.79E+01. Sample per second: 13099
# SLIM_BPR_Recommender: Epoch 646 of 650. Elapsed time 9.20 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 3.85E+01. Sample per second: 15154
# SLIM_BPR_Recommender: Epoch 647 of 650. Elapsed time 9.22 min
# Processed 13650 (100.0%) in 1.76 sec. BPR loss is 3.78E+01. Sample per second: 7767
# SLIM_BPR_Recommender: Epoch 648 of 650. Elapsed time 9.23 min
# Processed 13650 (100.0%) in 1.63 sec. BPR loss is 3.91E+01. Sample per second: 8385
# SLIM_BPR_Recommender: Epoch 649 of 650. Elapsed time 9.25 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 3.70E+01. Sample per second: 9062
# SLIM_BPR_Recommender: Epoch 650 of 650. Elapsed time 9.26 min
# SLIM_BPR_Recommender: Terminating at epoch 650. Elapsed time 9.70 min
# Deallocating Cython objects

# %%
from Recommenders.GraphBased.RP3betaRecommender import RP3betaRecommender
recommender_RP3beta = RP3betaRecommender(URM_all)
recommender_RP3beta.fit(alpha = 0.9902904484569759, beta = 0.5159273869398134, topK = 61, implicit = False)

# %%
# final hybrid recommender which combine all 3 models
recommender = DifferentLossScoresHybridRecommender(URM_all, recommender_SLIMElasticNet, recommender_SLIM_BPR_Cython, recommender_RP3beta)
recommender.fit(norm=1, alpha = 0.48, beta = 0.51)

# %%
test_users = pd.read_csv('../input/recommender-system-2021-challenge-polimi/data_target_users_test.csv')
test_users
# Out:
#        user_id
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 13645    13645
# 13646    13646
# 13647    13647
# 13648    13648
# 13649    13649
#
# [13650 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user,cutoff = 10))

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('submission.csv', index=False)
