# %%
# !cp -r ../input/d/romanofrancesco/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# %%
#load data_train, matrix of users interaction
URM_path = "../input/recommender-system-2021-challenge-polimi/data_train.csv"
URM_all_dataframe = pd.read_csv(filepath_or_buffer=URM_path, 
                                sep=",",
                                dtype={0:int, 1:int, 2:float},
                                header=0)
URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]

# %%
URM_all_dataframe.head()
# Out:
#    UserID  ItemID  Interaction
# 0       0      53          1.0
# 1       0     209          1.0
# 2       0     223          1.0
# 3       0     249          1.0
# 4       0     435          1.0

# %%
userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_all_dataframe)

print ("Number of items\t {}, Number of users\t {}".format(n_items, n_users))
print ("Max ID items\t {}, Max Id users\t {}\n".format(max(itemID_unique), max(userID_unique)))
print ("Average interactions per user {:.2f}".format(n_interactions/n_users))
print ("Average interactions per item {:.2f}\n".format(n_interactions/n_items))

print ("Sparsity {:.2f} %".format((1-float(n_interactions)/(n_items*n_users))*100))
# Out:
# Number of items	 18059, Number of users	 13650
# Max ID items	 18058, Max Id users	 13649
#
# Average interactions per user 387.23
# Average interactions per item 292.69
#
# Sparsity 97.86 %

# %%
URM_all = sps.coo_matrix((URM_all_dataframe["Interaction"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)
URM_all
# Out:
# <13650x18059 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5285664 stored elements in Compressed Sparse Row format>

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# split data into train and validation data 80/20
URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
from Recommenders.MatrixFactorization.IALSRecommender import IALSRecommender

#fit the IALS model tuned in previous experiments
mf_ials = IALSRecommender(URM_train)
mf_ials.fit(num_factors = 31,
            confidence_scaling= 'log',
            alpha = 0.0024941846820976015,
            epsilon = 3.449297756742473,
            reg = 5.61162089901928e-05,
            epochs = 40)
# Out:
# IALSRecommender: Epoch 1 of 40. Elapsed time 7.59 sec
# IALSRecommender: Epoch 2 of 40. Elapsed time 15.14 sec
# IALSRecommender: Epoch 3 of 40. Elapsed time 22.75 sec
# IALSRecommender: Epoch 4 of 40. Elapsed time 31.61 sec
# IALSRecommender: Epoch 5 of 40. Elapsed time 39.33 sec
# IALSRecommender: Epoch 6 of 40. Elapsed time 46.95 sec
# IALSRecommender: Epoch 7 of 40. Elapsed time 54.66 sec
# IALSRecommender: Epoch 8 of 40. Elapsed time 1.06 min
# IALSRecommender: Epoch 9 of 40. Elapsed time 1.18 min
# IALSRecommender: Epoch 10 of 40. Elapsed time 1.31 min
# IALSRecommender: Epoch 11 of 40. Elapsed time 1.44 min
# IALSRecommender: Epoch 12 of 40. Elapsed time 1.58 min
# IALSRecommender: Epoch 13 of 40. Elapsed time 1.71 min
# IALSRecommender: Epoch 14 of 40. Elapsed time 1.83 min
# IALSRecommender: Epoch 15 of 40. Elapsed time 1.96 min
# IALSRecommender: Epoch 16 of 40. Elapsed time 2.11 min
# IALSRecommender: Epoch 17 of 40. Elapsed time 2.23 min
# IALSRecommender: Epoch 18 of 40. Elapsed time 2.36 min
# IALSRecommender: Epoch 19 of 40. Elapsed time 2.48 min
# IALSRecommender: Epoch 20 of 40. Elapsed time 2.60 min
# IALSRecommender: Epoch 21 of 40. Elapsed time 2.75 min
# IALSRecommender: Epoch 22 of 40. Elapsed time 2.87 min
# IALSRecommender: Epoch 23 of 40. Elapsed time 2.99 min
# IALSRecommender: Epoch 24 of 40. Elapsed time 3.12 min
# IALSRecommender: Epoch 25 of 40. Elapsed time 3.27 min
# IALSRecommender: Epoch 26 of 40. Elapsed time 3.39 min
# IALSRecommender: Epoch 27 of 40. Elapsed time 3.52 min
# IALSRecommender: Epoch 28 of 40. Elapsed time 3.64 min
# IALSRecommender: Epoch 29 of 40. Elapsed time 3.79 min
# IALSRecommender: Epoch 30 of 40. Elapsed time 3.91 min
# IALSRecommender: Epoch 31 of 40. Elapsed time 4.04 min
# IALSRecommender: Epoch 32 of 40. Elapsed time 4.16 min
# IALSRecommender: Epoch 33 of 40. Elapsed time 4.31 min
# IALSRecommender: Epoch 34 of 40. Elapsed time 4.45 min
# IALSRecommender: Epoch 35 of 40. Elapsed time 4.57 min
# IALSRecommender: Epoch 36 of 40. Elapsed time 4.71 min
# IALSRecommender: Epoch 37 of 40. Elapsed time 4.85 min
# IALSRecommender: Epoch 38 of 40. Elapsed time 4.98 min
# IALSRecommender: Epoch 39 of 40. Elapsed time 5.10 min
# IALSRecommender: Epoch 40 of 40. Elapsed time 5.23 min
# IALSRecommender: Terminating at epoch 40. Elapsed time 5.23 min

# %%
#check evaluation on pure svd
evaluator_valid.evaluateRecommender(mf_ials)
# Out:
# EvaluatorHoldout: Processed 13646 (100.0%) in 15.36 sec. Users per second: 888
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#  cutoff
#  10      0.377327                 0.378693  0.065702  0.230622    0.231246
#
#               MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
#  cutoff                                                        ...
#  10      0.631976  0.392387  0.111917  0.963066       1.18543  ...
#
#         COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
#  cutoff
#  10                  0.039592      0.999707              0.962784
#
#         DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
#  cutoff
#  10           0.010426        7.930212                   0.993528
#
#         RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
#  cutoff
#  10                 0.042045              0.640038                 2.610212
#
#         RATIO_NOVELTY
#  cutoff
#  10          0.025974
#
#  [1 rows x 25 columns],
#  'CUTOFF: 10 - PRECISION: 0.3773267, PRECISION_RECALL_MIN_DEN: 0.3786935, RECALL: 0.0657020, MAP: 0.2306218, MAP_MIN_DEN: 0.2312455, MRR: 0.6319764, NDCG: 0.3923874, F1: 0.1119165, HIT_RATE: 0.9630661, ARHR_ALL_HITS: 1.1854303, NOVELTY: 0.0055205, AVERAGE_POPULARITY: 0.5306052, DIVERSITY_MEAN_INTER_LIST: 0.9315185, DIVERSITY_HERFINDAHL: 0.9931450, COVERAGE_ITEM: 0.0455175, COVERAGE_ITEM_CORRECT: 0.0395924, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9627839, DIVERSITY_GINI: 0.0104257, SHANNON_ENTROPY: 7.9302119, RATIO_DIVERSITY_HERFINDAHL: 0.9935284, RATIO_DIVERSITY_GINI: 0.0420450, RATIO_SHANNON_ENTROPY: 0.6400380, RATIO_AVERAGE_POPULARITY: 2.6102119, RATIO_NOVELTY: 0.0259740, \n')

# %%
#similarity_slimen = sps.load_npz("../input/slimen047/W_sparse.npz")
#similarity_slimen
#similarity_slimen_array = similarity_slimen['arr_0']

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
# create a Slim elasticnet object
slim_en = SLIMElasticNetRecommender(URM_train)
slim_en.fit(epochs = 500, l1_ratio = 0.0023170159712850467, alpha = 0.09078974149197175, positive_only = True, topK = 363)
# Out:
# SLIMElasticNetRecommender: Processed 1490 ( 8.3%) in 5.00 min. Items per second: 4.96
# SLIMElasticNetRecommender: Processed 2983 (16.5%) in 10.00 min. Items per second: 4.97
# SLIMElasticNetRecommender: Processed 4486 (24.8%) in 15.00 min. Items per second: 4.98
# SLIMElasticNetRecommender: Processed 5988 (33.2%) in 20.01 min. Items per second: 4.99
# SLIMElasticNetRecommender: Processed 7468 (41.4%) in 25.01 min. Items per second: 4.98
# SLIMElasticNetRecommender: Processed 8962 (49.6%) in 30.01 min. Items per second: 4.98
# SLIMElasticNetRecommender: Processed 10441 (57.8%) in 35.01 min. Items per second: 4.97
# SLIMElasticNetRecommender: Processed 11913 (66.0%) in 40.01 min. Items per second: 4.96
# SLIMElasticNetRecommender: Processed 13395 (74.2%) in 45.02 min. Items per second: 4.96
# SLIMElasticNetRecommender: Processed 14874 (82.4%) in 50.02 min. Items per second: 4.96
# SLIMElasticNetRecommender: Processed 16331 (90.4%) in 55.02 min. Items per second: 4.95
# SLIMElasticNetRecommender: Processed 17780 (98.5%) in 1.00 hour. Items per second: 4.94
# SLIMElasticNetRecommender: Processed 18059 (100.0%) in 1.02 hour. Items per second: 4.93

# %%
evaluator_valid.evaluateRecommender(slim_en)
# Out:
# EvaluatorHoldout: Processed 13646 (100.0%) in 26.93 sec. Users per second: 507
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
#  cutoff
#  10      0.399399                 0.401148  0.071367  0.247228    0.248054
#
#               MRR      NDCG        F1 HIT_RATE ARHR_ALL_HITS  ...  \
#  cutoff                                                       ...
#  10      0.645532  0.413152  0.121096  0.97208      1.240785  ...
#
#         COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
#  cutoff
#  10                  0.050944      0.999707              0.971795
#
#         DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
#  cutoff
#  10           0.010592         7.84549                   0.991782
#
#         RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
#  cutoff
#  10                 0.042715                0.6332                 2.675923
#
#         RATIO_NOVELTY
#  cutoff
#  10          0.025986
#
#  [1 rows x 25 columns],
#  'CUTOFF: 10 - PRECISION: 0.3993991, PRECISION_RECALL_MIN_DEN: 0.4011483, RECALL: 0.0713669, MAP: 0.2472278, MAP_MIN_DEN: 0.2480540, MRR: 0.6455320, NDCG: 0.4131520, F1: 0.1210957, HIT_RATE: 0.9720797, ARHR_ALL_HITS: 1.2407848, NOVELTY: 0.0055231, AVERAGE_POPULARITY: 0.5439629, DIVERSITY_MEAN_INTER_LIST: 0.9140581, DIVERSITY_HERFINDAHL: 0.9913991, COVERAGE_ITEM: 0.0732045, COVERAGE_ITEM_CORRECT: 0.0509441, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9717949, DIVERSITY_GINI: 0.0105917, SHANNON_ENTROPY: 7.8454901, RATIO_DIVERSITY_HERFINDAHL: 0.9917818, RATIO_DIVERSITY_GINI: 0.0427146, RATIO_SHANNON_ENTROPY: 0.6332002, RATIO_AVERAGE_POPULARITY: 2.6759227, RATIO_NOVELTY: 0.0259861, \n')

# %%
# explore scores differences between the two models
user_id= 50
item_scores_slim_en = slim_en._compute_item_score(user_id)
item_scores_slim_en
# Out:
# array([[0.00012783, 0.00076198, 0.00099631, ..., 0.        , 0.        ,
#         0.00071903]], dtype=float32)

# %%
item_scores_IALS = mf_ials._compute_item_score(user_id)
item_scores_IALS
# Out:
# array([-0.00183975, -0.00347735,  0.00030257, ...,  0.00323762,
#         0.00281395, -0.01231717])

# %%
# create a recommender object which performs the hybridation of the 2 models
from Recommenders.BaseRecommender import BaseRecommender

class ScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of two prediction scores R = R1*alpha + R2*(1-alpha)

    """

    RECOMMENDER_NAME = "ScoresHybridRecommender"

    def __init__(self, URM_train, recommender_1, recommender_2):
        super(ScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        
        
    def fit(self, alpha = 0.5):
        self.alpha = alpha      


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        # In a simple extension this could be a loop over a list of pretrained recommender objects
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        item_weights = item_weights_1*self.alpha + item_weights_2*(1-self.alpha)

        return item_weights

# %%
# grid search over different values of hyperparameter alpha

for alpha in np.arange(0,1,0.1):
    scoreshybridrecommender = ScoresHybridRecommender(URM_train, slim_en, mf_ials)
    scoreshybridrecommender.fit(alpha = alpha)
    print("Hybrid model with alpha weight:")
    print(alpha)
    print(evaluator_valid.evaluateRecommender(scoreshybridrecommender))
# Out:
# Hybrid model with alpha weight:
# 0.0
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.71 sec. Users per second: 475
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.377327                 0.378693  0.065702  0.230622    0.231246
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.631976  0.392387  0.111917  0.963066       1.18543  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.039592      0.999707              0.962784
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010426        7.930212                   0.993528
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.042045              0.640038                 2.610212
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025974
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3773267, PRECISION_RECALL_MIN_DEN: 0.3786935, RECALL: 0.0657020, MAP: 0.2306218, MAP_MIN_DEN: 0.2312455, MRR: 0.6319764, NDCG: 0.3923874, F1: 0.1119165, HIT_RATE: 0.9630661, ARHR_ALL_HITS: 1.1854303, NOVELTY: 0.0055205, AVERAGE_POPULARITY: 0.5306052, DIVERSITY_MEAN_INTER_LIST: 0.9315185, DIVERSITY_HERFINDAHL: 0.9931450, COVERAGE_ITEM: 0.0455175, COVERAGE_ITEM_CORRECT: 0.0395924, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9627839, DIVERSITY_GINI: 0.0104257, SHANNON_ENTROPY: 7.9302119, RATIO_DIVERSITY_HERFINDAHL: 0.9935284, RATIO_DIVERSITY_GINI: 0.0420450, RATIO_SHANNON_ENTROPY: 0.6400380, RATIO_AVERAGE_POPULARITY: 2.6102119, RATIO_NOVELTY: 0.0259740, \n')
# Hybrid model with alpha weight:
# 0.1
# EvaluatorHoldout: Processed 13646 (100.0%) in 29.00 sec. Users per second: 471
# (       PRECISION PRECISION_RECALL_MIN_DEN   RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10       0.38072                 0.382138  0.06656  0.233293    0.233942
#
#              MRR      NDCG       F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                       ...
# 10      0.634558  0.395719  0.11331  0.964605      1.194775  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.039592      0.999707              0.964322
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010276        7.904574                    0.99333
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                  0.04144              0.637969                 2.623592
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025957
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3807196, PRECISION_RECALL_MIN_DEN: 0.3821377, RECALL: 0.0665597, MAP: 0.2332931, MAP_MIN_DEN: 0.2339423, MRR: 0.6345584, NDCG: 0.3957193, F1: 0.1133099, HIT_RATE: 0.9646050, ARHR_ALL_HITS: 1.1947746, NOVELTY: 0.0055169, AVERAGE_POPULARITY: 0.5333251, DIVERSITY_MEAN_INTER_LIST: 0.9295359, DIVERSITY_HERFINDAHL: 0.9929468, COVERAGE_ITEM: 0.0461266, COVERAGE_ITEM_CORRECT: 0.0395924, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9643223, DIVERSITY_GINI: 0.0102756, SHANNON_ENTROPY: 7.9045738, RATIO_DIVERSITY_HERFINDAHL: 0.9933300, RATIO_DIVERSITY_GINI: 0.0414396, RATIO_SHANNON_ENTROPY: 0.6379688, RATIO_AVERAGE_POPULARITY: 2.6235920, RATIO_NOVELTY: 0.0259569, \n')
# Hybrid model with alpha weight:
# 0.2
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.86 sec. Users per second: 473
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.383497                 0.384988  0.067333  0.235798    0.236484
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.637967  0.398854  0.114553  0.966144      1.204571  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.039759      0.999707              0.965861
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010156        7.882226                   0.993128
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040959              0.636165                  2.63619
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025944
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3834970, PRECISION_RECALL_MIN_DEN: 0.3849885, RECALL: 0.0673332, MAP: 0.2357981, MAP_MIN_DEN: 0.2364844, MRR: 0.6379668, NDCG: 0.3988540, F1: 0.1145534, HIT_RATE: 0.9661439, ARHR_ALL_HITS: 1.2045713, NOVELTY: 0.0055142, AVERAGE_POPULARITY: 0.5358860, DIVERSITY_MEAN_INTER_LIST: 0.9275202, DIVERSITY_HERFINDAHL: 0.9927452, COVERAGE_ITEM: 0.0496705, COVERAGE_ITEM_CORRECT: 0.0397586, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9658608, DIVERSITY_GINI: 0.0101564, SHANNON_ENTROPY: 7.8822258, RATIO_DIVERSITY_HERFINDAHL: 0.9931284, RATIO_DIVERSITY_GINI: 0.0409591, RATIO_SHANNON_ENTROPY: 0.6361651, RATIO_AVERAGE_POPULARITY: 2.6361897, RATIO_NOVELTY: 0.0259441, \n')
# Hybrid model with alpha weight:
# 0.30000000000000004
# EvaluatorHoldout: Processed 13646 (100.0%) in 29.09 sec. Users per second: 469
# (       PRECISION PRECISION_RECALL_MIN_DEN   RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.387403                 0.388942  0.06823  0.238727    0.239442
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.640674  0.402468  0.116026  0.967536      1.214154  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.040534      0.999707              0.967253
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010074         7.86365                   0.992933
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040626              0.634666                 2.647128
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025934
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3874029, PRECISION_RECALL_MIN_DEN: 0.3889422, RECALL: 0.0682301, MAP: 0.2387270, MAP_MIN_DEN: 0.2394422, MRR: 0.6406736, NDCG: 0.4024680, F1: 0.1160256, HIT_RATE: 0.9675363, ARHR_ALL_HITS: 1.2141538, NOVELTY: 0.0055121, AVERAGE_POPULARITY: 0.5381095, DIVERSITY_MEAN_INTER_LIST: 0.9255704, DIVERSITY_HERFINDAHL: 0.9925503, COVERAGE_ITEM: 0.0522177, COVERAGE_ITEM_CORRECT: 0.0405338, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9672527, DIVERSITY_GINI: 0.0100738, SHANNON_ENTROPY: 7.8636501, RATIO_DIVERSITY_HERFINDAHL: 0.9929334, RATIO_DIVERSITY_GINI: 0.0406259, RATIO_SHANNON_ENTROPY: 0.6346659, RATIO_AVERAGE_POPULARITY: 2.6471277, RATIO_NOVELTY: 0.0259344, \n')
# Hybrid model with alpha weight:
# 0.4
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.93 sec. Users per second: 472
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.390723                 0.392349  0.069035  0.241074     0.24182
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.642334  0.405387  0.117338  0.968416      1.221308  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.041143      0.999707              0.968132
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010011        7.847017                    0.99274
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040372              0.633323                 2.657161
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025927
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3907226, PRECISION_RECALL_MIN_DEN: 0.3923491, RECALL: 0.0690349, MAP: 0.2410742, MAP_MIN_DEN: 0.2418204, MRR: 0.6423342, NDCG: 0.4053867, F1: 0.1173380, HIT_RATE: 0.9684157, ARHR_ALL_HITS: 1.2213078, NOVELTY: 0.0055105, AVERAGE_POPULARITY: 0.5401491, DIVERSITY_MEAN_INTER_LIST: 0.9236352, DIVERSITY_HERFINDAHL: 0.9923568, COVERAGE_ITEM: 0.0549311, COVERAGE_ITEM_CORRECT: 0.0411429, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9681319, DIVERSITY_GINI: 0.0100109, SHANNON_ENTROPY: 7.8470175, RATIO_DIVERSITY_HERFINDAHL: 0.9927398, RATIO_DIVERSITY_GINI: 0.0403722, RATIO_SHANNON_ENTROPY: 0.6333235, RATIO_AVERAGE_POPULARITY: 2.6571612, RATIO_NOVELTY: 0.0259267, \n')
# Hybrid model with alpha weight:
# 0.5
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.60 sec. Users per second: 477
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.393822                 0.395488  0.069641  0.243372    0.244172
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.643962  0.408204  0.118353  0.969588      1.228508  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.042472      0.999707              0.969304
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.009986        7.833323                   0.992532
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040271              0.632218                 2.666535
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025922
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3938224, PRECISION_RECALL_MIN_DEN: 0.3954878, RECALL: 0.0696410, MAP: 0.2433724, MAP_MIN_DEN: 0.2441719, MRR: 0.6439621, NDCG: 0.4082039, F1: 0.1183532, HIT_RATE: 0.9695882, ARHR_ALL_HITS: 1.2285076, NOVELTY: 0.0055095, AVERAGE_POPULARITY: 0.5420546, DIVERSITY_MEAN_INTER_LIST: 0.9215541, DIVERSITY_HERFINDAHL: 0.9921487, COVERAGE_ITEM: 0.0567030, COVERAGE_ITEM_CORRECT: 0.0424719, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9693040, DIVERSITY_GINI: 0.0099859, SHANNON_ENTROPY: 7.8333228, RATIO_DIVERSITY_HERFINDAHL: 0.9925316, RATIO_DIVERSITY_GINI: 0.0402713, RATIO_SHANNON_ENTROPY: 0.6322182, RATIO_AVERAGE_POPULARITY: 2.6665350, RATIO_NOVELTY: 0.0259220, \n')
# Hybrid model with alpha weight:
# 0.6000000000000001
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.44 sec. Users per second: 480
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.395566                 0.397257  0.070192  0.244818    0.245625
#
#              MRR      NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                        ...
# 10      0.644317  0.409839  0.119228  0.970687      1.232699  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.043746      0.999707              0.970403
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.009993        7.823294                   0.992336
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040301              0.631409                 2.673605
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025923
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3955665, PRECISION_RECALL_MIN_DEN: 0.3972568, RECALL: 0.0701922, MAP: 0.2448184, MAP_MIN_DEN: 0.2456252, MRR: 0.6443168, NDCG: 0.4098391, F1: 0.1192278, HIT_RATE: 0.9706874, ARHR_ALL_HITS: 1.2326992, NOVELTY: 0.0055097, AVERAGE_POPULARITY: 0.5434918, DIVERSITY_MEAN_INTER_LIST: 0.9195977, DIVERSITY_HERFINDAHL: 0.9919530, COVERAGE_ITEM: 0.0593056, COVERAGE_ITEM_CORRECT: 0.0437455, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9704029, DIVERSITY_GINI: 0.0099933, SHANNON_ENTROPY: 7.8232941, RATIO_DIVERSITY_HERFINDAHL: 0.9923359, RATIO_DIVERSITY_GINI: 0.0403014, RATIO_SHANNON_ENTROPY: 0.6314088, RATIO_AVERAGE_POPULARITY: 2.6736051, RATIO_NOVELTY: 0.0259229, \n')
# Hybrid model with alpha weight:
# 0.7000000000000001
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.33 sec. Users per second: 482
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10       0.39764                 0.399328  0.070612  0.246313    0.247133
#
#              MRR    NDCG        F1  HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                      ...
# 10      0.645665  0.4117  0.119927  0.970541      1.237598  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.044853      0.999707              0.970256
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010054        7.818309                   0.992144
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040545              0.631006                 2.678803
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025929
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3976403, PRECISION_RECALL_MIN_DEN: 0.3993281, RECALL: 0.0706115, MAP: 0.2463134, MAP_MIN_DEN: 0.2471330, MRR: 0.6456646, NDCG: 0.4116996, F1: 0.1199268, HIT_RATE: 0.9705408, ARHR_ALL_HITS: 1.2375984, NOVELTY: 0.0055110, AVERAGE_POPULARITY: 0.5445485, DIVERSITY_MEAN_INTER_LIST: 0.9176784, DIVERSITY_HERFINDAHL: 0.9917611, COVERAGE_ITEM: 0.0626281, COVERAGE_ITEM_CORRECT: 0.0448530, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9702564, DIVERSITY_GINI: 0.0100537, SHANNON_ENTROPY: 7.8183089, RATIO_DIVERSITY_HERFINDAHL: 0.9921439, RATIO_DIVERSITY_GINI: 0.0405449, RATIO_SHANNON_ENTROPY: 0.6310064, RATIO_AVERAGE_POPULARITY: 2.6788031, RATIO_NOVELTY: 0.0259292, \n')
# Hybrid model with alpha weight:
# 0.8
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.43 sec. Users per second: 480
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.398776                 0.400509  0.070976  0.247106    0.247954
#
#             MRR      NDCG        F1 HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                      ...
# 10      0.64686  0.412867  0.120505  0.97142      1.240896  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.046957      0.999707              0.971136
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010164        7.818539                   0.991971
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.040989              0.631025                 2.682101
#
#        RATIO_NOVELTY
# cutoff
# 10           0.02594
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3987762, PRECISION_RECALL_MIN_DEN: 0.4005094, RECALL: 0.0709765, MAP: 0.2471063, MAP_MIN_DEN: 0.2479542, MRR: 0.6468598, NDCG: 0.4128673, F1: 0.1205048, HIT_RATE: 0.9714202, ARHR_ALL_HITS: 1.2408956, NOVELTY: 0.0055134, AVERAGE_POPULARITY: 0.5452189, DIVERSITY_MEAN_INTER_LIST: 0.9159503, DIVERSITY_HERFINDAHL: 0.9915883, COVERAGE_ITEM: 0.0658951, COVERAGE_ITEM_CORRECT: 0.0469572, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9711355, DIVERSITY_GINI: 0.0101638, SHANNON_ENTROPY: 7.8185389, RATIO_DIVERSITY_HERFINDAHL: 0.9919710, RATIO_DIVERSITY_GINI: 0.0409890, RATIO_SHANNON_ENTROPY: 0.6310250, RATIO_AVERAGE_POPULARITY: 2.6821011, RATIO_NOVELTY: 0.0259402, \n')
# Hybrid model with alpha weight:
# 0.9
# EvaluatorHoldout: Processed 13646 (100.0%) in 28.31 sec. Users per second: 482
# (       PRECISION PRECISION_RECALL_MIN_DEN    RECALL       MAP MAP_MIN_DEN  \
# cutoff
# 10      0.399333                 0.401073  0.071208  0.247371    0.248219
#
#              MRR    NDCG        F1 HIT_RATE ARHR_ALL_HITS  ...  \
# cutoff                                                     ...
# 10      0.646054  0.4132  0.120864  0.97186      1.241173  ...
#
#        COVERAGE_ITEM_CORRECT COVERAGE_USER COVERAGE_USER_CORRECT  \
# cutoff
# 10                  0.049006      0.999707              0.971575
#
#        DIVERSITY_GINI SHANNON_ENTROPY RATIO_DIVERSITY_HERFINDAHL  \
# cutoff
# 10           0.010335        7.826976                   0.991848
#
#        RATIO_DIVERSITY_GINI RATIO_SHANNON_ENTROPY RATIO_AVERAGE_POPULARITY  \
# cutoff
# 10                 0.041679              0.631706                 2.681237
#
#        RATIO_NOVELTY
# cutoff
# 10          0.025959
#
# [1 rows x 25 columns], 'CUTOFF: 10 - PRECISION: 0.3993331, PRECISION_RECALL_MIN_DEN: 0.4010726, RECALL: 0.0712080, MAP: 0.2473706, MAP_MIN_DEN: 0.2482187, MRR: 0.6460545, NDCG: 0.4132005, F1: 0.1208638, HIT_RATE: 0.9718599, ARHR_ALL_HITS: 1.2411733, NOVELTY: 0.0055173, AVERAGE_POPULARITY: 0.5450433, DIVERSITY_MEAN_INTER_LIST: 0.9147212, DIVERSITY_HERFINDAHL: 0.9914654, COVERAGE_ITEM: 0.0689407, COVERAGE_ITEM_CORRECT: 0.0490060, COVERAGE_USER: 0.9997070, COVERAGE_USER_CORRECT: 0.9715751, DIVERSITY_GINI: 0.0103349, SHANNON_ENTROPY: 7.8269761, RATIO_DIVERSITY_HERFINDAHL: 0.9918481, RATIO_DIVERSITY_GINI: 0.0416789, RATIO_SHANNON_ENTROPY: 0.6317060, RATIO_AVERAGE_POPULARITY: 2.6812374, RATIO_NOVELTY: 0.0259586, \n')

# %% [markdown]
# LET'S TRY TO NORMALIZE SCORES

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of two prediction scores R = R1/norm*alpha + R2/norm*(1-alpha) where R1 and R2 come from
    algorithms trained on different loss functions.

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        
        
        
    def fit(self, norm, alpha = 0.5):

        self.alpha = alpha
        self.norm = norm


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        
        
        if norm_item_weights_1 == 0:
            raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
        
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * (1-self.alpha)

        return item_weights

# %%
recommender_object = DifferentLossScoresHybridRecommender(URM_train, slim_en, mf_ials)

best_model = {
    "MAP" : 0,
    "alpha" : 0,
    "norm" : 0
}

for norm in [1, 2]:
    for alpha in np.arange(0,1,0.1):
        print("----")
        recommender_object.fit(norm, alpha)

        result_df, _ = evaluator_valid.evaluateRecommender(recommender_object)
        print("Norm: {}, Alpha: {}, Result: {}".format(norm, alpha, result_df.loc[10]["MAP"]))

        if result_df.loc[10]["MAP"] > best_model["MAP"]:
            best_model["MAP"] = result_df.loc[10]["MAP"]
            best_model["alpha"] = alpha
            best_model["norm"] = norm
print("----")
print("Best model has MAP: {} with alpha: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["norm"]))
# Out:
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.22 sec. Users per second: 437
# Norm: 1, Alpha: 0.0, Result: 0.2306217561283151
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 32.09 sec. Users per second: 425
# Norm: 1, Alpha: 0.1, Result: 0.23354907479137998
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 32.00 sec. Users per second: 426
# Norm: 1, Alpha: 0.2, Result: 0.23613324388331675
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.40 sec. Users per second: 435
# Norm: 1, Alpha: 0.30000000000000004, Result: 0.23912988921691034
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.57 sec. Users per second: 432
# Norm: 1, Alpha: 0.4, Result: 0.241609751331282
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.91 sec. Users per second: 428
# Norm: 1, Alpha: 0.5, Result: 0.243610805771328
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 32.02 sec. Users per second: 426
# Norm: 1, Alpha: 0.6000000000000001, Result: 0.2449699981854091
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.49 sec. Users per second: 433
# Norm: 1, Alpha: 0.7000000000000001, Result: 0.24660421741123179
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.57 sec. Users per second: 432
# Norm: 1, Alpha: 0.8, Result: 0.24718065529988434
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 31.59 sec. Users per second: 432
# Norm: 1, Alpha: 0.9, Result: 0.24735608609069756
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.55 min. Users per second: 89
# Norm: 2, Alpha: 0.0, Result: 0.2306217561283151
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.48 min. Users per second: 92
# Norm: 2, Alpha: 0.1, Result: 0.23333855900560396
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.45 min. Users per second: 93
# Norm: 2, Alpha: 0.2, Result: 0.23589002766087597
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.51 min. Users per second: 91
# Norm: 2, Alpha: 0.30000000000000004, Result: 0.23879997976033365
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.51 min. Users per second: 91
# Norm: 2, Alpha: 0.4, Result: 0.24117314161484638
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.45 min. Users per second: 93
# Norm: 2, Alpha: 0.5, Result: 0.2434139314038181
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.51 min. Users per second: 91
# Norm: 2, Alpha: 0.6000000000000001, Result: 0.24492164108791678
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.57 min. Users per second: 88
# Norm: 2, Alpha: 0.7000000000000001, Result: 0.2463843902161006
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.65 min. Users per second: 86
# Norm: 2, Alpha: 0.8, Result: 0.24719153121212395
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.67 min. Users per second: 85
# Norm: 2, Alpha: 0.9, Result: 0.24737055338037323
# ----
# Best model has MAP: 0.24737055338037323 with alpha: 0.9, norm: 2

# %%
recommender_object = DifferentLossScoresHybridRecommender(URM_train, slim_en, mf_ials)

best_model = {
    "MAP" : 0,
    "alpha" : 0,
    "norm" : 0
}

for norm in [2]:
    for alpha in np.arange(0.85,0.95,0.01):
        print("----")
        recommender_object.fit(norm, alpha)

        result_df, _ = evaluator_valid.evaluateRecommender(recommender_object)
        print("Norm: {}, Alpha: {}, Result: {}".format(norm, alpha, result_df.loc[10]["MAP"]))

        if result_df.loc[10]["MAP"] > best_model["MAP"]:
            best_model["MAP"] = result_df.loc[10]["MAP"]
            best_model["alpha"] = alpha
            best_model["norm"] = norm
print("----")
print("Best model has MAP: {} with alpha: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["norm"]))
# Out:
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.56 min. Users per second: 89
# Norm: 2, Alpha: 0.85, Result: 0.24742979802209672
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.55 min. Users per second: 89
# Norm: 2, Alpha: 0.86, Result: 0.2473542424200131
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.53 min. Users per second: 90
# Norm: 2, Alpha: 0.87, Result: 0.24726825582937406
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.53 min. Users per second: 90
# Norm: 2, Alpha: 0.88, Result: 0.2473814380166071
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.56 min. Users per second: 89
# Norm: 2, Alpha: 0.89, Result: 0.24733452328608485
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.75 min. Users per second: 83
# Norm: 2, Alpha: 0.9, Result: 0.24737055338037323
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.53 min. Users per second: 90
# Norm: 2, Alpha: 0.91, Result: 0.24745395185286087
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.57 min. Users per second: 88
# Norm: 2, Alpha: 0.92, Result: 0.2474536901330473
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.50 min. Users per second: 91
# Norm: 2, Alpha: 0.93, Result: 0.24733517758561754
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 2.55 min. Users per second: 89
# Norm: 2, Alpha: 0.9400000000000001, Result: 0.24734152283708938
# ----
# Best model has MAP: 0.24745395185286087 with alpha: 0.91, norm: 2

# %%
#fit the IALS model with URM_all
mf_ials_all = IALSRecommender(URM_all)
mf_ials_all.fit(num_factors = 31,
            confidence_scaling= 'log',
            alpha = 0.0024941846820976015,
            epsilon = 3.449297756742473,
            reg = 5.61162089901928e-05,
            epochs = 40)
# Out:
# IALSRecommender: Epoch 1 of 40. Elapsed time 8.24 sec
# IALSRecommender: Epoch 2 of 40. Elapsed time 17.71 sec
# IALSRecommender: Epoch 3 of 40. Elapsed time 25.92 sec
# IALSRecommender: Epoch 4 of 40. Elapsed time 34.34 sec
# IALSRecommender: Epoch 5 of 40. Elapsed time 42.79 sec
# IALSRecommender: Epoch 6 of 40. Elapsed time 52.44 sec
# IALSRecommender: Epoch 7 of 40. Elapsed time 1.01 min
# IALSRecommender: Epoch 8 of 40. Elapsed time 1.15 min
# IALSRecommender: Epoch 9 of 40. Elapsed time 1.29 min
# IALSRecommender: Epoch 10 of 40. Elapsed time 1.45 min
# IALSRecommender: Epoch 11 of 40. Elapsed time 1.59 min
# IALSRecommender: Epoch 12 of 40. Elapsed time 1.73 min
# IALSRecommender: Epoch 13 of 40. Elapsed time 1.87 min
# IALSRecommender: Epoch 14 of 40. Elapsed time 2.03 min
# IALSRecommender: Epoch 15 of 40. Elapsed time 2.16 min
# IALSRecommender: Epoch 16 of 40. Elapsed time 2.29 min
# IALSRecommender: Epoch 17 of 40. Elapsed time 2.43 min
# IALSRecommender: Epoch 18 of 40. Elapsed time 2.59 min
# IALSRecommender: Epoch 19 of 40. Elapsed time 2.74 min
# IALSRecommender: Epoch 20 of 40. Elapsed time 2.88 min
# IALSRecommender: Epoch 21 of 40. Elapsed time 3.04 min
# IALSRecommender: Epoch 22 of 40. Elapsed time 3.17 min
# IALSRecommender: Epoch 23 of 40. Elapsed time 3.31 min
# IALSRecommender: Epoch 24 of 40. Elapsed time 3.45 min
# IALSRecommender: Epoch 25 of 40. Elapsed time 3.60 min
# IALSRecommender: Epoch 26 of 40. Elapsed time 3.74 min
# IALSRecommender: Epoch 27 of 40. Elapsed time 3.88 min
# IALSRecommender: Epoch 28 of 40. Elapsed time 4.02 min
# IALSRecommender: Epoch 29 of 40. Elapsed time 4.19 min
# IALSRecommender: Epoch 30 of 40. Elapsed time 4.32 min
# IALSRecommender: Epoch 31 of 40. Elapsed time 4.46 min
# IALSRecommender: Epoch 32 of 40. Elapsed time 4.60 min
# IALSRecommender: Epoch 33 of 40. Elapsed time 4.76 min
# IALSRecommender: Epoch 34 of 40. Elapsed time 4.89 min
# IALSRecommender: Epoch 35 of 40. Elapsed time 5.02 min
# IALSRecommender: Epoch 36 of 40. Elapsed time 5.16 min
# IALSRecommender: Epoch 37 of 40. Elapsed time 5.32 min
# IALSRecommender: Epoch 38 of 40. Elapsed time 5.45 min
# IALSRecommender: Epoch 39 of 40. Elapsed time 5.58 min
# IALSRecommender: Epoch 40 of 40. Elapsed time 5.72 min
# IALSRecommender: Terminating at epoch 40. Elapsed time 5.72 min

# %%
# create a Slim elasticnet trained with URM_all
slim_en_all = SLIMElasticNetRecommender(URM_all)
slim_en_all.fit(epochs = 500, l1_ratio = 0.0023170159712850467, alpha = 0.09078974149197175, positive_only = True, topK = 363)
# Out:
# SLIMElasticNetRecommender: Processed 1140 ( 6.3%) in 5.00 min. Items per second: 3.80
# SLIMElasticNetRecommender: Processed 2285 (12.7%) in 10.00 min. Items per second: 3.81
# SLIMElasticNetRecommender: Processed 3439 (19.0%) in 15.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 4582 (25.4%) in 20.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 5728 (31.7%) in 25.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 6874 (38.1%) in 30.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 8017 (44.4%) in 35.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 9168 (50.8%) in 40.01 min. Items per second: 3.82
# SLIMElasticNetRecommender: Processed 10303 (57.1%) in 45.02 min. Items per second: 3.81
# SLIMElasticNetRecommender: Processed 11439 (63.3%) in 50.02 min. Items per second: 3.81
# SLIMElasticNetRecommender: Processed 12566 (69.6%) in 55.02 min. Items per second: 3.81
# SLIMElasticNetRecommender: Processed 13650 (75.6%) in 1.00 hour. Items per second: 3.79
# SLIMElasticNetRecommender: Processed 14719 (81.5%) in 1.08 hour. Items per second: 3.77
# SLIMElasticNetRecommender: Processed 15806 (87.5%) in 1.17 hour. Items per second: 3.76
# SLIMElasticNetRecommender: Processed 16874 (93.4%) in 1.25 hour. Items per second: 3.75
# SLIMElasticNetRecommender: Processed 17956 (99.4%) in 1.33 hour. Items per second: 3.74
# SLIMElasticNetRecommender: Processed 18059 (100.0%) in 1.34 hour. Items per second: 3.74

# %%
recommender = DifferentLossScoresHybridRecommender(URM_all, slim_en_all, mf_ials_all)
recommender.fit(norm=2 , alpha=0.91)

# %% [markdown]
# # Create final recommendations

# %%
#let's use the hybrid model for final recommandations with the alpha tuned (NO NORMALIZATION)

#recommender = ScoresHybridRecommender(URM_all, slim_en, mf_ials)
#recommender.fit(alpha = 0.7924)
#evaluator_valid.evaluateRecommender(recommender)

# %%
test_users = pd.read_csv('../input/recommender-system-2021-challenge-polimi/data_target_users_test.csv')
test_users
# Out:
#        user_id
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 13645    13645
# 13646    13646
# 13647    13647
# 13648    13648
# 13649    13649
#
# [13650 rows x 1 columns]

# %%
user_id = test_users['user_id']
recommendations = []
for user in user_id:
    recommendations.append(recommender.recommend(user,cutoff = 10))

# %%
for index in range(len(recommendations)):
    recommendations[index]=np.array(recommendations[index])
    
test_users['item_list']= recommendations
test_users['item_list'] = pd.DataFrame([str(line).strip('[').strip(']').replace("'","") for line in test_users['item_list']])
test_users.to_csv('submission.csv', index=False)
