# %%
# !cp -r ../input/recsys-repo/RecSys_Course_AT_PoliMi-master/* ./

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import scipy.sparse as sps
import matplotlib.pyplot as pyplot
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_path = "../input/recommender-system-2021-challenge-polimi/data_train.csv"
URM_all_dataframe = pd.read_csv(filepath_or_buffer=URM_path, 
                                sep=",",
                                dtype={0:int, 1:int, 2:float},
                                header=0)
URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]

userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_all_dataframe)

URM_all = sps.coo_matrix((URM_all_dataframe["Interaction"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values)))
URM_all = URM_all.tocsr() # to obtain fast access to rows (users)

# %%
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

# split data into train and validation data 80/20
URM_train, URM_valid = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.80)
# Out:
# Warning: 4 (0.03 %) of 13650 users have no sampled items

# %%
from Evaluation.Evaluator import EvaluatorHoldout

#create an evaluator object to evaluate validation set
#we will use it for hyperparameter tuning
evaluator_valid = EvaluatorHoldout(URM_valid, cutoff_list=[10])
# Out:
# EvaluatorHoldout: Ignoring 13646 ( 0.0%) Users that have less than 1 test interactions

# %%
import numpy as np
import scipy.sparse as sps
from Recommenders.Recommender_utils import check_matrix
from sklearn.linear_model import ElasticNet
from Recommenders.BaseSimilarityMatrixRecommender import BaseItemSimilarityMatrixRecommender
from Utils.seconds_to_biggest_unit import seconds_to_biggest_unit
import time, sys
from tqdm import tqdm
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# os.environ["PYTHONWARNINGS"] = ('ignore::exceptions.ConvergenceWarning:sklearn.linear_model')
# os.environ["PYTHONWARNINGS"] = ('ignore:Objective did not converge:ConvergenceWarning:')

class SLIMElasticNetRecommender(BaseItemSimilarityMatrixRecommender):
    """
    Train a Sparse Linear Methods (SLIM) item similarity model.
    NOTE: ElasticNet solver is parallel, a single intance of SLIM_ElasticNet will
          make use of half the cores available
    See:
        Efficient Top-N Recommendation by Linear Regression,
        M. Levy and K. Jack, LSRS workshop at RecSys 2013.
        SLIM: Sparse linear methods for top-n recommender systems,
        X. Ning and G. Karypis, ICDM 2011.
        http://glaros.dtc.umn.edu/gkhome/fetch/papers/SLIM2011icdm.pdf
    """

    RECOMMENDER_NAME = "SLIMElasticNetRecommender"

    def __init__(self, URM_train, verbose = True):
        super(SLIMElasticNetRecommender, self).__init__(URM_train, verbose = verbose)

    @ignore_warnings(category=ConvergenceWarning)
    def fit(self, l1_ratio=0.1, alpha = 1.0, positive_only=True, topK = 100,**earlystopping_kwargs):

        assert l1_ratio>= 0 and l1_ratio<=1, "{}: l1_ratio must be between 0 and 1, provided value was {}".format(self.RECOMMENDER_NAME, l1_ratio)

        self.l1_ratio = l1_ratio
        self.positive_only = positive_only
        self.topK = topK


        # initialize the ElasticNet model
        self.model = ElasticNet(alpha=alpha,
                                l1_ratio=self.l1_ratio,
                                positive=self.positive_only,
                                fit_intercept=False,
                                copy_X=False,
                                precompute=True,
                                selection='random',
                                max_iter=100,
                                tol=1e-4)

        URM_train = check_matrix(self.URM_train, 'csc', dtype=np.float32)

        n_items = URM_train.shape[1]

        # Use array as it reduces memory requirements compared to lists
        dataBlock = 10000000

        rows = np.zeros(dataBlock, dtype=np.int32)
        cols = np.zeros(dataBlock, dtype=np.int32)
        values = np.zeros(dataBlock, dtype=np.float32)

        numCells = 0

        start_time = time.time()
        start_time_printBatch = start_time

        # fit each item's factors sequentially (not in parallel)
        for currentItem in range(n_items):

            # get the target column
            y = URM_train[:, currentItem].toarray()

            # set the j-th column of X to zero
            start_pos = URM_train.indptr[currentItem]
            end_pos = URM_train.indptr[currentItem + 1]

            current_item_data_backup = URM_train.data[start_pos: end_pos].copy()
            URM_train.data[start_pos: end_pos] = 0.0

            # fit one ElasticNet model per column
            self.model.fit(URM_train, y)

            # self.model.coef_ contains the coefficient of the ElasticNet model
            # let's keep only the non-zero values

            # Select topK values
            # Sorting is done in three steps. Faster then plain np.argsort for higher number of items
            # - Partition the data to extract the set of relevant items
            # - Sort only the relevant items
            # - Get the original item index

            nonzero_model_coef_index = self.model.sparse_coef_.indices
            nonzero_model_coef_value = self.model.sparse_coef_.data

            local_topK = min(len(nonzero_model_coef_value)-1, self.topK)

            relevant_items_partition = (-nonzero_model_coef_value).argpartition(local_topK)[0:local_topK]
            relevant_items_partition_sorting = np.argsort(-nonzero_model_coef_value[relevant_items_partition])
            ranking = relevant_items_partition[relevant_items_partition_sorting]

            for index in range(len(ranking)):

                if numCells == len(rows):
                    rows = np.concatenate((rows, np.zeros(dataBlock, dtype=np.int32)))
                    cols = np.concatenate((cols, np.zeros(dataBlock, dtype=np.int32)))
                    values = np.concatenate((values, np.zeros(dataBlock, dtype=np.float32)))


                rows[numCells] = nonzero_model_coef_index[ranking[index]]
                cols[numCells] = currentItem
                values[numCells] = nonzero_model_coef_value[ranking[index]]

                numCells += 1

            # finally, replace the original values of the j-th column
            URM_train.data[start_pos:end_pos] = current_item_data_backup

            elapsed_time = time.time() - start_time
            new_time_value, new_time_unit = seconds_to_biggest_unit(elapsed_time)


            if time.time() - start_time_printBatch > 300 or currentItem == n_items-1:
                self._print("Processed {} ({:4.1f}%) in {:.2f} {}. Items per second: {:.2f}".format(
                    currentItem+1,
                    100.0* float(currentItem+1)/n_items,
                    new_time_value,
                    new_time_unit,
                    float(currentItem)/elapsed_time))

                sys.stdout.flush()
                sys.stderr.flush()

                start_time_printBatch = time.time()

        # generate the sparse weight matrix
        self.W_sparse = sps.csr_matrix((values[:numCells], (rows[:numCells], cols[:numCells])),
                                       shape=(n_items, n_items), dtype=np.float32)

# %%
recommender_SLIMElasticNet = SLIMElasticNetRecommender(URM_train)
recommender_SLIMElasticNet.fit(l1_ratio = 0.004529437143089812, alpha = 0.0647636014497447, positive_only = True, topK = 332)
# Out:
# SLIMElasticNetRecommender: Processed 1584 ( 8.8%) in 5.00 min. Items per second: 5.28
# SLIMElasticNetRecommender: Processed 3200 (17.7%) in 10.00 min. Items per second: 5.33
# SLIMElasticNetRecommender: Processed 4806 (26.6%) in 15.00 min. Items per second: 5.34
# SLIMElasticNetRecommender: Processed 6367 (35.3%) in 20.01 min. Items per second: 5.30
# SLIMElasticNetRecommender: Processed 7943 (44.0%) in 25.01 min. Items per second: 5.29
# SLIMElasticNetRecommender: Processed 9521 (52.7%) in 30.01 min. Items per second: 5.29
# SLIMElasticNetRecommender: Processed 11123 (61.6%) in 35.01 min. Items per second: 5.29
# SLIMElasticNetRecommender: Processed 12748 (70.6%) in 40.01 min. Items per second: 5.31
# SLIMElasticNetRecommender: Processed 14390 (79.7%) in 45.02 min. Items per second: 5.33
# SLIMElasticNetRecommender: Processed 16025 (88.7%) in 50.02 min. Items per second: 5.34
# SLIMElasticNetRecommender: Processed 17575 (97.3%) in 55.02 min. Items per second: 5.32
# SLIMElasticNetRecommender: Processed 18059 (100.0%) in 56.58 min. Items per second: 5.32

# %%
import pyximport
pyximport.install()
# !python run_compile_all_cython.py
# Out:
# run_compile_all_cython: Found 10 Cython files in 4 folders...
# run_compile_all_cython: All files will be compiled using your current python environment: '/opt/conda/bin/python'
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorizationImpressions_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_f_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_sampleBPR_Cython’:
# MatrixFactorizationImpressions_Cython_Epoch.c:12608:17: warning: ‘__pyx_v_start_pos_impression_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 12608 |       __pyx_t_4 = (__pyx_v_start_pos_impression_items + __pyx_v_index);
#       |       ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# MatrixFactorizationImpressions_Cython_Epoch.c: In function ‘__pyx_pf_43MatrixFactorizationImpressions_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorizationImpressions_Cython_Epoch.c:8586:7: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8586 |       for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |       ^~~
# MatrixFactorizationImpressions_Cython_Epoch.c:8586:7: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorizationImpressions_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [1/10]: MatrixFactorizationImpressions_Cython_Epoch.pyx... PASS
#
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from MatrixFactorization_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# MatrixFactorization_Cython_Epoch.c: In function ‘__pyx_pf_32MatrixFactorization_Cython_Epoch_32MatrixFactorization_Cython_Epoch_10epochIteration_Cython_ASY_SVD_SGD’:
# MatrixFactorization_Cython_Epoch.c:8519:9: warning: ‘__pyx_v_end_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8519 |         for (__pyx_t_19 = __pyx_v_start_pos_seen_items; __pyx_t_19 < __pyx_t_18; __pyx_t_19+=1) {
#       |         ^~~
# MatrixFactorization_Cython_Epoch.c:8519:9: warning: ‘__pyx_v_start_pos_seen_items’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/MatrixFactorization/Cython/MatrixFactorization_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [2/10]: MatrixFactorization_Cython_Epoch.pyx... PASS
#
# Compiling [3/10]: Compute_Similarity_Cython.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Compute_Similarity_Cython.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/Similarity/Cython/Compute_Similarity_Cython.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [3/10]: Compute_Similarity_Cython.pyx... PASS
#
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx...
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from SLIM_BPR_Cython_Epoch.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# SLIM_BPR_Cython_Epoch.c: In function ‘__pyx_f_21SLIM_BPR_Cython_Epoch_22Sparse_Matrix_Tree_CSR_test_list_tee_conversion’:
# SLIM_BPR_Cython_Epoch.c:10691:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# 10691 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/SLIM_BPR_Cython_Epoch.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: SLIM_BPR_Cython_Epoch.pyx:633:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:633:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:818:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:917:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1052:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: SLIM_BPR_Cython_Epoch.pyx:1053:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [4/10]: SLIM_BPR_Cython_Epoch.pyx... PASS
#
# Compiling [5/10]: Triangular_Matrix.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Triangular_Matrix.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Triangular_Matrix.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [5/10]: Triangular_Matrix.pyx... PASS
#
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx...
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from Sparse_Matrix_Tree_CSR.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# Sparse_Matrix_Tree_CSR.c: In function ‘__pyx_f_22Sparse_Matrix_Tree_CSR_22Sparse_Matrix_Tree_CSR_test_list_tree_conversion’:
# Sparse_Matrix_Tree_CSR.c:5696:15: warning: ‘__pyx_v_previous_element’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5696 |     __pyx_t_7 = __pyx_v_current_element->lower;
#       |     ~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/SLIM/Cython/Sparse_Matrix_Tree_CSR.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: Sparse_Matrix_Tree_CSR.pyx:132:34: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:132:66: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:343:52: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:442:69: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:577:42: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:35: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# warning: Sparse_Matrix_Tree_CSR.pyx:578:53: Non-trivial type declarators in shared declaration (e.g. mix of pointers and values). Each pointer declaration should be on its own line.
# Compiling [6/10]: Sparse_Matrix_Tree_CSR.pyx... PASS
#
# Compiling [7/10]: HP3_Similarity_Cython_SGD.pyx...
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from HP3_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# HP3_Similarity_Cython_SGD.c: In function ‘__pyx_pf_25HP3_Similarity_Cython_SGD_25HP3_Similarity_Cython_SGD_4fit’:
# HP3_Similarity_Cython_SGD.c:6147:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  6147 |   __pyx_t_1 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_1)) __PYX_ERR(0, 291, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/HP3_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# warning: HP3_Similarity_Cython_SGD.pyx:113:40: Index should be typed for more efficient access
# Compiling [7/10]: HP3_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [8/10]: FBSM_Rating_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from FBSM_Rating_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# FBSM_Rating_Cython_SGD.c: In function ‘__pyx_pf_22FBSM_Rating_Cython_SGD_22FBSM_Rating_Cython_SGD_2fit’:
# FBSM_Rating_Cython_SGD.c:8875:55: warning: ‘__pyx_v_num_sample’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  8875 |   __pyx_t_5 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_num_sample))); if (unlikely(!__pyx_t_5)) __PYX_ERR(0, 551, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/FBSM_Rating_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [8/10]: FBSM_Rating_Cython_SGD.pyx... PASS
#
# Compiling [9/10]: CFW_D_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_D_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# CFW_D_Similarity_Cython_SGD.c: In function ‘__pyx_pf_27CFW_D_Similarity_Cython_SGD_27CFW_D_Similarity_Cython_SGD_6fit’:
# CFW_D_Similarity_Cython_SGD.c:5900:55: warning: ‘__pyx_v_sample_num’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#  5900 |   __pyx_t_3 = PyFloat_FromDouble((__pyx_v_cum_loss / ((double)__pyx_v_sample_num))); if (unlikely(!__pyx_t_3)) __PYX_ERR(0, 290, __pyx_L1_error)
#       |                                                      ~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_D_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [9/10]: CFW_D_Similarity_Cython_SGD.pyx... PASS
#
# Compiling [10/10]: CFW_DVV_Similarity_Cython_SGD.pyx...
# In file included from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarraytypes.h:1822,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from CFW_DVV_Similarity_Cython_SGD.c:620:
# /opt/conda/lib/python3.7/site-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:17:2: warning: #warning "Using deprecated NumPy API, disable it with " "#define NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#    17 | #warning "Using deprecated NumPy API, disable it with " \
#       |  ^~~~~~~
# /opt/conda/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /kaggle/working/Recommenders/FeatureWeighting/Cython/CFW_DVV_Similarity_Cython_SGD.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Compiling [10/10]: CFW_DVV_Similarity_Cython_SGD.pyx... PASS
#
# run_compile_all_cython: Compilation finished. SUCCESS.
# Compilation log can be found here: './result_experiments/run_compile_all_cython.txt'

# %%
from Recommenders.SLIM.Cython.SLIM_BPR_Cython import SLIM_BPR_Cython
recommender_SLIM_BPR_Cython = SLIM_BPR_Cython(URM_train)
recommender_SLIM_BPR_Cython.fit(epochs=650, sgd_mode = "sgd", topK = 483, lambda_i = 0.0006712905081189398, 
                lambda_j = 0.06584150350451998, learning_rate = 0.0036482363905043207)
# Out:
# SLIM_BPR_Recommender: Automatic selection of fastest train mode. Available RAM is 16722.00 MB (92.89%) of 18001.00 MB, required is 1304.51 MB. Using dense matrix.
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 2.75E-01. Sample per second: 15596
# SLIM_BPR_Recommender: Epoch 1 of 650. Elapsed time 0.60 sec
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 1.10E+00. Sample per second: 9229
# SLIM_BPR_Recommender: Epoch 2 of 650. Elapsed time 1.21 sec
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 1.91E+00. Sample per second: 12731
# SLIM_BPR_Recommender: Epoch 3 of 650. Elapsed time 1.80 sec
# Processed 13650 (100.0%) in 0.66 sec. BPR loss is 2.71E+00. Sample per second: 20596
# SLIM_BPR_Recommender: Epoch 4 of 650. Elapsed time 2.39 sec
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 3.45E+00. Sample per second: 10922
# SLIM_BPR_Recommender: Epoch 5 of 650. Elapsed time 2.98 sec
# Processed 13650 (100.0%) in 0.84 sec. BPR loss is 4.05E+00. Sample per second: 16213
# SLIM_BPR_Recommender: Epoch 6 of 650. Elapsed time 3.57 sec
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 4.71E+00. Sample per second: 9429
# SLIM_BPR_Recommender: Epoch 7 of 650. Elapsed time 4.18 sec
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 5.10E+00. Sample per second: 13128
# SLIM_BPR_Recommender: Epoch 8 of 650. Elapsed time 4.77 sec
# Processed 13650 (100.0%) in 0.64 sec. BPR loss is 5.77E+00. Sample per second: 21439
# SLIM_BPR_Recommender: Epoch 9 of 650. Elapsed time 5.36 sec
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 6.35E+00. Sample per second: 11170
# SLIM_BPR_Recommender: Epoch 10 of 650. Elapsed time 5.95 sec
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 6.98E+00. Sample per second: 16354
# SLIM_BPR_Recommender: Epoch 11 of 650. Elapsed time 6.56 sec
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 7.18E+00. Sample per second: 9614
# SLIM_BPR_Recommender: Epoch 12 of 650. Elapsed time 7.15 sec
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 7.35E+00. Sample per second: 13693
# SLIM_BPR_Recommender: Epoch 13 of 650. Elapsed time 7.72 sec
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 7.98E+00. Sample per second: 8652
# SLIM_BPR_Recommender: Epoch 14 of 650. Elapsed time 8.31 sec
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 8.29E+00. Sample per second: 11819
# SLIM_BPR_Recommender: Epoch 15 of 650. Elapsed time 8.88 sec
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 8.88E+00. Sample per second: 18696
# SLIM_BPR_Recommender: Epoch 16 of 650. Elapsed time 9.46 sec
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 9.21E+00. Sample per second: 10240
# SLIM_BPR_Recommender: Epoch 17 of 650. Elapsed time 10.06 sec
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 9.42E+00. Sample per second: 14960
# SLIM_BPR_Recommender: Epoch 18 of 650. Elapsed time 10.64 sec
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 9.69E+00. Sample per second: 8949
# SLIM_BPR_Recommender: Epoch 19 of 650. Elapsed time 11.25 sec
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 9.99E+00. Sample per second: 12102
# SLIM_BPR_Recommender: Epoch 20 of 650. Elapsed time 11.86 sec
# Processed 13650 (100.0%) in 0.74 sec. BPR loss is 1.00E+01. Sample per second: 18357
# SLIM_BPR_Recommender: Epoch 21 of 650. Elapsed time 12.47 sec
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 1.07E+01. Sample per second: 9816
# SLIM_BPR_Recommender: Epoch 22 of 650. Elapsed time 13.12 sec
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 1.07E+01. Sample per second: 13346
# SLIM_BPR_Recommender: Epoch 23 of 650. Elapsed time 13.75 sec
# Processed 13650 (100.0%) in 0.62 sec. BPR loss is 1.10E+01. Sample per second: 22057
# SLIM_BPR_Recommender: Epoch 24 of 650. Elapsed time 14.35 sec
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 1.16E+01. Sample per second: 11354
# SLIM_BPR_Recommender: Epoch 25 of 650. Elapsed time 14.93 sec
# Processed 13650 (100.0%) in 0.77 sec. BPR loss is 1.16E+01. Sample per second: 17733
# SLIM_BPR_Recommender: Epoch 26 of 650. Elapsed time 15.50 sec
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 1.15E+01. Sample per second: 10110
# SLIM_BPR_Recommender: Epoch 27 of 650. Elapsed time 16.08 sec
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 1.16E+01. Sample per second: 14886
# SLIM_BPR_Recommender: Epoch 28 of 650. Elapsed time 16.65 sec
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 1.21E+01. Sample per second: 9023
# SLIM_BPR_Recommender: Epoch 29 of 650. Elapsed time 17.24 sec
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 1.28E+01. Sample per second: 12692
# SLIM_BPR_Recommender: Epoch 30 of 650. Elapsed time 17.80 sec
# Processed 13650 (100.0%) in 0.63 sec. BPR loss is 1.26E+01. Sample per second: 21643
# SLIM_BPR_Recommender: Epoch 31 of 650. Elapsed time 18.36 sec
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 1.30E+01. Sample per second: 11382
# SLIM_BPR_Recommender: Epoch 32 of 650. Elapsed time 18.93 sec
# Processed 13650 (100.0%) in 0.77 sec. BPR loss is 1.32E+01. Sample per second: 17794
# SLIM_BPR_Recommender: Epoch 33 of 650. Elapsed time 19.50 sec
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 1.30E+01. Sample per second: 10187
# SLIM_BPR_Recommender: Epoch 34 of 650. Elapsed time 20.07 sec
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 1.33E+01. Sample per second: 14958
# SLIM_BPR_Recommender: Epoch 35 of 650. Elapsed time 20.64 sec
# Processed 13650 (100.0%) in 1.49 sec. BPR loss is 1.33E+01. Sample per second: 9149
# SLIM_BPR_Recommender: Epoch 36 of 650. Elapsed time 21.22 sec
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 1.35E+01. Sample per second: 12818
# SLIM_BPR_Recommender: Epoch 37 of 650. Elapsed time 21.79 sec
# Processed 13650 (100.0%) in 0.63 sec. BPR loss is 1.37E+01. Sample per second: 21829
# SLIM_BPR_Recommender: Epoch 38 of 650. Elapsed time 22.35 sec
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 1.41E+01. Sample per second: 11376
# SLIM_BPR_Recommender: Epoch 39 of 650. Elapsed time 22.93 sec
# Processed 13650 (100.0%) in 0.77 sec. BPR loss is 1.43E+01. Sample per second: 17778
# SLIM_BPR_Recommender: Epoch 40 of 650. Elapsed time 23.50 sec
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 1.44E+01. Sample per second: 10205
# SLIM_BPR_Recommender: Epoch 41 of 650. Elapsed time 24.07 sec
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 1.45E+01. Sample per second: 15071
# SLIM_BPR_Recommender: Epoch 42 of 650. Elapsed time 24.63 sec
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 1.45E+01. Sample per second: 9210
# SLIM_BPR_Recommender: Epoch 43 of 650. Elapsed time 25.21 sec
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 1.54E+01. Sample per second: 12886
# SLIM_BPR_Recommender: Epoch 44 of 650. Elapsed time 25.79 sec
# Processed 13650 (100.0%) in 0.64 sec. BPR loss is 1.49E+01. Sample per second: 21179
# SLIM_BPR_Recommender: Epoch 45 of 650. Elapsed time 26.37 sec
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 1.51E+01. Sample per second: 11170
# SLIM_BPR_Recommender: Epoch 46 of 650. Elapsed time 26.95 sec
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 1.51E+01. Sample per second: 17268
# SLIM_BPR_Recommender: Epoch 47 of 650. Elapsed time 27.52 sec
# Processed 13650 (100.0%) in 1.37 sec. BPR loss is 1.55E+01. Sample per second: 9930
# SLIM_BPR_Recommender: Epoch 48 of 650. Elapsed time 28.10 sec
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 1.60E+01. Sample per second: 14265
# SLIM_BPR_Recommender: Epoch 49 of 650. Elapsed time 28.69 sec
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 1.56E+01. Sample per second: 8891
# SLIM_BPR_Recommender: Epoch 50 of 650. Elapsed time 29.26 sec
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 1.53E+01. Sample per second: 12361
# SLIM_BPR_Recommender: Epoch 51 of 650. Elapsed time 29.83 sec
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 1.55E+01. Sample per second: 20304
# SLIM_BPR_Recommender: Epoch 52 of 650. Elapsed time 30.40 sec
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 1.59E+01. Sample per second: 10578
# SLIM_BPR_Recommender: Epoch 53 of 650. Elapsed time 31.02 sec
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 1.63E+01. Sample per second: 15786
# SLIM_BPR_Recommender: Epoch 54 of 650. Elapsed time 31.59 sec
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 1.64E+01. Sample per second: 9428
# SLIM_BPR_Recommender: Epoch 55 of 650. Elapsed time 32.18 sec
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 1.66E+01. Sample per second: 13334
# SLIM_BPR_Recommender: Epoch 56 of 650. Elapsed time 32.75 sec
# Processed 13650 (100.0%) in 0.59 sec. BPR loss is 1.63E+01. Sample per second: 23039
# SLIM_BPR_Recommender: Epoch 57 of 650. Elapsed time 33.32 sec
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 1.67E+01. Sample per second: 11758
# SLIM_BPR_Recommender: Epoch 58 of 650. Elapsed time 33.89 sec
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 1.68E+01. Sample per second: 18733
# SLIM_BPR_Recommender: Epoch 59 of 650. Elapsed time 34.46 sec
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 1.69E+01. Sample per second: 10536
# SLIM_BPR_Recommender: Epoch 60 of 650. Elapsed time 35.02 sec
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 1.71E+01. Sample per second: 15692
# SLIM_BPR_Recommender: Epoch 61 of 650. Elapsed time 35.60 sec
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 1.66E+01. Sample per second: 9353
# SLIM_BPR_Recommender: Epoch 62 of 650. Elapsed time 36.19 sec
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 1.69E+01. Sample per second: 12741
# SLIM_BPR_Recommender: Epoch 63 of 650. Elapsed time 36.80 sec
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 1.69E+01. Sample per second: 20272
# SLIM_BPR_Recommender: Epoch 64 of 650. Elapsed time 37.40 sec
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 1.72E+01. Sample per second: 10667
# SLIM_BPR_Recommender: Epoch 65 of 650. Elapsed time 38.01 sec
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 1.68E+01. Sample per second: 15842
# SLIM_BPR_Recommender: Epoch 66 of 650. Elapsed time 38.59 sec
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 1.70E+01. Sample per second: 9123
# SLIM_BPR_Recommender: Epoch 67 of 650. Elapsed time 39.22 sec
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 1.72E+01. Sample per second: 12341
# SLIM_BPR_Recommender: Epoch 68 of 650. Elapsed time 39.83 sec
# Processed 13650 (100.0%) in 0.69 sec. BPR loss is 1.73E+01. Sample per second: 19686
# SLIM_BPR_Recommender: Epoch 69 of 650. Elapsed time 40.42 sec
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 1.69E+01. Sample per second: 10697
# SLIM_BPR_Recommender: Epoch 70 of 650. Elapsed time 41.00 sec
# Processed 13650 (100.0%) in 0.85 sec. BPR loss is 1.72E+01. Sample per second: 16117
# SLIM_BPR_Recommender: Epoch 71 of 650. Elapsed time 41.58 sec
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 1.70E+01. Sample per second: 9559
# SLIM_BPR_Recommender: Epoch 72 of 650. Elapsed time 42.16 sec
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 1.78E+01. Sample per second: 13732
# SLIM_BPR_Recommender: Epoch 73 of 650. Elapsed time 42.72 sec
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 1.77E+01. Sample per second: 8630
# SLIM_BPR_Recommender: Epoch 74 of 650. Elapsed time 43.31 sec
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 1.72E+01. Sample per second: 11763
# SLIM_BPR_Recommender: Epoch 75 of 650. Elapsed time 43.89 sec
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 1.79E+01. Sample per second: 18692
# SLIM_BPR_Recommender: Epoch 76 of 650. Elapsed time 44.46 sec
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 1.76E+01. Sample per second: 10309
# SLIM_BPR_Recommender: Epoch 77 of 650. Elapsed time 45.05 sec
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 1.78E+01. Sample per second: 14990
# SLIM_BPR_Recommender: Epoch 78 of 650. Elapsed time 45.64 sec
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 1.81E+01. Sample per second: 9128
# SLIM_BPR_Recommender: Epoch 79 of 650. Elapsed time 46.22 sec
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 1.75E+01. Sample per second: 12654
# SLIM_BPR_Recommender: Epoch 80 of 650. Elapsed time 46.81 sec
# Processed 13650 (100.0%) in 0.68 sec. BPR loss is 1.80E+01. Sample per second: 19958
# SLIM_BPR_Recommender: Epoch 81 of 650. Elapsed time 47.41 sec
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 1.79E+01. Sample per second: 10658
# SLIM_BPR_Recommender: Epoch 82 of 650. Elapsed time 48.01 sec
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 1.77E+01. Sample per second: 15514
# SLIM_BPR_Recommender: Epoch 83 of 650. Elapsed time 48.61 sec
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 1.86E+01. Sample per second: 9197
# SLIM_BPR_Recommender: Epoch 84 of 650. Elapsed time 49.21 sec
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 1.88E+01. Sample per second: 12650
# SLIM_BPR_Recommender: Epoch 85 of 650. Elapsed time 49.81 sec
# Processed 13650 (100.0%) in 0.71 sec. BPR loss is 1.84E+01. Sample per second: 19347
# SLIM_BPR_Recommender: Epoch 86 of 650. Elapsed time 50.43 sec
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 1.82E+01. Sample per second: 10448
# SLIM_BPR_Recommender: Epoch 87 of 650. Elapsed time 51.03 sec
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 1.85E+01. Sample per second: 15200
# SLIM_BPR_Recommender: Epoch 88 of 650. Elapsed time 51.63 sec
# Processed 13650 (100.0%) in 1.49 sec. BPR loss is 1.86E+01. Sample per second: 9178
# SLIM_BPR_Recommender: Epoch 89 of 650. Elapsed time 52.22 sec
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 1.86E+01. Sample per second: 12663
# SLIM_BPR_Recommender: Epoch 90 of 650. Elapsed time 52.81 sec
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 1.85E+01. Sample per second: 20277
# SLIM_BPR_Recommender: Epoch 91 of 650. Elapsed time 53.40 sec
# Processed 13650 (100.0%) in 1.26 sec. BPR loss is 1.91E+01. Sample per second: 10820
# SLIM_BPR_Recommender: Epoch 92 of 650. Elapsed time 53.99 sec
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 1.86E+01. Sample per second: 15818
# SLIM_BPR_Recommender: Epoch 93 of 650. Elapsed time 54.59 sec
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 1.87E+01. Sample per second: 9258
# SLIM_BPR_Recommender: Epoch 94 of 650. Elapsed time 55.20 sec
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 1.87E+01. Sample per second: 12795
# SLIM_BPR_Recommender: Epoch 95 of 650. Elapsed time 55.79 sec
# Processed 13650 (100.0%) in 0.66 sec. BPR loss is 1.84E+01. Sample per second: 20680
# SLIM_BPR_Recommender: Epoch 96 of 650. Elapsed time 56.39 sec
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 1.87E+01. Sample per second: 10755
# SLIM_BPR_Recommender: Epoch 97 of 650. Elapsed time 57.00 sec
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 1.92E+01. Sample per second: 15904
# SLIM_BPR_Recommender: Epoch 98 of 650. Elapsed time 57.59 sec
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 1.95E+01. Sample per second: 9279
# SLIM_BPR_Recommender: Epoch 99 of 650. Elapsed time 58.20 sec
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 1.87E+01. Sample per second: 12453
# SLIM_BPR_Recommender: Epoch 100 of 650. Elapsed time 58.82 sec
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 1.88E+01. Sample per second: 19581
# SLIM_BPR_Recommender: Epoch 101 of 650. Elapsed time 59.43 sec
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 1.89E+01. Sample per second: 10488
# SLIM_BPR_Recommender: Epoch 102 of 650. Elapsed time 1.00 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 1.92E+01. Sample per second: 14904
# SLIM_BPR_Recommender: Epoch 103 of 650. Elapsed time 1.01 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 1.87E+01. Sample per second: 8814
# SLIM_BPR_Recommender: Epoch 104 of 650. Elapsed time 1.02 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 1.94E+01. Sample per second: 11880
# SLIM_BPR_Recommender: Epoch 105 of 650. Elapsed time 1.03 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 1.90E+01. Sample per second: 16810
# SLIM_BPR_Recommender: Epoch 106 of 650. Elapsed time 1.04 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 1.90E+01. Sample per second: 9652
# SLIM_BPR_Recommender: Epoch 107 of 650. Elapsed time 1.05 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 1.94E+01. Sample per second: 13602
# SLIM_BPR_Recommender: Epoch 108 of 650. Elapsed time 1.06 min
# Processed 13650 (100.0%) in 0.61 sec. BPR loss is 1.91E+01. Sample per second: 22409
# SLIM_BPR_Recommender: Epoch 109 of 650. Elapsed time 1.07 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 1.92E+01. Sample per second: 11378
# SLIM_BPR_Recommender: Epoch 110 of 650. Elapsed time 1.08 min
# Processed 13650 (100.0%) in 0.80 sec. BPR loss is 1.98E+01. Sample per second: 17120
# SLIM_BPR_Recommender: Epoch 111 of 650. Elapsed time 1.09 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 1.88E+01. Sample per second: 9819
# SLIM_BPR_Recommender: Epoch 112 of 650. Elapsed time 1.10 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 1.95E+01. Sample per second: 13733
# SLIM_BPR_Recommender: Epoch 113 of 650. Elapsed time 1.11 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 1.97E+01. Sample per second: 8574
# SLIM_BPR_Recommender: Epoch 114 of 650. Elapsed time 1.12 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 1.95E+01. Sample per second: 11429
# SLIM_BPR_Recommender: Epoch 115 of 650. Elapsed time 1.13 min
# Processed 13650 (100.0%) in 0.80 sec. BPR loss is 1.99E+01. Sample per second: 17020
# SLIM_BPR_Recommender: Epoch 116 of 650. Elapsed time 1.14 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.00E+01. Sample per second: 9742
# SLIM_BPR_Recommender: Epoch 117 of 650. Elapsed time 1.15 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.00E+01. Sample per second: 13504
# SLIM_BPR_Recommender: Epoch 118 of 650. Elapsed time 1.16 min
# Processed 13650 (100.0%) in 0.61 sec. BPR loss is 1.99E+01. Sample per second: 22334
# SLIM_BPR_Recommender: Epoch 119 of 650. Elapsed time 1.17 min
# Processed 13650 (100.0%) in 1.23 sec. BPR loss is 1.93E+01. Sample per second: 11064
# SLIM_BPR_Recommender: Epoch 120 of 650. Elapsed time 1.18 min
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 2.01E+01. Sample per second: 15927
# SLIM_BPR_Recommender: Epoch 121 of 650. Elapsed time 1.19 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.03E+01. Sample per second: 9091
# SLIM_BPR_Recommender: Epoch 122 of 650. Elapsed time 1.20 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.06E+01. Sample per second: 12457
# SLIM_BPR_Recommender: Epoch 123 of 650. Elapsed time 1.21 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 1.98E+01. Sample per second: 19425
# SLIM_BPR_Recommender: Epoch 124 of 650. Elapsed time 1.22 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.00E+01. Sample per second: 10318
# SLIM_BPR_Recommender: Epoch 125 of 650. Elapsed time 1.23 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 2.03E+01. Sample per second: 14539
# SLIM_BPR_Recommender: Epoch 126 of 650. Elapsed time 1.24 min
# Processed 13650 (100.0%) in 1.57 sec. BPR loss is 2.05E+01. Sample per second: 8674
# SLIM_BPR_Recommender: Epoch 127 of 650. Elapsed time 1.26 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.00E+01. Sample per second: 11365
# SLIM_BPR_Recommender: Epoch 128 of 650. Elapsed time 1.27 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.02E+01. Sample per second: 16433
# SLIM_BPR_Recommender: Epoch 129 of 650. Elapsed time 1.28 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.07E+01. Sample per second: 9361
# SLIM_BPR_Recommender: Epoch 130 of 650. Elapsed time 1.29 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.09E+01. Sample per second: 12608
# SLIM_BPR_Recommender: Epoch 131 of 650. Elapsed time 1.30 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 2.07E+01. Sample per second: 19518
# SLIM_BPR_Recommender: Epoch 132 of 650. Elapsed time 1.31 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.01E+01. Sample per second: 10352
# SLIM_BPR_Recommender: Epoch 133 of 650. Elapsed time 1.32 min
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.05E+01. Sample per second: 14609
# SLIM_BPR_Recommender: Epoch 134 of 650. Elapsed time 1.33 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.03E+01. Sample per second: 8904
# SLIM_BPR_Recommender: Epoch 135 of 650. Elapsed time 1.34 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 2.08E+01. Sample per second: 11899
# SLIM_BPR_Recommender: Epoch 136 of 650. Elapsed time 1.35 min
# Processed 13650 (100.0%) in 0.74 sec. BPR loss is 2.05E+01. Sample per second: 18388
# SLIM_BPR_Recommender: Epoch 137 of 650. Elapsed time 1.36 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 2.10E+01. Sample per second: 10276
# SLIM_BPR_Recommender: Epoch 138 of 650. Elapsed time 1.37 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.08E+01. Sample per second: 14407
# SLIM_BPR_Recommender: Epoch 139 of 650. Elapsed time 1.38 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.14E+01. Sample per second: 8529
# SLIM_BPR_Recommender: Epoch 140 of 650. Elapsed time 1.39 min
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 2.09E+01. Sample per second: 11194
# SLIM_BPR_Recommender: Epoch 141 of 650. Elapsed time 1.40 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.05E+01. Sample per second: 16494
# SLIM_BPR_Recommender: Epoch 142 of 650. Elapsed time 1.41 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.17E+01. Sample per second: 9346
# SLIM_BPR_Recommender: Epoch 143 of 650. Elapsed time 1.42 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.13E+01. Sample per second: 12525
# SLIM_BPR_Recommender: Epoch 144 of 650. Elapsed time 1.43 min
# Processed 13650 (100.0%) in 0.71 sec. BPR loss is 2.11E+01. Sample per second: 19092
# SLIM_BPR_Recommender: Epoch 145 of 650. Elapsed time 1.44 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.13E+01. Sample per second: 10174
# SLIM_BPR_Recommender: Epoch 146 of 650. Elapsed time 1.45 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 2.10E+01. Sample per second: 14152
# SLIM_BPR_Recommender: Epoch 147 of 650. Elapsed time 1.46 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 2.05E+01. Sample per second: 8570
# SLIM_BPR_Recommender: Epoch 148 of 650. Elapsed time 1.47 min
# Processed 13650 (100.0%) in 1.21 sec. BPR loss is 2.05E+01. Sample per second: 11303
# SLIM_BPR_Recommender: Epoch 149 of 650. Elapsed time 1.48 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.15E+01. Sample per second: 16511
# SLIM_BPR_Recommender: Epoch 150 of 650. Elapsed time 1.49 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.13E+01. Sample per second: 9426
# SLIM_BPR_Recommender: Epoch 151 of 650. Elapsed time 1.50 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.14E+01. Sample per second: 12641
# SLIM_BPR_Recommender: Epoch 152 of 650. Elapsed time 1.51 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 2.15E+01. Sample per second: 19366
# SLIM_BPR_Recommender: Epoch 153 of 650. Elapsed time 1.52 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.09E+01. Sample per second: 10339
# SLIM_BPR_Recommender: Epoch 154 of 650. Elapsed time 1.53 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.15E+01. Sample per second: 14817
# SLIM_BPR_Recommender: Epoch 155 of 650. Elapsed time 1.54 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 2.13E+01. Sample per second: 8865
# SLIM_BPR_Recommender: Epoch 156 of 650. Elapsed time 1.55 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 2.13E+01. Sample per second: 11428
# SLIM_BPR_Recommender: Epoch 157 of 650. Elapsed time 1.57 min
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 2.12E+01. Sample per second: 15456
# SLIM_BPR_Recommender: Epoch 158 of 650. Elapsed time 1.58 min
# Processed 13650 (100.0%) in 1.48 sec. BPR loss is 2.28E+01. Sample per second: 9192
# SLIM_BPR_Recommender: Epoch 159 of 650. Elapsed time 1.59 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.16E+01. Sample per second: 12442
# SLIM_BPR_Recommender: Epoch 160 of 650. Elapsed time 1.60 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 2.13E+01. Sample per second: 19622
# SLIM_BPR_Recommender: Epoch 161 of 650. Elapsed time 1.61 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 2.14E+01. Sample per second: 10507
# SLIM_BPR_Recommender: Epoch 162 of 650. Elapsed time 1.62 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.17E+01. Sample per second: 15121
# SLIM_BPR_Recommender: Epoch 163 of 650. Elapsed time 1.63 min
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.13E+01. Sample per second: 9073
# SLIM_BPR_Recommender: Epoch 164 of 650. Elapsed time 1.64 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.19E+01. Sample per second: 12438
# SLIM_BPR_Recommender: Epoch 165 of 650. Elapsed time 1.65 min
# Processed 13650 (100.0%) in 0.68 sec. BPR loss is 2.20E+01. Sample per second: 19968
# SLIM_BPR_Recommender: Epoch 166 of 650. Elapsed time 1.66 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.19E+01. Sample per second: 10668
# SLIM_BPR_Recommender: Epoch 167 of 650. Elapsed time 1.67 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 2.10E+01. Sample per second: 15650
# SLIM_BPR_Recommender: Epoch 168 of 650. Elapsed time 1.68 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.15E+01. Sample per second: 9053
# SLIM_BPR_Recommender: Epoch 169 of 650. Elapsed time 1.69 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.17E+01. Sample per second: 12125
# SLIM_BPR_Recommender: Epoch 170 of 650. Elapsed time 1.70 min
# Processed 13650 (100.0%) in 0.74 sec. BPR loss is 2.14E+01. Sample per second: 18566
# SLIM_BPR_Recommender: Epoch 171 of 650. Elapsed time 1.71 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 2.27E+01. Sample per second: 9921
# SLIM_BPR_Recommender: Epoch 172 of 650. Elapsed time 1.72 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.16E+01. Sample per second: 13744
# SLIM_BPR_Recommender: Epoch 173 of 650. Elapsed time 1.73 min
# Processed 13650 (100.0%) in 1.62 sec. BPR loss is 2.20E+01. Sample per second: 8444
# SLIM_BPR_Recommender: Epoch 174 of 650. Elapsed time 1.74 min
# Processed 13650 (100.0%) in 1.24 sec. BPR loss is 2.18E+01. Sample per second: 11013
# SLIM_BPR_Recommender: Epoch 175 of 650. Elapsed time 1.75 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 2.18E+01. Sample per second: 15039
# SLIM_BPR_Recommender: Epoch 176 of 650. Elapsed time 1.76 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.21E+01. Sample per second: 8893
# SLIM_BPR_Recommender: Epoch 177 of 650. Elapsed time 1.77 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 2.25E+01. Sample per second: 11899
# SLIM_BPR_Recommender: Epoch 178 of 650. Elapsed time 1.78 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 2.15E+01. Sample per second: 17876
# SLIM_BPR_Recommender: Epoch 179 of 650. Elapsed time 1.79 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 2.27E+01. Sample per second: 9903
# SLIM_BPR_Recommender: Epoch 180 of 650. Elapsed time 1.80 min
# Processed 13650 (100.0%) in 0.98 sec. BPR loss is 2.19E+01. Sample per second: 13927
# SLIM_BPR_Recommender: Epoch 181 of 650. Elapsed time 1.81 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.17E+01. Sample per second: 8530
# SLIM_BPR_Recommender: Epoch 182 of 650. Elapsed time 1.82 min
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 2.20E+01. Sample per second: 11217
# SLIM_BPR_Recommender: Epoch 183 of 650. Elapsed time 1.83 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.24E+01. Sample per second: 16357
# SLIM_BPR_Recommender: Epoch 184 of 650. Elapsed time 1.84 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.15E+01. Sample per second: 9265
# SLIM_BPR_Recommender: Epoch 185 of 650. Elapsed time 1.85 min
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 2.20E+01. Sample per second: 12313
# SLIM_BPR_Recommender: Epoch 186 of 650. Elapsed time 1.86 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.23E+01. Sample per second: 18804
# SLIM_BPR_Recommender: Epoch 187 of 650. Elapsed time 1.87 min
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 2.18E+01. Sample per second: 10072
# SLIM_BPR_Recommender: Epoch 188 of 650. Elapsed time 1.88 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.16E+01. Sample per second: 14343
# SLIM_BPR_Recommender: Epoch 189 of 650. Elapsed time 1.89 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 2.21E+01. Sample per second: 8847
# SLIM_BPR_Recommender: Epoch 190 of 650. Elapsed time 1.90 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 2.22E+01. Sample per second: 11873
# SLIM_BPR_Recommender: Epoch 191 of 650. Elapsed time 1.91 min
# Processed 13650 (100.0%) in 0.78 sec. BPR loss is 2.17E+01. Sample per second: 17383
# SLIM_BPR_Recommender: Epoch 192 of 650. Elapsed time 1.93 min
# Processed 13650 (100.0%) in 1.44 sec. BPR loss is 2.23E+01. Sample per second: 9501
# SLIM_BPR_Recommender: Epoch 193 of 650. Elapsed time 1.94 min
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 2.28E+01. Sample per second: 12820
# SLIM_BPR_Recommender: Epoch 194 of 650. Elapsed time 1.95 min
# Processed 13650 (100.0%) in 0.69 sec. BPR loss is 2.22E+01. Sample per second: 19755
# SLIM_BPR_Recommender: Epoch 195 of 650. Elapsed time 1.96 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.21E+01. Sample per second: 10360
# SLIM_BPR_Recommender: Epoch 196 of 650. Elapsed time 1.97 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.31E+01. Sample per second: 14391
# SLIM_BPR_Recommender: Epoch 197 of 650. Elapsed time 1.98 min
# Processed 13650 (100.0%) in 1.57 sec. BPR loss is 2.21E+01. Sample per second: 8685
# SLIM_BPR_Recommender: Epoch 198 of 650. Elapsed time 1.99 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.34E+01. Sample per second: 11374
# SLIM_BPR_Recommender: Epoch 199 of 650. Elapsed time 2.00 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.22E+01. Sample per second: 16361
# SLIM_BPR_Recommender: Epoch 200 of 650. Elapsed time 2.01 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.37E+01. Sample per second: 9371
# SLIM_BPR_Recommender: Epoch 201 of 650. Elapsed time 2.02 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.27E+01. Sample per second: 12502
# SLIM_BPR_Recommender: Epoch 202 of 650. Elapsed time 2.03 min
# Processed 13650 (100.0%) in 0.72 sec. BPR loss is 2.25E+01. Sample per second: 19079
# SLIM_BPR_Recommender: Epoch 203 of 650. Elapsed time 2.04 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.24E+01. Sample per second: 10172
# SLIM_BPR_Recommender: Epoch 204 of 650. Elapsed time 2.05 min
# Processed 13650 (100.0%) in 0.95 sec. BPR loss is 2.28E+01. Sample per second: 14390
# SLIM_BPR_Recommender: Epoch 205 of 650. Elapsed time 2.06 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.28E+01. Sample per second: 8656
# SLIM_BPR_Recommender: Epoch 206 of 650. Elapsed time 2.07 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.33E+01. Sample per second: 11411
# SLIM_BPR_Recommender: Epoch 207 of 650. Elapsed time 2.08 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.31E+01. Sample per second: 14871
# SLIM_BPR_Recommender: Epoch 208 of 650. Elapsed time 2.09 min
# Processed 13650 (100.0%) in 1.57 sec. BPR loss is 2.34E+01. Sample per second: 8671
# SLIM_BPR_Recommender: Epoch 209 of 650. Elapsed time 2.11 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.25E+01. Sample per second: 11376
# SLIM_BPR_Recommender: Epoch 210 of 650. Elapsed time 2.12 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.28E+01. Sample per second: 15210
# SLIM_BPR_Recommender: Epoch 211 of 650. Elapsed time 2.13 min
# Processed 13650 (100.0%) in 1.53 sec. BPR loss is 2.21E+01. Sample per second: 8934
# SLIM_BPR_Recommender: Epoch 212 of 650. Elapsed time 2.14 min
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 2.26E+01. Sample per second: 11722
# SLIM_BPR_Recommender: Epoch 213 of 650. Elapsed time 2.15 min
# Processed 13650 (100.0%) in 0.82 sec. BPR loss is 2.25E+01. Sample per second: 16686
# SLIM_BPR_Recommender: Epoch 214 of 650. Elapsed time 2.16 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.21E+01. Sample per second: 9366
# SLIM_BPR_Recommender: Epoch 215 of 650. Elapsed time 2.17 min
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 2.29E+01. Sample per second: 12818
# SLIM_BPR_Recommender: Epoch 216 of 650. Elapsed time 2.18 min
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 2.28E+01. Sample per second: 20460
# SLIM_BPR_Recommender: Epoch 217 of 650. Elapsed time 2.19 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.23E+01. Sample per second: 10557
# SLIM_BPR_Recommender: Epoch 218 of 650. Elapsed time 2.20 min
# Processed 13650 (100.0%) in 0.91 sec. BPR loss is 2.20E+01. Sample per second: 15056
# SLIM_BPR_Recommender: Epoch 219 of 650. Elapsed time 2.21 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.25E+01. Sample per second: 9014
# SLIM_BPR_Recommender: Epoch 220 of 650. Elapsed time 2.22 min
# Processed 13650 (100.0%) in 1.12 sec. BPR loss is 2.25E+01. Sample per second: 12163
# SLIM_BPR_Recommender: Epoch 221 of 650. Elapsed time 2.23 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 2.26E+01. Sample per second: 18045
# SLIM_BPR_Recommender: Epoch 222 of 650. Elapsed time 2.24 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.22E+01. Sample per second: 9754
# SLIM_BPR_Recommender: Epoch 223 of 650. Elapsed time 2.25 min
# Processed 13650 (100.0%) in 1.03 sec. BPR loss is 2.29E+01. Sample per second: 13248
# SLIM_BPR_Recommender: Epoch 224 of 650. Elapsed time 2.26 min
# Processed 13650 (100.0%) in 0.66 sec. BPR loss is 2.18E+01. Sample per second: 20653
# SLIM_BPR_Recommender: Epoch 225 of 650. Elapsed time 2.27 min
# Processed 13650 (100.0%) in 1.30 sec. BPR loss is 2.25E+01. Sample per second: 10503
# SLIM_BPR_Recommender: Epoch 226 of 650. Elapsed time 2.28 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 2.27E+01. Sample per second: 14542
# SLIM_BPR_Recommender: Epoch 227 of 650. Elapsed time 2.29 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 2.26E+01. Sample per second: 8591
# SLIM_BPR_Recommender: Epoch 228 of 650. Elapsed time 2.31 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.30E+01. Sample per second: 11333
# SLIM_BPR_Recommender: Epoch 229 of 650. Elapsed time 2.32 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.21E+01. Sample per second: 16423
# SLIM_BPR_Recommender: Epoch 230 of 650. Elapsed time 2.33 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.36E+01. Sample per second: 9355
# SLIM_BPR_Recommender: Epoch 231 of 650. Elapsed time 2.34 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.27E+01. Sample per second: 12687
# SLIM_BPR_Recommender: Epoch 232 of 650. Elapsed time 2.35 min
# Processed 13650 (100.0%) in 0.72 sec. BPR loss is 2.29E+01. Sample per second: 19077
# SLIM_BPR_Recommender: Epoch 233 of 650. Elapsed time 2.36 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.26E+01. Sample per second: 10151
# SLIM_BPR_Recommender: Epoch 234 of 650. Elapsed time 2.37 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 2.28E+01. Sample per second: 14090
# SLIM_BPR_Recommender: Epoch 235 of 650. Elapsed time 2.38 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.33E+01. Sample per second: 8527
# SLIM_BPR_Recommender: Epoch 236 of 650. Elapsed time 2.39 min
# Processed 13650 (100.0%) in 1.21 sec. BPR loss is 2.26E+01. Sample per second: 11233
# SLIM_BPR_Recommender: Epoch 237 of 650. Elapsed time 2.40 min
# Processed 13650 (100.0%) in 0.84 sec. BPR loss is 2.29E+01. Sample per second: 16183
# SLIM_BPR_Recommender: Epoch 238 of 650. Elapsed time 2.41 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.31E+01. Sample per second: 9293
# SLIM_BPR_Recommender: Epoch 239 of 650. Elapsed time 2.42 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.33E+01. Sample per second: 12649
# SLIM_BPR_Recommender: Epoch 240 of 650. Elapsed time 2.43 min
# Processed 13650 (100.0%) in 0.69 sec. BPR loss is 2.31E+01. Sample per second: 19867
# SLIM_BPR_Recommender: Epoch 241 of 650. Elapsed time 2.44 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.30E+01. Sample per second: 10632
# SLIM_BPR_Recommender: Epoch 242 of 650. Elapsed time 2.45 min
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 2.24E+01. Sample per second: 15505
# SLIM_BPR_Recommender: Epoch 243 of 650. Elapsed time 2.46 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.23E+01. Sample per second: 9255
# SLIM_BPR_Recommender: Epoch 244 of 650. Elapsed time 2.47 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.36E+01. Sample per second: 12581
# SLIM_BPR_Recommender: Epoch 245 of 650. Elapsed time 2.48 min
# Processed 13650 (100.0%) in 0.71 sec. BPR loss is 2.28E+01. Sample per second: 19219
# SLIM_BPR_Recommender: Epoch 246 of 650. Elapsed time 2.49 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.24E+01. Sample per second: 10430
# SLIM_BPR_Recommender: Epoch 247 of 650. Elapsed time 2.50 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.29E+01. Sample per second: 14913
# SLIM_BPR_Recommender: Epoch 248 of 650. Elapsed time 2.51 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.31E+01. Sample per second: 8993
# SLIM_BPR_Recommender: Epoch 249 of 650. Elapsed time 2.52 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 2.34E+01. Sample per second: 11994
# SLIM_BPR_Recommender: Epoch 250 of 650. Elapsed time 2.53 min
# Processed 13650 (100.0%) in 0.75 sec. BPR loss is 2.31E+01. Sample per second: 18172
# SLIM_BPR_Recommender: Epoch 251 of 650. Elapsed time 2.54 min
# Processed 13650 (100.0%) in 1.34 sec. BPR loss is 2.30E+01. Sample per second: 10201
# SLIM_BPR_Recommender: Epoch 252 of 650. Elapsed time 2.55 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 2.24E+01. Sample per second: 14564
# SLIM_BPR_Recommender: Epoch 253 of 650. Elapsed time 2.56 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.32E+01. Sample per second: 8773
# SLIM_BPR_Recommender: Epoch 254 of 650. Elapsed time 2.57 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 2.38E+01. Sample per second: 11691
# SLIM_BPR_Recommender: Epoch 255 of 650. Elapsed time 2.58 min
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 2.37E+01. Sample per second: 17269
# SLIM_BPR_Recommender: Epoch 256 of 650. Elapsed time 2.59 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.36E+01. Sample per second: 9680
# SLIM_BPR_Recommender: Epoch 257 of 650. Elapsed time 2.60 min
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 2.33E+01. Sample per second: 13126
# SLIM_BPR_Recommender: Epoch 258 of 650. Elapsed time 2.61 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 2.30E+01. Sample per second: 19408
# SLIM_BPR_Recommender: Epoch 259 of 650. Elapsed time 2.62 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.37E+01. Sample per second: 10346
# SLIM_BPR_Recommender: Epoch 260 of 650. Elapsed time 2.63 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.28E+01. Sample per second: 14827
# SLIM_BPR_Recommender: Epoch 261 of 650. Elapsed time 2.64 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.35E+01. Sample per second: 8981
# SLIM_BPR_Recommender: Epoch 262 of 650. Elapsed time 2.65 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 2.38E+01. Sample per second: 11966
# SLIM_BPR_Recommender: Epoch 263 of 650. Elapsed time 2.66 min
# Processed 13650 (100.0%) in 0.78 sec. BPR loss is 2.38E+01. Sample per second: 17509
# SLIM_BPR_Recommender: Epoch 264 of 650. Elapsed time 2.68 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.30E+01. Sample per second: 9824
# SLIM_BPR_Recommender: Epoch 265 of 650. Elapsed time 2.69 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.33E+01. Sample per second: 13738
# SLIM_BPR_Recommender: Epoch 266 of 650. Elapsed time 2.70 min
# Processed 13650 (100.0%) in 1.59 sec. BPR loss is 2.37E+01. Sample per second: 8606
# SLIM_BPR_Recommender: Epoch 267 of 650. Elapsed time 2.71 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 2.48E+01. Sample per second: 11566
# SLIM_BPR_Recommender: Epoch 268 of 650. Elapsed time 2.72 min
# Processed 13650 (100.0%) in 0.77 sec. BPR loss is 2.36E+01. Sample per second: 17766
# SLIM_BPR_Recommender: Epoch 269 of 650. Elapsed time 2.72 min
# Processed 13650 (100.0%) in 1.36 sec. BPR loss is 2.38E+01. Sample per second: 10039
# SLIM_BPR_Recommender: Epoch 270 of 650. Elapsed time 2.73 min
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.39E+01. Sample per second: 14636
# SLIM_BPR_Recommender: Epoch 271 of 650. Elapsed time 2.74 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.33E+01. Sample per second: 9015
# SLIM_BPR_Recommender: Epoch 272 of 650. Elapsed time 2.75 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.33E+01. Sample per second: 12503
# SLIM_BPR_Recommender: Epoch 273 of 650. Elapsed time 2.76 min
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 2.32E+01. Sample per second: 20227
# SLIM_BPR_Recommender: Epoch 274 of 650. Elapsed time 2.77 min
# Processed 13650 (100.0%) in 1.27 sec. BPR loss is 2.37E+01. Sample per second: 10769
# SLIM_BPR_Recommender: Epoch 275 of 650. Elapsed time 2.78 min
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 2.34E+01. Sample per second: 15903
# SLIM_BPR_Recommender: Epoch 276 of 650. Elapsed time 2.79 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.41E+01. Sample per second: 9406
# SLIM_BPR_Recommender: Epoch 277 of 650. Elapsed time 2.80 min
# Processed 13650 (100.0%) in 1.04 sec. BPR loss is 2.30E+01. Sample per second: 13168
# SLIM_BPR_Recommender: Epoch 278 of 650. Elapsed time 2.81 min
# Processed 13650 (100.0%) in 0.61 sec. BPR loss is 2.35E+01. Sample per second: 22220
# SLIM_BPR_Recommender: Epoch 279 of 650. Elapsed time 2.82 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.44E+01. Sample per second: 11382
# SLIM_BPR_Recommender: Epoch 280 of 650. Elapsed time 2.83 min
# Processed 13650 (100.0%) in 0.78 sec. BPR loss is 2.38E+01. Sample per second: 17471
# SLIM_BPR_Recommender: Epoch 281 of 650. Elapsed time 2.84 min
# Processed 13650 (100.0%) in 1.36 sec. BPR loss is 2.40E+01. Sample per second: 10011
# SLIM_BPR_Recommender: Epoch 282 of 650. Elapsed time 2.85 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 2.33E+01. Sample per second: 13681
# SLIM_BPR_Recommender: Epoch 283 of 650. Elapsed time 2.86 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.33E+01. Sample per second: 8652
# SLIM_BPR_Recommender: Epoch 284 of 650. Elapsed time 2.87 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 2.41E+01. Sample per second: 11698
# SLIM_BPR_Recommender: Epoch 285 of 650. Elapsed time 2.88 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 2.28E+01. Sample per second: 18041
# SLIM_BPR_Recommender: Epoch 286 of 650. Elapsed time 2.89 min
# Processed 13650 (100.0%) in 1.35 sec. BPR loss is 2.40E+01. Sample per second: 10097
# SLIM_BPR_Recommender: Epoch 287 of 650. Elapsed time 2.90 min
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.32E+01. Sample per second: 14719
# SLIM_BPR_Recommender: Epoch 288 of 650. Elapsed time 2.91 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.40E+01. Sample per second: 9036
# SLIM_BPR_Recommender: Epoch 289 of 650. Elapsed time 2.92 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 2.37E+01. Sample per second: 12739
# SLIM_BPR_Recommender: Epoch 290 of 650. Elapsed time 2.93 min
# Processed 13650 (100.0%) in 0.65 sec. BPR loss is 2.31E+01. Sample per second: 20935
# SLIM_BPR_Recommender: Epoch 291 of 650. Elapsed time 2.94 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.34E+01. Sample per second: 10884
# SLIM_BPR_Recommender: Epoch 292 of 650. Elapsed time 2.95 min
# Processed 13650 (100.0%) in 0.86 sec. BPR loss is 2.34E+01. Sample per second: 15810
# SLIM_BPR_Recommender: Epoch 293 of 650. Elapsed time 2.96 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.31E+01. Sample per second: 9325
# SLIM_BPR_Recommender: Epoch 294 of 650. Elapsed time 2.97 min
# Processed 13650 (100.0%) in 1.07 sec. BPR loss is 2.34E+01. Sample per second: 12759
# SLIM_BPR_Recommender: Epoch 295 of 650. Elapsed time 2.98 min
# Processed 13650 (100.0%) in 0.67 sec. BPR loss is 2.40E+01. Sample per second: 20219
# SLIM_BPR_Recommender: Epoch 296 of 650. Elapsed time 2.99 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.42E+01. Sample per second: 10691
# SLIM_BPR_Recommender: Epoch 297 of 650. Elapsed time 3.00 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 2.47E+01. Sample per second: 15403
# SLIM_BPR_Recommender: Epoch 298 of 650. Elapsed time 3.01 min
# Processed 13650 (100.0%) in 1.49 sec. BPR loss is 2.43E+01. Sample per second: 9138
# SLIM_BPR_Recommender: Epoch 299 of 650. Elapsed time 3.02 min
# Processed 13650 (100.0%) in 1.08 sec. BPR loss is 2.37E+01. Sample per second: 12585
# SLIM_BPR_Recommender: Epoch 300 of 650. Elapsed time 3.03 min
# Processed 13650 (100.0%) in 0.72 sec. BPR loss is 2.38E+01. Sample per second: 19066
# SLIM_BPR_Recommender: Epoch 301 of 650. Elapsed time 3.04 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.39E+01. Sample per second: 10358
# SLIM_BPR_Recommender: Epoch 302 of 650. Elapsed time 3.05 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.39E+01. Sample per second: 14806
# SLIM_BPR_Recommender: Epoch 303 of 650. Elapsed time 3.06 min
# Processed 13650 (100.0%) in 1.54 sec. BPR loss is 2.44E+01. Sample per second: 8861
# SLIM_BPR_Recommender: Epoch 304 of 650. Elapsed time 3.07 min
# Processed 13650 (100.0%) in 1.17 sec. BPR loss is 2.42E+01. Sample per second: 11625
# SLIM_BPR_Recommender: Epoch 305 of 650. Elapsed time 3.08 min
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 2.42E+01. Sample per second: 17243
# SLIM_BPR_Recommender: Epoch 306 of 650. Elapsed time 3.09 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.31E+01. Sample per second: 9771
# SLIM_BPR_Recommender: Epoch 307 of 650. Elapsed time 3.10 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.45E+01. Sample per second: 13501
# SLIM_BPR_Recommender: Epoch 308 of 650. Elapsed time 3.11 min
# Processed 13650 (100.0%) in 0.62 sec. BPR loss is 2.41E+01. Sample per second: 22032
# SLIM_BPR_Recommender: Epoch 309 of 650. Elapsed time 3.12 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.37E+01. Sample per second: 10914
# SLIM_BPR_Recommender: Epoch 310 of 650. Elapsed time 3.13 min
# Processed 13650 (100.0%) in 0.94 sec. BPR loss is 2.43E+01. Sample per second: 14473
# SLIM_BPR_Recommender: Epoch 311 of 650. Elapsed time 3.14 min
# Processed 13650 (100.0%) in 1.55 sec. BPR loss is 2.48E+01. Sample per second: 8787
# SLIM_BPR_Recommender: Epoch 312 of 650. Elapsed time 3.15 min
# Processed 13650 (100.0%) in 1.15 sec. BPR loss is 2.49E+01. Sample per second: 11841
# SLIM_BPR_Recommender: Epoch 313 of 650. Elapsed time 3.16 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.47E+01. Sample per second: 18572
# SLIM_BPR_Recommender: Epoch 314 of 650. Elapsed time 3.17 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.35E+01. Sample per second: 10311
# SLIM_BPR_Recommender: Epoch 315 of 650. Elapsed time 3.18 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.38E+01. Sample per second: 14851
# SLIM_BPR_Recommender: Epoch 316 of 650. Elapsed time 3.19 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.38E+01. Sample per second: 9049
# SLIM_BPR_Recommender: Epoch 317 of 650. Elapsed time 3.20 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.42E+01. Sample per second: 12361
# SLIM_BPR_Recommender: Epoch 318 of 650. Elapsed time 3.21 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.40E+01. Sample per second: 18674
# SLIM_BPR_Recommender: Epoch 319 of 650. Elapsed time 3.22 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 2.45E+01. Sample per second: 10237
# SLIM_BPR_Recommender: Epoch 320 of 650. Elapsed time 3.23 min
# Processed 13650 (100.0%) in 0.93 sec. BPR loss is 2.41E+01. Sample per second: 14682
# SLIM_BPR_Recommender: Epoch 321 of 650. Elapsed time 3.24 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.37E+01. Sample per second: 8970
# SLIM_BPR_Recommender: Epoch 322 of 650. Elapsed time 3.25 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.33E+01. Sample per second: 12103
# SLIM_BPR_Recommender: Epoch 323 of 650. Elapsed time 3.26 min
# Processed 13650 (100.0%) in 0.72 sec. BPR loss is 2.48E+01. Sample per second: 19019
# SLIM_BPR_Recommender: Epoch 324 of 650. Elapsed time 3.27 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.41E+01. Sample per second: 10355
# SLIM_BPR_Recommender: Epoch 325 of 650. Elapsed time 3.28 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.35E+01. Sample per second: 15132
# SLIM_BPR_Recommender: Epoch 326 of 650. Elapsed time 3.29 min
# ...
# Processed 13650 (100.0%) in 1.50 sec. BPR loss is 2.67E+01. Sample per second: 9069
# SLIM_BPR_Recommender: Epoch 543 of 650. Elapsed time 5.44 min
# Processed 13650 (100.0%) in 1.10 sec. BPR loss is 2.72E+01. Sample per second: 12406
# SLIM_BPR_Recommender: Epoch 544 of 650. Elapsed time 5.45 min
# Processed 13650 (100.0%) in 0.68 sec. BPR loss is 2.62E+01. Sample per second: 20161
# SLIM_BPR_Recommender: Epoch 545 of 650. Elapsed time 5.46 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.68E+01. Sample per second: 10637
# SLIM_BPR_Recommender: Epoch 546 of 650. Elapsed time 5.47 min
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 2.64E+01. Sample per second: 15457
# SLIM_BPR_Recommender: Epoch 547 of 650. Elapsed time 5.48 min
# Processed 13650 (100.0%) in 1.47 sec. BPR loss is 2.54E+01. Sample per second: 9274
# SLIM_BPR_Recommender: Epoch 548 of 650. Elapsed time 5.49 min
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 2.63E+01. Sample per second: 12831
# SLIM_BPR_Recommender: Epoch 549 of 650. Elapsed time 5.50 min
# Processed 13650 (100.0%) in 0.64 sec. BPR loss is 2.56E+01. Sample per second: 21255
# SLIM_BPR_Recommender: Epoch 550 of 650. Elapsed time 5.51 min
# Processed 13650 (100.0%) in 1.24 sec. BPR loss is 2.59E+01. Sample per second: 11034
# SLIM_BPR_Recommender: Epoch 551 of 650. Elapsed time 5.52 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 2.56E+01. Sample per second: 16761
# SLIM_BPR_Recommender: Epoch 552 of 650. Elapsed time 5.53 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.71E+01. Sample per second: 9826
# SLIM_BPR_Recommender: Epoch 553 of 650. Elapsed time 5.54 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.57E+01. Sample per second: 13781
# SLIM_BPR_Recommender: Epoch 554 of 650. Elapsed time 5.55 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.64E+01. Sample per second: 8549
# SLIM_BPR_Recommender: Epoch 555 of 650. Elapsed time 5.56 min
# Processed 13650 (100.0%) in 1.21 sec. BPR loss is 2.63E+01. Sample per second: 11280
# SLIM_BPR_Recommender: Epoch 556 of 650. Elapsed time 5.57 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 2.79E+01. Sample per second: 16787
# SLIM_BPR_Recommender: Epoch 557 of 650. Elapsed time 5.58 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.69E+01. Sample per second: 9667
# SLIM_BPR_Recommender: Epoch 558 of 650. Elapsed time 5.59 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.66E+01. Sample per second: 13556
# SLIM_BPR_Recommender: Epoch 559 of 650. Elapsed time 5.60 min
# Processed 13650 (100.0%) in 0.64 sec. BPR loss is 2.61E+01. Sample per second: 21397
# SLIM_BPR_Recommender: Epoch 560 of 650. Elapsed time 5.61 min
# Processed 13650 (100.0%) in 1.23 sec. BPR loss is 2.63E+01. Sample per second: 11080
# SLIM_BPR_Recommender: Epoch 561 of 650. Elapsed time 5.62 min
# Processed 13650 (100.0%) in 0.82 sec. BPR loss is 2.66E+01. Sample per second: 16715
# SLIM_BPR_Recommender: Epoch 562 of 650. Elapsed time 5.63 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.68E+01. Sample per second: 9691
# SLIM_BPR_Recommender: Epoch 563 of 650. Elapsed time 5.64 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.60E+01. Sample per second: 13815
# SLIM_BPR_Recommender: Epoch 564 of 650. Elapsed time 5.65 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.70E+01. Sample per second: 8734
# SLIM_BPR_Recommender: Epoch 565 of 650. Elapsed time 5.65 min
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 2.77E+01. Sample per second: 11793
# SLIM_BPR_Recommender: Epoch 566 of 650. Elapsed time 5.66 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.65E+01. Sample per second: 18716
# SLIM_BPR_Recommender: Epoch 567 of 650. Elapsed time 5.67 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 2.75E+01. Sample per second: 10274
# SLIM_BPR_Recommender: Epoch 568 of 650. Elapsed time 5.68 min
# Processed 13650 (100.0%) in 0.92 sec. BPR loss is 2.64E+01. Sample per second: 14856
# SLIM_BPR_Recommender: Epoch 569 of 650. Elapsed time 5.69 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.65E+01. Sample per second: 8958
# SLIM_BPR_Recommender: Epoch 570 of 650. Elapsed time 5.70 min
# Processed 13650 (100.0%) in 1.13 sec. BPR loss is 2.72E+01. Sample per second: 12102
# SLIM_BPR_Recommender: Epoch 571 of 650. Elapsed time 5.71 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.66E+01. Sample per second: 18730
# SLIM_BPR_Recommender: Epoch 572 of 650. Elapsed time 5.72 min
# Processed 13650 (100.0%) in 1.32 sec. BPR loss is 2.76E+01. Sample per second: 10362
# SLIM_BPR_Recommender: Epoch 573 of 650. Elapsed time 5.73 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.68E+01. Sample per second: 15130
# SLIM_BPR_Recommender: Epoch 574 of 650. Elapsed time 5.74 min
# Processed 13650 (100.0%) in 1.49 sec. BPR loss is 2.73E+01. Sample per second: 9148
# SLIM_BPR_Recommender: Epoch 575 of 650. Elapsed time 5.75 min
# Processed 13650 (100.0%) in 1.09 sec. BPR loss is 2.66E+01. Sample per second: 12549
# SLIM_BPR_Recommender: Epoch 576 of 650. Elapsed time 5.76 min
# Processed 13650 (100.0%) in 0.78 sec. BPR loss is 2.71E+01. Sample per second: 17438
# SLIM_BPR_Recommender: Epoch 577 of 650. Elapsed time 5.78 min
# Processed 13650 (100.0%) in 1.42 sec. BPR loss is 2.64E+01. Sample per second: 9644
# SLIM_BPR_Recommender: Epoch 578 of 650. Elapsed time 5.79 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.68E+01. Sample per second: 13386
# SLIM_BPR_Recommender: Epoch 579 of 650. Elapsed time 5.80 min
# Processed 13650 (100.0%) in 0.60 sec. BPR loss is 2.73E+01. Sample per second: 22587
# SLIM_BPR_Recommender: Epoch 580 of 650. Elapsed time 5.81 min
# Processed 13650 (100.0%) in 1.21 sec. BPR loss is 2.77E+01. Sample per second: 11274
# SLIM_BPR_Recommender: Epoch 581 of 650. Elapsed time 5.82 min
# Processed 13650 (100.0%) in 0.80 sec. BPR loss is 2.65E+01. Sample per second: 17050
# SLIM_BPR_Recommender: Epoch 582 of 650. Elapsed time 5.83 min
# Processed 13650 (100.0%) in 1.39 sec. BPR loss is 2.68E+01. Sample per second: 9787
# SLIM_BPR_Recommender: Epoch 583 of 650. Elapsed time 5.84 min
# Processed 13650 (100.0%) in 0.99 sec. BPR loss is 2.69E+01. Sample per second: 13756
# SLIM_BPR_Recommender: Epoch 584 of 650. Elapsed time 5.85 min
# Processed 13650 (100.0%) in 1.60 sec. BPR loss is 2.74E+01. Sample per second: 8552
# SLIM_BPR_Recommender: Epoch 585 of 650. Elapsed time 5.86 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.61E+01. Sample per second: 11339
# SLIM_BPR_Recommender: Epoch 586 of 650. Elapsed time 5.87 min
# Processed 13650 (100.0%) in 0.80 sec. BPR loss is 2.62E+01. Sample per second: 16973
# SLIM_BPR_Recommender: Epoch 587 of 650. Elapsed time 5.88 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.69E+01. Sample per second: 9759
# SLIM_BPR_Recommender: Epoch 588 of 650. Elapsed time 5.89 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 2.71E+01. Sample per second: 13632
# SLIM_BPR_Recommender: Epoch 589 of 650. Elapsed time 5.90 min
# Processed 13650 (100.0%) in 0.60 sec. BPR loss is 2.71E+01. Sample per second: 22651
# SLIM_BPR_Recommender: Epoch 590 of 650. Elapsed time 5.91 min
# Processed 13650 (100.0%) in 1.20 sec. BPR loss is 2.68E+01. Sample per second: 11375
# SLIM_BPR_Recommender: Epoch 591 of 650. Elapsed time 5.92 min
# Processed 13650 (100.0%) in 0.81 sec. BPR loss is 2.67E+01. Sample per second: 16877
# SLIM_BPR_Recommender: Epoch 592 of 650. Elapsed time 5.93 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.71E+01. Sample per second: 9663
# SLIM_BPR_Recommender: Epoch 593 of 650. Elapsed time 5.94 min
# Processed 13650 (100.0%) in 1.01 sec. BPR loss is 2.71E+01. Sample per second: 13515
# SLIM_BPR_Recommender: Epoch 594 of 650. Elapsed time 5.95 min
# Processed 13650 (100.0%) in 0.62 sec. BPR loss is 2.62E+01. Sample per second: 22021
# SLIM_BPR_Recommender: Epoch 595 of 650. Elapsed time 5.96 min
# Processed 13650 (100.0%) in 1.22 sec. BPR loss is 2.75E+01. Sample per second: 11226
# SLIM_BPR_Recommender: Epoch 596 of 650. Elapsed time 5.97 min
# Processed 13650 (100.0%) in 0.85 sec. BPR loss is 2.69E+01. Sample per second: 16034
# SLIM_BPR_Recommender: Epoch 597 of 650. Elapsed time 5.98 min
# Processed 13650 (100.0%) in 1.46 sec. BPR loss is 2.71E+01. Sample per second: 9374
# SLIM_BPR_Recommender: Epoch 598 of 650. Elapsed time 5.99 min
# Processed 13650 (100.0%) in 1.05 sec. BPR loss is 2.64E+01. Sample per second: 13028
# SLIM_BPR_Recommender: Epoch 599 of 650. Elapsed time 6.00 min
# Processed 13650 (100.0%) in 0.64 sec. BPR loss is 2.64E+01. Sample per second: 21414
# SLIM_BPR_Recommender: Epoch 600 of 650. Elapsed time 6.01 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.63E+01. Sample per second: 10939
# SLIM_BPR_Recommender: Epoch 601 of 650. Elapsed time 6.02 min
# Processed 13650 (100.0%) in 0.84 sec. BPR loss is 2.70E+01. Sample per second: 16234
# SLIM_BPR_Recommender: Epoch 602 of 650. Elapsed time 6.03 min
# Processed 13650 (100.0%) in 1.43 sec. BPR loss is 2.65E+01. Sample per second: 9555
# SLIM_BPR_Recommender: Epoch 603 of 650. Elapsed time 6.04 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.63E+01. Sample per second: 13387
# SLIM_BPR_Recommender: Epoch 604 of 650. Elapsed time 6.05 min
# Processed 13650 (100.0%) in 0.61 sec. BPR loss is 2.68E+01. Sample per second: 22354
# SLIM_BPR_Recommender: Epoch 605 of 650. Elapsed time 6.06 min
# Processed 13650 (100.0%) in 1.19 sec. BPR loss is 2.64E+01. Sample per second: 11455
# SLIM_BPR_Recommender: Epoch 606 of 650. Elapsed time 6.07 min
# Processed 13650 (100.0%) in 0.79 sec. BPR loss is 2.80E+01. Sample per second: 17380
# SLIM_BPR_Recommender: Epoch 607 of 650. Elapsed time 6.08 min
# Processed 13650 (100.0%) in 1.38 sec. BPR loss is 2.60E+01. Sample per second: 9861
# SLIM_BPR_Recommender: Epoch 608 of 650. Elapsed time 6.09 min
# Processed 13650 (100.0%) in 0.98 sec. BPR loss is 2.71E+01. Sample per second: 13970
# SLIM_BPR_Recommender: Epoch 609 of 650. Elapsed time 6.10 min
# Processed 13650 (100.0%) in 1.56 sec. BPR loss is 2.68E+01. Sample per second: 8748
# SLIM_BPR_Recommender: Epoch 610 of 650. Elapsed time 6.10 min
# Processed 13650 (100.0%) in 1.14 sec. BPR loss is 2.74E+01. Sample per second: 11993
# SLIM_BPR_Recommender: Epoch 611 of 650. Elapsed time 6.11 min
# Processed 13650 (100.0%) in 0.70 sec. BPR loss is 2.79E+01. Sample per second: 19400
# SLIM_BPR_Recommender: Epoch 612 of 650. Elapsed time 6.12 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.60E+01. Sample per second: 10575
# SLIM_BPR_Recommender: Epoch 613 of 650. Elapsed time 6.13 min
# Processed 13650 (100.0%) in 0.90 sec. BPR loss is 2.81E+01. Sample per second: 15149
# SLIM_BPR_Recommender: Epoch 614 of 650. Elapsed time 6.14 min
# Processed 13650 (100.0%) in 1.52 sec. BPR loss is 2.71E+01. Sample per second: 8974
# SLIM_BPR_Recommender: Epoch 615 of 650. Elapsed time 6.15 min
# Processed 13650 (100.0%) in 1.11 sec. BPR loss is 2.70E+01. Sample per second: 12290
# SLIM_BPR_Recommender: Epoch 616 of 650. Elapsed time 6.16 min
# Processed 13650 (100.0%) in 0.69 sec. BPR loss is 2.61E+01. Sample per second: 19669
# SLIM_BPR_Recommender: Epoch 617 of 650. Elapsed time 6.17 min
# Processed 13650 (100.0%) in 1.29 sec. BPR loss is 2.73E+01. Sample per second: 10554
# SLIM_BPR_Recommender: Epoch 618 of 650. Elapsed time 6.18 min
# Processed 13650 (100.0%) in 0.87 sec. BPR loss is 2.73E+01. Sample per second: 15759
# SLIM_BPR_Recommender: Epoch 619 of 650. Elapsed time 6.19 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.70E+01. Sample per second: 9429
# SLIM_BPR_Recommender: Epoch 620 of 650. Elapsed time 6.20 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.78E+01. Sample per second: 13346
# SLIM_BPR_Recommender: Epoch 621 of 650. Elapsed time 6.21 min
# Processed 13650 (100.0%) in 0.60 sec. BPR loss is 2.78E+01. Sample per second: 22584
# SLIM_BPR_Recommender: Epoch 622 of 650. Elapsed time 6.22 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 2.79E+01. Sample per second: 11542
# SLIM_BPR_Recommender: Epoch 623 of 650. Elapsed time 6.23 min
# Processed 13650 (100.0%) in 0.76 sec. BPR loss is 2.72E+01. Sample per second: 17983
# SLIM_BPR_Recommender: Epoch 624 of 650. Elapsed time 6.24 min
# Processed 13650 (100.0%) in 1.33 sec. BPR loss is 2.70E+01. Sample per second: 10255
# SLIM_BPR_Recommender: Epoch 625 of 650. Elapsed time 6.25 min
# Processed 13650 (100.0%) in 0.89 sec. BPR loss is 2.69E+01. Sample per second: 15351
# SLIM_BPR_Recommender: Epoch 626 of 650. Elapsed time 6.26 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.68E+01. Sample per second: 9436
# SLIM_BPR_Recommender: Epoch 627 of 650. Elapsed time 6.27 min
# Processed 13650 (100.0%) in 1.02 sec. BPR loss is 2.66E+01. Sample per second: 13443
# SLIM_BPR_Recommender: Epoch 628 of 650. Elapsed time 6.28 min
# Processed 13650 (100.0%) in 0.66 sec. BPR loss is 2.71E+01. Sample per second: 20785
# SLIM_BPR_Recommender: Epoch 629 of 650. Elapsed time 6.29 min
# Processed 13650 (100.0%) in 1.25 sec. BPR loss is 2.65E+01. Sample per second: 10929
# SLIM_BPR_Recommender: Epoch 630 of 650. Elapsed time 6.30 min
# Processed 13650 (100.0%) in 0.83 sec. BPR loss is 2.59E+01. Sample per second: 16369
# SLIM_BPR_Recommender: Epoch 631 of 650. Elapsed time 6.31 min
# Processed 13650 (100.0%) in 1.41 sec. BPR loss is 2.72E+01. Sample per second: 9690
# SLIM_BPR_Recommender: Epoch 632 of 650. Elapsed time 6.32 min
# Processed 13650 (100.0%) in 0.97 sec. BPR loss is 2.72E+01. Sample per second: 14123
# SLIM_BPR_Recommender: Epoch 633 of 650. Elapsed time 6.33 min
# Processed 13650 (100.0%) in 1.58 sec. BPR loss is 2.76E+01. Sample per second: 8663
# SLIM_BPR_Recommender: Epoch 634 of 650. Elapsed time 6.34 min
# Processed 13650 (100.0%) in 1.16 sec. BPR loss is 2.83E+01. Sample per second: 11782
# SLIM_BPR_Recommender: Epoch 635 of 650. Elapsed time 6.35 min
# Processed 13650 (100.0%) in 0.73 sec. BPR loss is 2.63E+01. Sample per second: 18762
# SLIM_BPR_Recommender: Epoch 636 of 650. Elapsed time 6.36 min
# Processed 13650 (100.0%) in 1.28 sec. BPR loss is 2.64E+01. Sample per second: 10672
# SLIM_BPR_Recommender: Epoch 637 of 650. Elapsed time 6.37 min
# Processed 13650 (100.0%) in 0.84 sec. BPR loss is 2.69E+01. Sample per second: 16276
# SLIM_BPR_Recommender: Epoch 638 of 650. Elapsed time 6.38 min
# Processed 13650 (100.0%) in 1.40 sec. BPR loss is 2.66E+01. Sample per second: 9730
# SLIM_BPR_Recommender: Epoch 639 of 650. Elapsed time 6.39 min
# Processed 13650 (100.0%) in 0.96 sec. BPR loss is 2.66E+01. Sample per second: 14290
# SLIM_BPR_Recommender: Epoch 640 of 650. Elapsed time 6.39 min
# Processed 13650 (100.0%) in 1.51 sec. BPR loss is 2.68E+01. Sample per second: 9063
# SLIM_BPR_Recommender: Epoch 641 of 650. Elapsed time 6.40 min
# Processed 13650 (100.0%) in 1.06 sec. BPR loss is 2.70E+01. Sample per second: 12895
# SLIM_BPR_Recommender: Epoch 642 of 650. Elapsed time 6.41 min
# Processed 13650 (100.0%) in 0.63 sec. BPR loss is 2.74E+01. Sample per second: 21641
# SLIM_BPR_Recommender: Epoch 643 of 650. Elapsed time 6.42 min
# Processed 13650 (100.0%) in 1.18 sec. BPR loss is 2.64E+01. Sample per second: 11526
# SLIM_BPR_Recommender: Epoch 644 of 650. Elapsed time 6.43 min
# Processed 13650 (100.0%) in 0.75 sec. BPR loss is 2.74E+01. Sample per second: 18257
# SLIM_BPR_Recommender: Epoch 645 of 650. Elapsed time 6.44 min
# Processed 13650 (100.0%) in 1.31 sec. BPR loss is 2.76E+01. Sample per second: 10427
# SLIM_BPR_Recommender: Epoch 646 of 650. Elapsed time 6.45 min
# Processed 13650 (100.0%) in 0.88 sec. BPR loss is 2.72E+01. Sample per second: 15503
# SLIM_BPR_Recommender: Epoch 647 of 650. Elapsed time 6.46 min
# Processed 13650 (100.0%) in 1.45 sec. BPR loss is 2.75E+01. Sample per second: 9433
# SLIM_BPR_Recommender: Epoch 648 of 650. Elapsed time 6.47 min
# Processed 13650 (100.0%) in 1.00 sec. BPR loss is 2.61E+01. Sample per second: 13623
# SLIM_BPR_Recommender: Epoch 649 of 650. Elapsed time 6.48 min
# Processed 13650 (100.0%) in 0.57 sec. BPR loss is 2.69E+01. Sample per second: 23933
# SLIM_BPR_Recommender: Epoch 650 of 650. Elapsed time 6.49 min
# SLIM_BPR_Recommender: Terminating at epoch 650. Elapsed time 6.91 min
# Deallocating Cython objects

# %%
from Recommenders.MatrixFactorization.IALSRecommender import IALSRecommender

recommender_mf_ials = IALSRecommender(URM_train)
recommender_mf_ials.fit(num_factors = 48, confidence_scaling= 'linear', alpha = 1.0, epsilon = 0.10715471885641545, reg = 0.0005294631576919714, epochs = 30)
# Out:
# IALSRecommender: Epoch 1 of 30. Elapsed time 11.55 sec
# IALSRecommender: Epoch 2 of 30. Elapsed time 22.84 sec
# IALSRecommender: Epoch 3 of 30. Elapsed time 35.42 sec
# IALSRecommender: Epoch 4 of 30. Elapsed time 47.78 sec
# IALSRecommender: Epoch 5 of 30. Elapsed time 58.74 sec
# IALSRecommender: Epoch 6 of 30. Elapsed time 1.19 min
# IALSRecommender: Epoch 7 of 30. Elapsed time 1.39 min
# IALSRecommender: Epoch 8 of 30. Elapsed time 1.57 min
# IALSRecommender: Epoch 9 of 30. Elapsed time 1.77 min
# IALSRecommender: Epoch 10 of 30. Elapsed time 1.98 min
# IALSRecommender: Epoch 11 of 30. Elapsed time 2.16 min
# IALSRecommender: Epoch 12 of 30. Elapsed time 2.36 min
# IALSRecommender: Epoch 13 of 30. Elapsed time 2.56 min
# IALSRecommender: Epoch 14 of 30. Elapsed time 2.77 min
# IALSRecommender: Epoch 15 of 30. Elapsed time 2.95 min
# IALSRecommender: Epoch 16 of 30. Elapsed time 3.15 min
# IALSRecommender: Epoch 17 of 30. Elapsed time 3.36 min
# IALSRecommender: Epoch 18 of 30. Elapsed time 3.54 min
# IALSRecommender: Epoch 19 of 30. Elapsed time 3.74 min
# IALSRecommender: Epoch 20 of 30. Elapsed time 3.95 min
# IALSRecommender: Epoch 21 of 30. Elapsed time 4.13 min
# IALSRecommender: Epoch 22 of 30. Elapsed time 4.33 min
# IALSRecommender: Epoch 23 of 30. Elapsed time 4.53 min
# IALSRecommender: Epoch 24 of 30. Elapsed time 4.71 min
# IALSRecommender: Epoch 25 of 30. Elapsed time 4.91 min
# IALSRecommender: Epoch 26 of 30. Elapsed time 5.12 min
# IALSRecommender: Epoch 27 of 30. Elapsed time 5.30 min
# IALSRecommender: Epoch 28 of 30. Elapsed time 5.52 min
# IALSRecommender: Epoch 29 of 30. Elapsed time 5.71 min
# IALSRecommender: Epoch 30 of 30. Elapsed time 5.89 min
# IALSRecommender: Terminating at epoch 30. Elapsed time 5.89 min

# %%
from Recommenders.MatrixFactorization.NMFRecommender import NMFRecommender

recommender_NMF = NMFRecommender(URM_train)
recommender_NMF.fit(num_factors = 36, beta_loss = 'frobenius', l1_ratio = 1.0)
# Out:
# NMFRecommender: Computing NMF decomposition...
# NMFRecommender: Computing NMF decomposition... done in 1.17 min

# %%
print("MAP of the starting models")

result_df, _ = evaluator_valid.evaluateRecommender(recommender_SLIMElasticNet)
print("SLIM ElasticNet - MAP: {}".format(result_df.loc[10]["MAP"]))

result_df, _ = evaluator_valid.evaluateRecommender(recommender_SLIM_BPR_Cython)
print("SLIM BPR - MAP: {}".format(result_df.loc[10]["MAP"]))

result_df, _ = evaluator_valid.evaluateRecommender(recommender_mf_ials)
print("MF IALS - MAP: {}".format(result_df.loc[10]["MAP"]))

result_df, _ = evaluator_valid.evaluateRecommender(recommender_NMF)
print("NMF - MAP: {}".format(result_df.loc[10]["MAP"]))
# Out:
# MAP of the starting models
# EvaluatorHoldout: Processed 13646 (100.0%) in 24.34 sec. Users per second: 561
# SLIM ElasticNet - MAP: 0.24700765559533663
# EvaluatorHoldout: Processed 13646 (100.0%) in 23.81 sec. Users per second: 573
# SLIM BPR - MAP: 0.2395518280838154
# EvaluatorHoldout: Processed 13646 (100.0%) in 14.58 sec. Users per second: 936
# MF IALS - MAP: 0.23390040165267473
# EvaluatorHoldout: Processed 13646 (100.0%) in 25.24 sec. Users per second: 541
# NMF - MAP: 0.21594444211804648

# %%
from numpy import linalg as LA
from Recommenders.BaseRecommender import BaseRecommender

class DifferentLossScoresHybridRecommender(BaseRecommender):
    """ ScoresHybridRecommender
    Hybrid of four predictions scores
    R = R1*alpha + R2*beta + R3*theta + R3*(1-alpha-beta-theta)
    
    Class from Dacrema exercise modified by Antonio Ercolani
    The original took as input 2 recommender

    """

    RECOMMENDER_NAME = "DifferentLossScoresHybridRecommender"


    def __init__(self, URM_train, recommender_1, recommender_2, recommender_3, recommender_4):
        super(DifferentLossScoresHybridRecommender, self).__init__(URM_train)

        self.URM_train = sps.csr_matrix(URM_train)
        self.recommender_1 = recommender_1
        self.recommender_2 = recommender_2
        self.recommender_3 = recommender_3
        self.recommender_4 = recommender_4
        
        
        
    def fit(self, norm, alpha = 0.5, beta = 0.5, theta = 0):

        self.alpha = alpha
        self.beta = beta
        self.theta = theta
        self.norm = norm


    def _compute_item_score(self, user_id_array, items_to_compute):
        
        item_weights_1 = self.recommender_1._compute_item_score(user_id_array)
        item_weights_2 = self.recommender_2._compute_item_score(user_id_array)
        item_weights_3 = self.recommender_3._compute_item_score(user_id_array)
        item_weights_4 = self.recommender_4._compute_item_score(user_id_array)

        norm_item_weights_1 = LA.norm(item_weights_1, self.norm)
        norm_item_weights_2 = LA.norm(item_weights_2, self.norm)
        norm_item_weights_3 = LA.norm(item_weights_3, self.norm)
        norm_item_weights_4 = LA.norm(item_weights_4, self.norm)
        
        
        if norm_item_weights_1 == 0:
            raise ValueError("Norm {} of item weights for recommender 1 is zero. Avoiding division by zero".format(self.norm))
        
        if norm_item_weights_2 == 0:
            raise ValueError("Norm {} of item weights for recommender 2 is zero. Avoiding division by zero".format(self.norm))
            
        if norm_item_weights_3 == 0:
            raise ValueError("Norm {} of item weights for recommender 3 is zero. Avoiding division by zero".format(self.norm))
            
        if norm_item_weights_4 == 0:
            raise ValueError("Norm {} of item weights for recommender 4 is zero. Avoiding division by zero".format(self.norm))
        
        item_weights = item_weights_1 / norm_item_weights_1 * self.alpha + item_weights_2 / norm_item_weights_2 * self.beta + item_weights_3 / norm_item_weights_3 * self.theta + item_weights_4 / norm_item_weights_4 * (1-self.alpha-self.beta-self.theta)

        return item_weights

# %%
recommender_object = DifferentLossScoresHybridRecommender(URM_train, recommender_SLIMElasticNet, recommender_SLIM_BPR_Cython, recommender_mf_ials, recommender_NMF)

best_model = {
    "MAP" : 0,
    "alpha" : 0,
    "beta" : 0,
    "theta" : 0,
    "norm" : 0
}

for norm in [2]:
    for alpha in np.arange(0.2, 1.1, 0.1):
        for beta in np.arange(0.3, 1.1, 0.1):
            for theta in np.arange(0.4, 1.1, 0.1):
            
                #truncate digits since np.arange sometimes doesn't
                alpha = round(alpha,1)
                beta = round(beta,1)
                theta = round(theta,1)


                #discard cases in which the sum is greater than 1 
                if ( (alpha+beta+theta) <= 1): 
                    gamma = round(1-alpha-beta-theta,1)

                    print("----")
                    recommender_object.fit(norm, alpha, beta, theta)
                    result_df, _ = evaluator_valid.evaluateRecommender(recommender_object)
                    print("Norm: {}, Alpha: {}, Beta: {}, Theta: {}, Gamma: {}, Result: {}".format(norm, alpha, beta, theta, gamma, result_df.loc[10]["MAP"]))

                    if result_df.loc[10]["MAP"] > best_model["MAP"]:
                        best_model["MAP"] = result_df.loc[10]["MAP"]
                        best_model["alpha"] = alpha
                        best_model["beta"] = beta
                        best_model["theta"] = theta
                        best_model["norm"] = norm

                        print("*** New best model found! ")
                        print("New best model has MAP: {} with alpha: {}, beta: {}, theta: {}, gamma: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"],
                                                                                                                           best_model["theta"], gamma,
                                                                                                                           best_model["norm"]))

print("----")
print("Best model has MAP: {} with alpha: {}, beta: {}, theta: {}, norm: {}".format(best_model["MAP"], best_model["alpha"], best_model["beta"], best_model["theta"], best_model["norm"]))
# Out:
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 3.96 min. Users per second: 57
# Norm: 2, Alpha: 0.2, Beta: 0.3, Theta: 0.4, Gamma: 0.1, Result: 0.24864367777987173
# *** New best model found!
# New best model has MAP: 0.24864367777987173 with alpha: 0.2, beta: 0.3, theta: 0.4, gamma: 0.1, norm: 2
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 3.56 min. Users per second: 64
# Norm: 2, Alpha: 0.2, Beta: 0.3, Theta: 0.5, Gamma: 0.0, Result: 0.24907279940165017
# *** New best model found!
# New best model has MAP: 0.24907279940165017 with alpha: 0.2, beta: 0.3, theta: 0.5, gamma: 0.0, norm: 2
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 3.23 min. Users per second: 70
# Norm: 2, Alpha: 0.2, Beta: 0.4, Theta: 0.4, Gamma: 0.0, Result: 0.2501788738603555
# *** New best model found!
# New best model has MAP: 0.2501788738603555 with alpha: 0.2, beta: 0.4, theta: 0.4, gamma: 0.0, norm: 2
# ----
# EvaluatorHoldout: Processed 13646 (100.0%) in 3.21 min. Users per second: 71
# Norm: 2, Alpha: 0.3, Beta: 0.3, Theta: 0.4, Gamma: -0.0, Result: 0.25030820125206743
# *** New best model found!
# New best model has MAP: 0.25030820125206743 with alpha: 0.3, beta: 0.3, theta: 0.4, gamma: -0.0, norm: 2
# ----
# Best model has MAP: 0.25030820125206743 with alpha: 0.3, beta: 0.3, theta: 0.4, norm: 2
